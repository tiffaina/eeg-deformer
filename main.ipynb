# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Setup

# %%
# %cd /content
# !rm -rf eeg-deformer EEG-Deformer

# !git clone -b setup https://github.com/tiffaina/eeg-deformer.git
# Out:
# /content
# Cloning into 'eeg-deformer'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 105 (delta 16), reused 98 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (105/105), 11.18 MiB | 15.29 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !mv eeg-deformer EEG-Deformer

# %cd EEG-Deformer

# !ls
# %cd EEG-Deformer
# Out:
# /content/EEG-Deformer
# EEG-Deformer  README.md  requirements.txt  run_model.ipynb
# /content/EEG-Deformer/EEG-Deformer

# %%
# !pip install uv
# !uv pip install --system \
    "torch>=1.10.0" \
    "torchvision>=0.11.0" \
    "torchaudio>=0.10.0" \
    "numpy>=1.21.0" \
    "scipy>=1.7.0" \
    "pandas>=1.3.0" \
    "scikit-learn>=1.0.0" \
    "matplotlib>=3.4.0" \
    "seaborn>=0.11.0" \
    "tqdm>=4.62.0" \
    "einops>=0.4.0" \
    "tensorboard>=2.8.0" \
    "pytorch-lightning==2.0.9.post0" \
    "mne" \
    "sktime"
# Out:
# Requirement already satisfied: uv in /usr/local/lib/python3.12/dist-packages (0.9.21)
# Using Python 3.12.12 environment at: /usr
# Resolved 80 packages in 390ms
# Prepared 6 packages in 654ms
# Installed 6 packages in 63ms
#  + lightning-utilities==0.15.2
#  + mne==1.11.0
#  + pytorch-lightning==2.0.9.post0
#  + scikit-base==0.13.0
#  + sktime==0.40.1
#  + torchmetrics==1.8.2

# %%
import torch
import argparse
torch.serialization.add_safe_globals([argparse.Namespace])

# %%
# !ln -s "/content/drive/MyDrive/MVA/time-series-project/data_processed" "/content/EEG-Deformer/EEG-Deformer/data_processed"

# !ls /content/EEG-Deformer/EEG-Deformer/data_processed
# Out:
# data_eeg_FATIG_FTG  data_eeg_MWL_MW  data_processed

# %% [markdown]
# ## Baseline Model

# %%
# !find /content -name "Task.py"
# Out:
# /content/EEG-Deformer/EEG-Deformer/Task.py

# %%
# %%writefile /content/EEG-Deformer/EEG-Deformer/Task.py
from models.model_handler import DLModel
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint
from utils import *
import torch

def LOSO(test_idx: list, subjects: list, experiment_ID, logs_name, args):
    pl.seed_everything(seed=args.random_seed)
    torch.manual_seed(args.random_seed)
    torch.backends.cudnn.deterministic = True
    # load test data
    load_path = osp.join(args.load_path, 'data_{}_{}_{}'.format(args.data_format, args.dataset, args.label_type))
    data_test, label_test = load_data(load_path=load_path, load_idx=test_idx, concat=True)
    # load training data
    train_idx = [item for item in subjects if item not in test_idx]
    data_train, label_train = load_data(load_path=load_path, load_idx=train_idx, concat=True)
    train_idx, val_idx = get_validation_set(train_idx=np.arange(data_train.shape[0]), val_rate=args.val_rate, shuffle=True)
    data_val, label_val = data_train[val_idx], label_train[val_idx]
    data_train, label_train = data_train[train_idx], label_train[train_idx]
    # normalize the data
    data_train, data_val, data_test = normalize(train=data_train, val=data_val, test=data_test)

    print('Train:{} Val:{} Test:{}'.format(data_train.shape, data_val.shape, data_test.shape))
    idx, _ = get_channel_info(load_path=load_path, graph_type=args.graph_type)
    # prepare dataloaders
    train_loader = prepare_data_for_training(data=data_train, label=label_train, idx=idx, batch_size=args.batch_size, shuffle=True)
    val_loader = prepare_data_for_training(data=data_val, label=label_val, idx=idx, batch_size=args.batch_size, shuffle=False)
    test_loader = prepare_data_for_training(data=data_test, label=label_test, idx=idx, batch_size=1000, shuffle=False)

    # train and test the model
    model = DLModel(config=args)
    checkpoint_callback = ModelCheckpoint(monitor="val_acc", mode='max')
    ensure_path(args.save_path)
    logger = TensorBoardLogger(save_dir=args.save_path, version=experiment_ID, name=logs_name)

    if args.mixed_precision:
        trainer = pl.Trainer(accelerator="gpu", devices=[args.gpu], max_epochs=args.max_epoch, logger=logger, callbacks=[checkpoint_callback], precision='16-mixed')
    else:
        trainer = pl.Trainer(accelerator="gpu", devices=[args.gpu], max_epochs=args.max_epoch, logger=logger, callbacks=[checkpoint_callback])

    trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)

    best_model_path = trainer.checkpoint_callback.best_model_path
    best_val_metrics = trainer.checkpoint_callback.best_model_score.item()
    print(f"Loading best model weights from: {best_model_path}")

    # Force weights_only=False
    checkpoint = torch.load(best_model_path, map_location=lambda storage, loc: storage, weights_only=False)
    model.load_state_dict(checkpoint['state_dict'])

    results = trainer.test(model=model, dataloaders=test_loader)
    results[0]['best_val'] = best_val_metrics
    return results
# Out:
# Overwriting /content/EEG-Deformer/EEG-Deformer/Task.py

# %%
# %cd /content/EEG-Deformer/EEG-Deformer/
# !python main_FATIG.py --model Deformer --full-run 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.16it/s]
# Epoch 29: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.448, val_acc=0.861, val_f1=0.848, train_loss=0.164, train_acc=0.930, train_f1=0.927]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.37it/s]
# Epoch 30: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.669, val_acc=0.816, val_f1=0.782, train_loss=0.149, train_acc=0.939, train_f1=0.936]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.80it/s]
# Epoch 31: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.500, val_acc=0.848, val_f1=0.829, train_loss=0.165, train_acc=0.935, train_f1=0.931]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.01it/s]
# Epoch 32: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.400, val_acc=0.880, val_f1=0.872, train_loss=0.158, train_acc=0.941, train_f1=0.938]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.32it/s]
# Epoch 33: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.437, val_acc=0.879, val_f1=0.866, train_loss=0.166, train_acc=0.930, train_f1=0.926]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.72it/s]
# Epoch 34: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.458, val_acc=0.863, val_f1=0.848, train_loss=0.144, train_acc=0.949, train_f1=0.946]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.40it/s]
# Epoch 35: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.539, val_acc=0.850, val_f1=0.830, train_loss=0.142, train_acc=0.944, train_f1=0.941]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.68it/s]
# Epoch 36: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.501, val_acc=0.857, val_f1=0.843, train_loss=0.124, train_acc=0.954, train_f1=0.952]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.78it/s]
# Epoch 37: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.813, val_acc=0.798, val_f1=0.757, train_loss=0.146, train_acc=0.944, train_f1=0.941]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.64it/s]
# Epoch 38: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.371, val_acc=0.879, val_f1=0.868, train_loss=0.131, train_acc=0.948, train_f1=0.945]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.44it/s]
# Epoch 39: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.395, val_acc=0.880, val_f1=0.870, train_loss=0.125, train_acc=0.951, train_f1=0.949]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.97it/s]
# Epoch 40: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.385, val_acc=0.875, val_f1=0.869, train_loss=0.123, train_acc=0.949, train_f1=0.946]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.02it/s]
# Epoch 41: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.407, val_acc=0.875, val_f1=0.864, train_loss=0.122, train_acc=0.952, train_f1=0.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.10it/s]
# Epoch 42: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.448, val_acc=0.855, val_f1=0.839, train_loss=0.136, train_acc=0.949, train_f1=0.946]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.12it/s]
# Epoch 43: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.421, val_acc=0.864, val_f1=0.851, train_loss=0.123, train_acc=0.950, train_f1=0.946]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.20it/s]
# Epoch 44: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.462, val_acc=0.873, val_f1=0.860, train_loss=0.175, train_acc=0.936, train_f1=0.933]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.97it/s]
# Epoch 45: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.412, val_acc=0.877, val_f1=0.869, train_loss=0.115, train_acc=0.955, train_f1=0.952]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.51it/s]
# Epoch 46: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.385, val_acc=0.871, val_f1=0.862, train_loss=0.124, train_acc=0.951, train_f1=0.948]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 45.34it/s]
# Epoch 47: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.520, val_acc=0.871, val_f1=0.860, train_loss=0.0983, train_acc=0.963, train_f1=0.962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.45it/s]
# Epoch 48: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.624, val_acc=0.837, val_f1=0.815, train_loss=0.103, train_acc=0.961, train_f1=0.959]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.09it/s]
# Epoch 49: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub41, val_loss=0.520, val_acc=0.879, val_f1=0.868, train_loss=0.107, train_acc=0.957, train_f1=0.954]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.33it/s]
# Epoch 50: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.533, val_acc=0.863, val_f1=0.848, train_loss=0.111, train_acc=0.956, train_f1=0.953]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.92it/s]
# Epoch 51: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.503, val_acc=0.870, val_f1=0.861, train_loss=0.106, train_acc=0.959, train_f1=0.957]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.39it/s]
# Epoch 52: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.451, val_acc=0.871, val_f1=0.863, train_loss=0.0908, train_acc=0.966, train_f1=0.964]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.51it/s]
# Epoch 53: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub41, val_loss=0.571, val_acc=0.859, val_f1=0.841, train_loss=0.0887, train_acc=0.965, train_f1=0.964]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.56it/s]
# Epoch 54: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.476, val_acc=0.866, val_f1=0.855, train_loss=0.103, train_acc=0.960, train_f1=0.957]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.69it/s]
# Epoch 55: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.643, val_acc=0.857, val_f1=0.839, train_loss=0.0849, train_acc=0.966, train_f1=0.965]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.71it/s]
# Epoch 56: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.425, val_acc=0.886, val_f1=0.877, train_loss=0.0916, train_acc=0.965, train_f1=0.963]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.37it/s]
# Epoch 57: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.884, val_acc=0.796, val_f1=0.756, train_loss=0.0884, train_acc=0.972, train_f1=0.970]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.87it/s]
# Epoch 58: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.546, val_acc=0.875, val_f1=0.862, train_loss=0.0823, train_acc=0.964, train_f1=0.962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.89it/s]
# Epoch 59: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.548, val_acc=0.873, val_f1=0.860, train_loss=0.0927, train_acc=0.962, train_f1=0.961]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.26it/s]
# Epoch 60: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.698, val_acc=0.845, val_f1=0.822, train_loss=0.0992, train_acc=0.957, train_f1=0.955]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.01it/s]
# Epoch 61: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.472, val_acc=0.879, val_f1=0.868, train_loss=0.0756, train_acc=0.969, train_f1=0.967]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.27it/s]
# Epoch 62: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.531, val_acc=0.877, val_f1=0.865, train_loss=0.0613, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.51it/s]
# Epoch 63: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.697, val_acc=0.855, val_f1=0.837, train_loss=0.0706, train_acc=0.973, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.01it/s]
# Epoch 64: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.507, val_acc=0.875, val_f1=0.865, train_loss=0.0703, train_acc=0.972, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.74it/s]
# Epoch 65: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.530, val_acc=0.879, val_f1=0.866, train_loss=0.100, train_acc=0.964, train_f1=0.962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.58it/s]
# Epoch 66: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.654, val_acc=0.846, val_f1=0.824, train_loss=0.104, train_acc=0.963, train_f1=0.961]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.97it/s]
# Epoch 67: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.500, val_acc=0.880, val_f1=0.871, train_loss=0.0859, train_acc=0.968, train_f1=0.966]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.45it/s]
# Epoch 68: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.605, val_acc=0.857, val_f1=0.838, train_loss=0.113, train_acc=0.958, train_f1=0.955]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.22it/s]
# Epoch 69: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.463, val_acc=0.880, val_f1=0.870, train_loss=0.073, train_acc=0.974, train_f1=0.972]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.71it/s]
# Epoch 70: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.442, val_acc=0.882, val_f1=0.874, train_loss=0.0716, train_acc=0.969, train_f1=0.967]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.10it/s]
# Epoch 71: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.694, val_acc=0.827, val_f1=0.795, train_loss=0.0815, train_acc=0.969, train_f1=0.967]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 47.46it/s]
# Epoch 72: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.430, val_acc=0.886, val_f1=0.875, train_loss=0.076, train_acc=0.973, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.13it/s]
# Epoch 73: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.558, val_acc=0.868, val_f1=0.852, train_loss=0.0739, train_acc=0.975, train_f1=0.973]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.33it/s]
# Epoch 74: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.654, val_acc=0.846, val_f1=0.825, train_loss=0.0532, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.60it/s]
# Epoch 75: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.602, val_acc=0.868, val_f1=0.852, train_loss=0.0539, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.83it/s]
# Epoch 76: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.566, val_acc=0.877, val_f1=0.863, train_loss=0.045, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.89it/s]
# Epoch 77: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.762, val_acc=0.845, val_f1=0.822, train_loss=0.0668, train_acc=0.977, train_f1=0.976]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.06it/s]
# Epoch 78: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.527, val_acc=0.875, val_f1=0.862, train_loss=0.0585, train_acc=0.980, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.96it/s]
# Epoch 79: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.544, val_acc=0.877, val_f1=0.865, train_loss=0.0658, train_acc=0.976, train_f1=0.975]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.73it/s]
# Epoch 80: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.626, val_acc=0.864, val_f1=0.849, train_loss=0.0579, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.79it/s]
# Epoch 81: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.660, val_acc=0.861, val_f1=0.844, train_loss=0.0582, train_acc=0.981, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.85it/s]
# Epoch 82: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.512, val_acc=0.887, val_f1=0.879, train_loss=0.0552, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.45it/s]
# Epoch 83: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.574, val_acc=0.884, val_f1=0.873, train_loss=0.066, train_acc=0.978, train_f1=0.977]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.24it/s]
# Epoch 84: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.711, val_acc=0.863, val_f1=0.847, train_loss=0.0513, train_acc=0.983, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.24it/s]
# Epoch 85: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.667, val_acc=0.864, val_f1=0.848, train_loss=0.0519, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.59it/s]
# Epoch 86: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.523, val_acc=0.879, val_f1=0.869, train_loss=0.0418, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.38it/s]
# Epoch 87: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.733, val_acc=0.850, val_f1=0.829, train_loss=0.0509, train_acc=0.980, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.84it/s]
# Epoch 88: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.531, val_acc=0.882, val_f1=0.872, train_loss=0.0491, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.10it/s]
# Epoch 89: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.796, val_acc=0.836, val_f1=0.811, train_loss=0.0519, train_acc=0.983, train_f1=0.982]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 47.42it/s]
# Epoch 90: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.602, val_acc=0.886, val_f1=0.875, train_loss=0.0513, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.45it/s]
# Epoch 91: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.661, val_acc=0.863, val_f1=0.847, train_loss=0.0466, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.92it/s]
# Epoch 92: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.746, val_acc=0.845, val_f1=0.823, train_loss=0.0477, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.41it/s]
# Epoch 93: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.585, val_acc=0.875, val_f1=0.861, train_loss=0.0537, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.48it/s]
# Epoch 94: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.608, val_acc=0.880, val_f1=0.867, train_loss=0.0489, train_acc=0.983, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.73it/s]
# Epoch 95: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.631, val_acc=0.873, val_f1=0.858, train_loss=0.0514, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.12it/s]
# Epoch 96: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.870, val_acc=0.834, val_f1=0.808, train_loss=0.0431, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.52it/s]
# Epoch 97: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.581, val_acc=0.887, val_f1=0.876, train_loss=0.0485, train_acc=0.982, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.95it/s]
# Epoch 98: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub41, val_loss=0.538, val_acc=0.891, val_f1=0.881, train_loss=0.0405, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.58it/s]
# Epoch 99: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.520, val_acc=0.896, val_f1=0.887, train_loss=0.0439, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.02it/s]
# Epoch 100: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.591, val_acc=0.886, val_f1=0.875, train_loss=0.0377, train_acc=0.987, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.93it/s]
# Epoch 101: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.538, val_acc=0.893, val_f1=0.884, train_loss=0.0369, train_acc=0.987, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.72it/s]
# Epoch 102: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.474, val_acc=0.889, val_f1=0.881, train_loss=0.050, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.84it/s]
# Epoch 103: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.558, val_acc=0.884, val_f1=0.873, train_loss=0.0409, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.58it/s]
# Epoch 104: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=ub41, val_loss=0.705, val_acc=0.863, val_f1=0.846, train_loss=0.0383, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.31it/s]
# Epoch 105: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.950, val_acc=0.818, val_f1=0.786, train_loss=0.0424, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.98it/s]
# Epoch 106: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.686, val_acc=0.871, val_f1=0.854, train_loss=0.041, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.02it/s]
# Epoch 107: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.600, val_acc=0.873, val_f1=0.861, train_loss=0.0345, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.77it/s]
# Epoch 108: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.698, val_acc=0.857, val_f1=0.838, train_loss=0.0345, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.68it/s]
# Epoch 109: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.785, val_acc=0.850, val_f1=0.827, train_loss=0.0474, train_acc=0.982, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.05it/s]
# Epoch 110: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.612, val_acc=0.882, val_f1=0.870, train_loss=0.0264, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.68it/s]
# Epoch 111: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.483, val_acc=0.882, val_f1=0.875, train_loss=0.0363, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.77it/s]
# Epoch 112: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.650, val_acc=0.887, val_f1=0.876, train_loss=0.0325, train_acc=0.989, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.25it/s]
# Epoch 113: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.582, val_acc=0.895, val_f1=0.885, train_loss=0.0306, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.52it/s]
# Epoch 114: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.728, val_acc=0.877, val_f1=0.864, train_loss=0.0408, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.77it/s]
# Epoch 115: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.744, val_acc=0.864, val_f1=0.846, train_loss=0.0394, train_acc=0.985, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.20it/s]
# Epoch 116: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.609, val_acc=0.880, val_f1=0.870, train_loss=0.043, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.10it/s]
# Epoch 117: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.679, val_acc=0.868, val_f1=0.853, train_loss=0.0345, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.36it/s]
# Epoch 118: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.659, val_acc=0.877, val_f1=0.864, train_loss=0.0289, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.13it/s]
# Epoch 119: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.707, val_acc=0.859, val_f1=0.841, train_loss=0.0369, train_acc=0.983, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.41it/s]
# Epoch 120: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.545, val_acc=0.893, val_f1=0.884, train_loss=0.0288, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.26it/s]
# Epoch 121: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.599, val_acc=0.887, val_f1=0.876, train_loss=0.0316, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.15it/s]
# Epoch 122: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.643, val_acc=0.863, val_f1=0.847, train_loss=0.0338, train_acc=0.989, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.47it/s]
# Epoch 123: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.662, val_acc=0.875, val_f1=0.863, train_loss=0.0288, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.10it/s]
# Epoch 124: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.571, val_acc=0.893, val_f1=0.884, train_loss=0.0399, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.18it/s]
# Epoch 125: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.614, val_acc=0.887, val_f1=0.877, train_loss=0.0281, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.44it/s]
# Epoch 126: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.852, val_acc=0.846, val_f1=0.823, train_loss=0.0287, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.65it/s]
# Epoch 127: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub41, val_loss=0.833, val_acc=0.859, val_f1=0.841, train_loss=0.0274, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.11it/s]
# Epoch 128: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.687, val_acc=0.879, val_f1=0.866, train_loss=0.034, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.39it/s]
# Epoch 129: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.556, val_acc=0.889, val_f1=0.880, train_loss=0.027, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.19it/s]
# Epoch 130: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.674, val_acc=0.879, val_f1=0.866, train_loss=0.0232, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.75it/s]
# Epoch 131: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.735, val_acc=0.861, val_f1=0.845, train_loss=0.0259, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.19it/s]
# Epoch 132: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.633, val_acc=0.889, val_f1=0.880, train_loss=0.0302, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.34it/s]
# Epoch 133: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.648, val_acc=0.880, val_f1=0.869, train_loss=0.0268, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.21it/s]
# Epoch 134: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.674, val_acc=0.870, val_f1=0.855, train_loss=0.0296, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.95it/s]
# Epoch 135: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.740, val_acc=0.868, val_f1=0.852, train_loss=0.0277, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.89it/s]
# Epoch 136: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.744, val_acc=0.859, val_f1=0.842, train_loss=0.0238, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.34it/s]
# Epoch 137: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.706, val_acc=0.868, val_f1=0.854, train_loss=0.0232, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.24it/s]
# Epoch 138: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.603, val_acc=0.889, val_f1=0.880, train_loss=0.0215, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.98it/s]
# Epoch 139: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=ub41, val_loss=0.881, val_acc=0.841, val_f1=0.819, train_loss=0.0222, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.44it/s]
# Epoch 140: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=ub41, val_loss=0.651, val_acc=0.879, val_f1=0.866, train_loss=0.0219, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.50it/s]
# Epoch 141: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.716, val_acc=0.866, val_f1=0.850, train_loss=0.0273, train_acc=0.989, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.29it/s]
# Epoch 142: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=ub41, val_loss=0.682, val_acc=0.873, val_f1=0.860, train_loss=0.0233, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.95it/s]
# Epoch 143: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.788, val_acc=0.857, val_f1=0.839, train_loss=0.0268, train_acc=0.989, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.21it/s]
# Epoch 144: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.583, val_acc=0.895, val_f1=0.886, train_loss=0.0197, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.26it/s]
# Epoch 145: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.664, val_acc=0.868, val_f1=0.853, train_loss=0.0257, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.71it/s]
# Epoch 146: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.860, val_acc=0.836, val_f1=0.812, train_loss=0.0254, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.47it/s]
# Epoch 147: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.725, val_acc=0.866, val_f1=0.850, train_loss=0.0216, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.09it/s]
# Epoch 148: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.644, val_acc=0.875, val_f1=0.863, train_loss=0.0285, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.60it/s]
# Epoch 149: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.640, val_acc=0.886, val_f1=0.875, train_loss=0.0228, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.42it/s]
# Epoch 150: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.700, val_acc=0.866, val_f1=0.851, train_loss=0.0253, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.20it/s]
# Epoch 151: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.762, val_acc=0.857, val_f1=0.839, train_loss=0.0209, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.02it/s]
# Epoch 152: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.664, val_acc=0.879, val_f1=0.867, train_loss=0.0207, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.54it/s]
# Epoch 153: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=ub41, val_loss=0.684, val_acc=0.871, val_f1=0.859, train_loss=0.0339, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.04it/s]
# Epoch 154: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.657, val_acc=0.875, val_f1=0.863, train_loss=0.0214, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.60it/s]
# Epoch 155: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub41, val_loss=0.753, val_acc=0.864, val_f1=0.848, train_loss=0.0259, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.93it/s]
# Epoch 156: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.659, val_acc=0.879, val_f1=0.867, train_loss=0.0247, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.18it/s]
# Epoch 157: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.682, val_acc=0.870, val_f1=0.855, train_loss=0.0267, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.99it/s]
# Epoch 158: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.596, val_acc=0.891, val_f1=0.882, train_loss=0.0242, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.58it/s]
# Epoch 159: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.784, val_acc=0.859, val_f1=0.841, train_loss=0.0232, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.49it/s]
# Epoch 160: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=ub41, val_loss=0.626, val_acc=0.887, val_f1=0.877, train_loss=0.0263, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.25it/s]
# Epoch 161: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.714, val_acc=0.870, val_f1=0.855, train_loss=0.0232, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.09it/s]
# Epoch 162: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.647, val_acc=0.880, val_f1=0.869, train_loss=0.0197, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.92it/s]
# Epoch 163: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=ub41, val_loss=0.679, val_acc=0.875, val_f1=0.863, train_loss=0.0183, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.64it/s]
# Epoch 164: 100% 35/35 [00:03<00:00, 10.04it/s, v_num=ub41, val_loss=0.641, val_acc=0.882, val_f1=0.871, train_loss=0.0232, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.22it/s]
# Epoch 165: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=ub41, val_loss=0.774, val_acc=0.861, val_f1=0.844, train_loss=0.0194, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.49it/s]
# Epoch 166: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.626, val_acc=0.889, val_f1=0.880, train_loss=0.0167, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.91it/s]
# Epoch 167: 100% 35/35 [00:03<00:00, 10.06it/s, v_num=ub41, val_loss=0.667, val_acc=0.877, val_f1=0.864, train_loss=0.0232, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.23it/s]
# Epoch 168: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.584, val_acc=0.896, val_f1=0.888, train_loss=0.018, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.29it/s]
# Epoch 169: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.703, val_acc=0.871, val_f1=0.857, train_loss=0.0211, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.34it/s]
# Epoch 170: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.749, val_acc=0.866, val_f1=0.851, train_loss=0.0169, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.57it/s]
# Epoch 171: 100% 35/35 [00:03<00:00, 10.02it/s, v_num=ub41, val_loss=0.642, val_acc=0.893, val_f1=0.883, train_loss=0.0237, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.55it/s]
# ...
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.84it/s]
# Epoch 156: 100% 34/34 [00:03<00:00, 10.01it/s, v_num=ub52, val_loss=0.557, val_acc=0.869, val_f1=0.862, train_loss=0.0352, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.43it/s]
# Epoch 157: 100% 34/34 [00:03<00:00, 10.01it/s, v_num=ub52, val_loss=0.557, val_acc=0.871, val_f1=0.865, train_loss=0.0188, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.79it/s]
# Epoch 158: 100% 34/34 [00:03<00:00, 10.09it/s, v_num=ub52, val_loss=0.569, val_acc=0.869, val_f1=0.862, train_loss=0.017, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.66it/s]
# Epoch 159: 100% 34/34 [00:03<00:00, 10.05it/s, v_num=ub52, val_loss=0.602, val_acc=0.863, val_f1=0.856, train_loss=0.0244, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.18it/s]
# Epoch 160: 100% 34/34 [00:03<00:00, 10.04it/s, v_num=ub52, val_loss=0.627, val_acc=0.858, val_f1=0.850, train_loss=0.0171, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 45.63it/s]
# Epoch 161: 100% 34/34 [00:03<00:00, 10.08it/s, v_num=ub52, val_loss=0.592, val_acc=0.875, val_f1=0.869, train_loss=0.0184, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.86it/s]
# Epoch 162: 100% 34/34 [00:03<00:00, 10.11it/s, v_num=ub52, val_loss=0.662, val_acc=0.849, val_f1=0.839, train_loss=0.0196, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.45it/s]
# Epoch 163: 100% 34/34 [00:03<00:00, 10.08it/s, v_num=ub52, val_loss=0.607, val_acc=0.875, val_f1=0.868, train_loss=0.0185, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.01it/s]
# Epoch 164: 100% 34/34 [00:03<00:00,  9.99it/s, v_num=ub52, val_loss=0.625, val_acc=0.867, val_f1=0.860, train_loss=0.0212, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.88it/s]
# Epoch 165: 100% 34/34 [00:03<00:00, 10.11it/s, v_num=ub52, val_loss=0.622, val_acc=0.871, val_f1=0.864, train_loss=0.0205, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.62it/s]
# Epoch 166: 100% 34/34 [00:03<00:00, 10.11it/s, v_num=ub52, val_loss=0.602, val_acc=0.873, val_f1=0.866, train_loss=0.0206, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.73it/s]
# Epoch 167: 100% 34/34 [00:03<00:00, 10.10it/s, v_num=ub52, val_loss=0.585, val_acc=0.875, val_f1=0.868, train_loss=0.0276, train_acc=0.988, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.54it/s]
# Epoch 168: 100% 34/34 [00:03<00:00, 10.16it/s, v_num=ub52, val_loss=0.582, val_acc=0.873, val_f1=0.866, train_loss=0.0194, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 54.09it/s]
# Epoch 169: 100% 34/34 [00:03<00:00, 10.15it/s, v_num=ub52, val_loss=0.585, val_acc=0.875, val_f1=0.869, train_loss=0.0249, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 55.25it/s]
# Epoch 170: 100% 34/34 [00:03<00:00, 10.13it/s, v_num=ub52, val_loss=0.597, val_acc=0.875, val_f1=0.868, train_loss=0.0194, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.41it/s]
# Epoch 171: 100% 34/34 [00:03<00:00, 10.07it/s, v_num=ub52, val_loss=0.627, val_acc=0.865, val_f1=0.858, train_loss=0.0261, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.18it/s]
# Epoch 172: 100% 34/34 [00:03<00:00, 10.09it/s, v_num=ub52, val_loss=0.597, val_acc=0.875, val_f1=0.868, train_loss=0.0206, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.14it/s]
# Epoch 173: 100% 34/34 [00:03<00:00, 10.15it/s, v_num=ub52, val_loss=0.607, val_acc=0.862, val_f1=0.854, train_loss=0.0142, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.25it/s]
# Epoch 174: 100% 34/34 [00:03<00:00, 10.12it/s, v_num=ub52, val_loss=0.625, val_acc=0.867, val_f1=0.860, train_loss=0.0166, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 54.92it/s]
# Epoch 175: 100% 34/34 [00:03<00:00, 10.05it/s, v_num=ub52, val_loss=0.632, val_acc=0.860, val_f1=0.852, train_loss=0.0231, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.30it/s]
# Epoch 176: 100% 34/34 [00:03<00:00, 10.14it/s, v_num=ub52, val_loss=0.610, val_acc=0.869, val_f1=0.862, train_loss=0.0179, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.58it/s]
# Epoch 177: 100% 34/34 [00:03<00:00, 10.15it/s, v_num=ub52, val_loss=0.595, val_acc=0.875, val_f1=0.868, train_loss=0.0201, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.40it/s]
# Epoch 178: 100% 34/34 [00:03<00:00, 10.12it/s, v_num=ub52, val_loss=0.573, val_acc=0.871, val_f1=0.864, train_loss=0.0189, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.84it/s]
# Epoch 179: 100% 34/34 [00:03<00:00, 10.08it/s, v_num=ub52, val_loss=0.595, val_acc=0.869, val_f1=0.862, train_loss=0.0207, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.20it/s]
# Epoch 180: 100% 34/34 [00:03<00:00, 10.08it/s, v_num=ub52, val_loss=0.588, val_acc=0.875, val_f1=0.868, train_loss=0.016, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.60it/s]
# Epoch 181: 100% 34/34 [00:03<00:00, 10.09it/s, v_num=ub52, val_loss=0.585, val_acc=0.871, val_f1=0.864, train_loss=0.0137, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.83it/s]
# Epoch 182: 100% 34/34 [00:03<00:00, 10.03it/s, v_num=ub52, val_loss=0.594, val_acc=0.876, val_f1=0.870, train_loss=0.0219, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.70it/s]
# Epoch 183: 100% 34/34 [00:03<00:00, 10.03it/s, v_num=ub52, val_loss=0.624, val_acc=0.869, val_f1=0.862, train_loss=0.0286, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.91it/s]
# Epoch 184: 100% 34/34 [00:03<00:00, 10.08it/s, v_num=ub52, val_loss=0.594, val_acc=0.875, val_f1=0.869, train_loss=0.0204, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.10it/s]
# Epoch 185: 100% 34/34 [00:03<00:00, 10.12it/s, v_num=ub52, val_loss=0.588, val_acc=0.876, val_f1=0.870, train_loss=0.0168, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.23it/s]
# Epoch 186: 100% 34/34 [00:03<00:00, 10.03it/s, v_num=ub52, val_loss=0.596, val_acc=0.873, val_f1=0.866, train_loss=0.0275, train_acc=0.992, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.84it/s]
# Epoch 187: 100% 34/34 [00:03<00:00, 10.00it/s, v_num=ub52, val_loss=0.623, val_acc=0.856, val_f1=0.847, train_loss=0.0213, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.70it/s]
# Epoch 188: 100% 34/34 [00:03<00:00, 10.08it/s, v_num=ub52, val_loss=0.608, val_acc=0.873, val_f1=0.867, train_loss=0.0195, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.69it/s]
# Epoch 189: 100% 34/34 [00:03<00:00, 10.10it/s, v_num=ub52, val_loss=0.612, val_acc=0.873, val_f1=0.866, train_loss=0.0197, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.11it/s]
# Epoch 190: 100% 34/34 [00:03<00:00,  9.97it/s, v_num=ub52, val_loss=0.598, val_acc=0.878, val_f1=0.872, train_loss=0.0203, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.77it/s]
# Epoch 191: 100% 34/34 [00:03<00:00, 10.11it/s, v_num=ub52, val_loss=0.595, val_acc=0.873, val_f1=0.867, train_loss=0.0252, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.15it/s]
# Epoch 192: 100% 34/34 [00:03<00:00, 10.09it/s, v_num=ub52, val_loss=0.628, val_acc=0.862, val_f1=0.854, train_loss=0.0163, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.14it/s]
# Epoch 193: 100% 34/34 [00:03<00:00, 10.09it/s, v_num=ub52, val_loss=0.594, val_acc=0.873, val_f1=0.867, train_loss=0.022, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.07it/s]
# Epoch 194: 100% 34/34 [00:03<00:00, 10.01it/s, v_num=ub52, val_loss=0.616, val_acc=0.862, val_f1=0.854, train_loss=0.0218, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.86it/s]
# Epoch 195: 100% 34/34 [00:03<00:00, 10.09it/s, v_num=ub52, val_loss=0.606, val_acc=0.869, val_f1=0.862, train_loss=0.0167, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.65it/s]
# Epoch 196: 100% 34/34 [00:03<00:00, 10.10it/s, v_num=ub52, val_loss=0.641, val_acc=0.856, val_f1=0.847, train_loss=0.0184, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.93it/s]
# Epoch 197: 100% 34/34 [00:03<00:00, 10.02it/s, v_num=ub52, val_loss=0.615, val_acc=0.869, val_f1=0.862, train_loss=0.0173, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.23it/s]
# Epoch 198: 100% 34/34 [00:03<00:00, 10.00it/s, v_num=ub52, val_loss=0.611, val_acc=0.875, val_f1=0.868, train_loss=0.0214, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.22it/s]
# Epoch 199: 100% 34/34 [00:03<00:00, 10.11it/s, v_num=ub52, val_loss=0.613, val_acc=0.865, val_f1=0.858, train_loss=0.0262, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 46.71it/s]
# Epoch 199: 100% 34/34 [00:03<00:00,  9.54it/s, v_num=ub52, val_loss=0.608, val_acc=0.873, val_f1=0.866, train_loss=0.0208, train_acc=0.993, train_f1=0.993]`Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199: 100% 34/34 [00:03<00:00,  9.53it/s, v_num=ub52, val_loss=0.608, val_acc=0.873, val_f1=0.866, train_loss=0.0208, train_acc=0.993, train_f1=0.993]
# Loading best model weights from: ./save/logs_FATIG_Deformer/sub52/checkpoints/epoch=101-step=3468.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 1/1 [00:00<00:00, 23.89it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7377049326896667     │
# │          test_f1          │    0.7296960353851318     │
# │         test_loss         │    1.3307048082351685     │
# └───────────────────────────┴───────────────────────────┘
# Data has been logged to ./save/logs_FATIG_Deformer/sub52/result.csv

# %%
# !mkdir -p /content/drive/MyDrive/MVA/time-series-project/final_results/baseline

# !cp -r /content/EEG-Deformer/EEG-Deformer/save/logs_FATIG_Deformer/ /content/drive/MyDrive/MVA/time-series-project/final_results/baseline/

# %% [markdown]
# # DREAMER Experiment

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import Dataset, Dataloader
import numpy as np
from tqdm import tqdm
import os
import json
from datetime import datetime
import sys
import scipy.io as sio
from sklearn.preprocessing import StandardScaler

from EEGDeformer import Deformer

# %% [markdown]
# ### Application of EEG-Deformer on DREAMER database

# %%
class DREAMERDataset(Dataset):

    def __init__(self, data_path, task='valence', segment_length=384, overlap=0.5,
                 split='train', test_size=0.2, random_state=42, normalize=True,
                 binary_classification=True, threshold=3):

        self.data_path = data_path
        self.task = task
        self.segment_length = segment_length
        self.overlap = overlap
        self.normalize = normalize
        self.binary_classification = binary_classification
        self.threshold = threshold

        self.data, self.labels = self._load_and_process_data()

        X_train, X_test, y_train, y_test = train_test_split(
            self.data, self.labels, test_size=test_size,
            random_state=random_state, stratify=self.labels
        )

        if split == 'train':
            self.data = X_train
            self.labels = y_train
        else:
            self.data = X_test
            self.labels = y_test

        if self.normalize:
            self._normalize_data()

    def _load_and_process_data(self):
        print(f"Loading DREAMER dataset from {self.data_path}...")

        mat_data = sio.loadmat(self.data_path)
        dreamer = mat_data['DREAMER']

        all_segments = []
        all_labels = []

        data_field = dreamer['Data'][0, 0]
        num_subjects = data_field.shape[1]

        print(f"Processing {num_subjects} subjects...")

        for subject_idx in range(num_subjects):
            subject_data = data_field[0, subject_idx]

            eeg_struct = subject_data['EEG'][0, 0]

            if self.task == 'valence':
                scores = subject_data['ScoreValence'][0, 0].flatten()
            elif self.task == 'arousal':
                scores = subject_data['ScoreArousal'][0, 0].flatten()
            elif self.task == 'dominance':
                scores = subject_data['ScoreDominance'][0, 0].flatten()
            else:
                raise ValueError(f"Unknown task: {self.task}")

            stimuli_data = eeg_struct['stimuli'][0, 0]
            num_videos = stimuli_data.shape[0]

            for video_idx in range(num_videos):
                eeg_recording = stimuli_data[video_idx, 0]

                if eeg_recording.size == 0:
                    continue

                label = scores[video_idx]

                if self.binary_classification:
                    label = 1 if label > self.threshold else 0
                else:
                    label = int(label) - 1

                segments = self._segment_signal(eeg_recording)

                for segment in segments:
                    all_segments.append(segment)
                    all_labels.append(label)

        print(f"Generated {len(all_segments)} segments")
        print(f"Label distribution: {np.bincount(all_labels)}")

        return np.array(all_segments), np.array(all_labels)

    def _segment_signal(self, signal):
        num_samples = signal.shape[0]
        step_size = int(self.segment_length * (1 - self.overlap))

        segments = []
        start = 0

        while start + self.segment_length <= num_samples:
            segment = signal[start:start + self.segment_length, :]
            segment = segment.T
            segments.append(segment)
            start += step_size

        return segments

    def _normalize_data(self):
        original_shape = self.data.shape
        reshaped = self.data.reshape(-1, self.data.shape[-1])

        scaler = StandardScaler()
        normalized = scaler.fit_transform(reshaped.T).T

        self.data = normalized.reshape(original_shape)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = torch.FloatTensor(self.data[idx])
        label = torch.LongTensor([self.labels[idx]])[0]

        return data, label

# %%
def get_dreamer_dataloaders(data_path, task='valence', segment_length=384,
                            batch_size=32, num_workers=4, **kwargs):
    """
    Create train and test dataloaders for DREAMER dataset
    """

    train_dataset = DREAMERDataset(
        data_path=data_path,
        task=task,
        segment_length=segment_length,
        split='train',
        **kwargs
    )

    test_dataset = DREAMERDataset(
        data_path=data_path,
        task=task,
        segment_length=segment_length,
        split='test',
        **kwargs
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    return train_loader, test_loader

# %%
class EEGDeformerTrainer:
    """Trainer class for EEGDeformer on DREAMER dataset"""

    def __init__(self, config):
        self.config = config
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        print(f"Using device: {self.device}")

        self.train_loader, self.test_loader = get_dreamer_dataloaders(
            data_path=config['data_path'],
            task=config['task'],
            segment_length=config['segment_length'],
            batch_size=config['batch_size'],
            overlap=config.get('overlap', 0.5),
            test_size=config.get('test_size', 0.2),
            random_state=config.get('random_state', 42),
            normalize=config.get('normalize', True),
            binary_classification=config.get('binary_classification', True),
            threshold=config.get('threshold', 3)
        )

        self.model = Deformer(
            num_chan=14,
            num_time=config['segment_length'],
            temporal_kernel=config.get('temporal_kernel', 13),
            num_kernel=config.get('num_kernel', 64),
            num_classes=config['num_classes'],
            depth=config.get('depth', 4),
            heads=config.get('heads', 16),
            mlp_dim=config.get('mlp_dim', 16),
            dim_head=config.get('dim_head', 16),
            dropout=config.get('dropout', 0.5)
        ).to(self.device)

        print(f"\nModel parameters: {sum(p.numel() for p in self.model.parameters()):,}")

        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = optim.AdamW(
            self.model.parameters(),
            lr=config['learning_rate'],
            weight_decay=config.get('weight_decay', 0.01)
        )

        self.scheduler = CosineAnnealingLR(
            self.optimizer,
            T_max=config['num_epochs'],
            eta_min=config.get('min_lr', 1e-6)
        )
        self.best_acc = 0.0
        self.history = {
            'train_loss': [],
            'train_acc': [],
            'test_loss': [],
            'test_acc': []
        }

        self.save_dir = config.get('save_dir', 'checkpoints')
        os.makedirs(self.save_dir, exist_ok=True)

    def train_epoch(self):
        """Train for one epoch"""
        self.model.train()

        train_loss = 0.0
        correct = 0
        total = 0

        pbar = tqdm(self.train_loader, desc='Training')
        for data, labels in pbar:
            data, labels = data.to(self.device), labels.to(self.device)

            self.optimizer.zero_grad()
            outputs = self.model(data)
            loss = self.criterion(outputs, labels)

            loss.backward()
            self.optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            pbar.set_postfix({
                'loss': f'{loss.item():.4f}',
                'acc': f'{100.*correct/total:.2f}%'
            })

        avg_loss = train_loss / len(self.train_loader)
        accuracy = 100. * correct / total

        return avg_loss, accuracy

    def validate(self):
        """Validate the model"""
        self.model.eval()

        test_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            pbar = tqdm(self.test_loader, desc='Validation')
            for data, labels in pbar:
                data, labels = data.to(self.device), labels.to(self.device)

                outputs = self.model(data)
                loss = self.criterion(outputs, labels)

                test_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

                pbar.set_postfix({
                    'loss': f'{loss.item():.4f}',
                    'acc': f'{100.*correct/total:.2f}%'
                })

        avg_loss = test_loss / len(self.test_loader)
        accuracy = 100. * correct / total

        return avg_loss, accuracy

    def train(self):
        """Full training loop"""
        print(f"\n{'='*60}")
        print(f"Starting training for task: {self.config['task'].upper()}")
        print(f"{'='*60}\n")

        for epoch in range(self.config['num_epochs']):
            print(f"\nEpoch {epoch+1}/{self.config['num_epochs']}")
            print('-' * 60)

            train_loss, train_acc = self.train_epoch()

            test_loss, test_acc = self.validate()

            self.scheduler.step()

            self.history['train_loss'].append(train_loss)
            self.history['train_acc'].append(train_acc)
            self.history['test_loss'].append(test_loss)
            self.history['test_acc'].append(test_acc)

            print(f"\nEpoch {epoch+1} Results:")
            print(f"  Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
            print(f"  Test Loss:  {test_loss:.4f} | Test Acc:  {test_acc:.2f}%")
            print(f"  Learning Rate: {self.optimizer.param_groups[0]['lr']:.6f}")

            if test_acc > self.best_acc:
                self.best_acc = test_acc
                self.save_checkpoint(epoch, is_best=True)
                print(f"  ✓ New best accuracy: {test_acc:.2f}%")

            if (epoch + 1) % 10 == 0:
                self.save_checkpoint(epoch, is_best=False)

        print(f"\n{'='*60}")
        print(f"Training completed!")
        print(f"Best test accuracy: {self.best_acc:.2f}%")
        print(f"{'='*60}\n")

        self.save_results()

    def save_checkpoint(self, epoch, is_best=False):
        """Save model checkpoint"""
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'scheduler_state_dict': self.scheduler.state_dict(),
            'best_acc': self.best_acc,
            'config': self.config,
            'history': self.history
        }

        if is_best:
            path = os.path.join(self.save_dir, f'best_model_{self.config["task"]}.pth')
            torch.save(checkpoint, path)
        else:
            path = os.path.join(self.save_dir, f'checkpoint_epoch_{epoch+1}.pth')
            torch.save(checkpoint, path)

    def save_results(self):
        """Save training results and config"""
        results = {
            'config': self.config,
            'best_accuracy': self.best_acc,
            'history': self.history,
            'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }

        path = os.path.join(self.save_dir, f'results_{self.config["task"]}.json')
        with open(path, 'w') as f:
            json.dump(results, f, indent=4)

        print(f"Results saved to {path}")

# %%
config = {
    # Data parameters
    'data_path': 'DREAMER.mat',
    'task': 'dominance',  # Alternate between 'valence', 'arousal', 'dominance'
    'segment_length': 384,  # 3 seconds at 128 Hz (DREAMER sampling rate)
    'overlap': 0.5,
    'test_size': 0.2,
    'random_state': 42,
    'normalize': True,
    'binary_classification': True,  # High/Low
    'threshold': 3,  # For binary classification

    # Model parameters
    'num_classes': 2,  # Binary classification
    'temporal_kernel': 13,
    'num_kernel': 64,
    'depth': 4,
    'heads': 16,
    'mlp_dim': 16,
    'dim_head': 16,
    'dropout': 0.5,

    # Training parameters
    'batch_size': 32,
    'num_epochs': 100,
    'learning_rate': 1e-3,
    'weight_decay': 0.01,
    'min_lr': 1e-6,

    'save_dir': 'checkpoints/dreamer',
    }

trainer = EEGDeformerTrainer(config)
trainer.train()
# Out:
# Using device: cuda
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [26166 30414]
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [26166 30414]
#
# Model parameters: 477,394
#
# ============================================================
# Starting training for task: DOMINANCE
# ============================================================
#
#
# Epoch 1/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 52.10it/s, loss=0.5832, acc=56.39%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.09it/s, loss=0.5029, acc=64.39%]
# Epoch 1 Results:
#   Train Loss: 0.6912 | Train Acc: 56.39%
#   Test Loss:  0.6208 | Test Acc:  64.39%
#   Learning Rate: 0.001000
#   ✓ New best accuracy: 64.39%
#
# Epoch 2/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.67it/s, loss=0.8346, acc=62.22%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 130.67it/s, loss=0.4683, acc=64.28%]
# Epoch 2 Results:
#   Train Loss: 0.6456 | Train Acc: 62.22%
#   Test Loss:  0.6158 | Test Acc:  64.28%
#   Learning Rate: 0.000999
#
# Epoch 3/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.46it/s, loss=0.5942, acc=64.38%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.69it/s, loss=0.4085, acc=66.99%]
# Epoch 3 Results:
#   Train Loss: 0.6209 | Train Acc: 64.38%
#   Test Loss:  0.6027 | Test Acc:  66.99%
#   Learning Rate: 0.000998
#   ✓ New best accuracy: 66.99%
#
# Epoch 4/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.07it/s, loss=0.4745, acc=65.83%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 141.18it/s, loss=0.3835, acc=67.99%]
# Epoch 4 Results:
#   Train Loss: 0.6068 | Train Acc: 65.83%
#   Test Loss:  0.5794 | Test Acc:  67.99%
#   Learning Rate: 0.000996
#   ✓ New best accuracy: 67.99%
#
# Epoch 5/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.63it/s, loss=0.6747, acc=66.70%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.35it/s, loss=0.3908, acc=67.44%]
# Epoch 5 Results:
#   Train Loss: 0.5962 | Train Acc: 66.70%
#   Test Loss:  0.5897 | Test Acc:  67.44%
#   Learning Rate: 0.000994
#
# Epoch 6/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.88it/s, loss=0.4464, acc=67.13%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.81it/s, loss=0.3929, acc=69.29%]
# Epoch 6 Results:
#   Train Loss: 0.5913 | Train Acc: 67.13%
#   Test Loss:  0.5613 | Test Acc:  69.29%
#   Learning Rate: 0.000991
#   ✓ New best accuracy: 69.29%
#
# Epoch 7/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.22it/s, loss=0.5032, acc=68.09%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.52it/s, loss=0.3944, acc=68.89%]
# Epoch 7 Results:
#   Train Loss: 0.5830 | Train Acc: 68.09%
#   Test Loss:  0.5706 | Test Acc:  68.89%
#   Learning Rate: 0.000988
#
# Epoch 8/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.92it/s, loss=0.5384, acc=68.47%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.37it/s, loss=0.3275, acc=69.41%]
# Epoch 8 Results:
#   Train Loss: 0.5755 | Train Acc: 68.47%
#   Test Loss:  0.5688 | Test Acc:  69.41%
#   Learning Rate: 0.000984
#   ✓ New best accuracy: 69.41%
#
# Epoch 9/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.68it/s, loss=0.3832, acc=68.84%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.97it/s, loss=0.4375, acc=68.15%]
# Epoch 9 Results:
#   Train Loss: 0.5741 | Train Acc: 68.84%
#   Test Loss:  0.5797 | Test Acc:  68.15%
#   Learning Rate: 0.000980
#
# Epoch 10/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.92it/s, loss=0.6404, acc=69.66%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.89it/s, loss=0.4621, acc=68.17%]
# Epoch 10 Results:
#   Train Loss: 0.5633 | Train Acc: 69.66%
#   Test Loss:  0.5803 | Test Acc:  68.17%
#   Learning Rate: 0.000976
#
# Epoch 11/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.12it/s, loss=0.5199, acc=69.89%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.59it/s, loss=0.3208, acc=70.55%]
# Epoch 11 Results:
#   Train Loss: 0.5601 | Train Acc: 69.89%
#   Test Loss:  0.5497 | Test Acc:  70.55%
#   Learning Rate: 0.000970
#   ✓ New best accuracy: 70.55%
#
# Epoch 12/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.31it/s, loss=0.5526, acc=70.31%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.04it/s, loss=0.3712, acc=69.95%]
# Epoch 12 Results:
#   Train Loss: 0.5567 | Train Acc: 70.31%
#   Test Loss:  0.5692 | Test Acc:  69.95%
#   Learning Rate: 0.000965
#
# Epoch 13/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.79it/s, loss=0.4295, acc=70.63%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 133.09it/s, loss=0.3990, acc=68.64%]
# Epoch 13 Results:
#   Train Loss: 0.5495 | Train Acc: 70.63%
#   Test Loss:  0.5939 | Test Acc:  68.64%
#   Learning Rate: 0.000959
#
# Epoch 14/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.79it/s, loss=0.4707, acc=70.87%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.29it/s, loss=0.2663, acc=71.36%]
# Epoch 14 Results:
#   Train Loss: 0.5470 | Train Acc: 70.87%
#   Test Loss:  0.5434 | Test Acc:  71.36%
#   Learning Rate: 0.000952
#   ✓ New best accuracy: 71.36%
#
# Epoch 15/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.15it/s, loss=0.5380, acc=70.95%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.96it/s, loss=0.3725, acc=70.52%]
# Epoch 15 Results:
#   Train Loss: 0.5447 | Train Acc: 70.95%
#   Test Loss:  0.5727 | Test Acc:  70.52%
#   Learning Rate: 0.000946
#
# Epoch 16/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.43it/s, loss=0.3439, acc=71.38%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.42it/s, loss=0.3602, acc=71.26%]
# Epoch 16 Results:
#   Train Loss: 0.5430 | Train Acc: 71.38%
#   Test Loss:  0.5424 | Test Acc:  71.26%
#   Learning Rate: 0.000938
#
# Epoch 17/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.65it/s, loss=0.7514, acc=72.01%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.77it/s, loss=0.2785, acc=68.90%]
# Epoch 17 Results:
#   Train Loss: 0.5357 | Train Acc: 72.01%
#   Test Loss:  0.5940 | Test Acc:  68.90%
#   Learning Rate: 0.000930
#
# Epoch 18/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.89it/s, loss=0.4234, acc=71.97%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 132.26it/s, loss=0.4618, acc=71.86%]
# Epoch 18 Results:
#   Train Loss: 0.5329 | Train Acc: 71.97%
#   Test Loss:  0.5358 | Test Acc:  71.86%
#   Learning Rate: 0.000922
#   ✓ New best accuracy: 71.86%
#
# Epoch 19/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.41it/s, loss=0.5525, acc=72.43%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.10it/s, loss=0.3543, acc=71.32%]
# Epoch 19 Results:
#   Train Loss: 0.5304 | Train Acc: 72.43%
#   Test Loss:  0.5441 | Test Acc:  71.32%
#   Learning Rate: 0.000914
#
# Epoch 20/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.34it/s, loss=0.6395, acc=72.66%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 133.60it/s, loss=0.3122, acc=72.16%]
# Epoch 20 Results:
#   Train Loss: 0.5241 | Train Acc: 72.66%
#   Test Loss:  0.5295 | Test Acc:  72.16%
#   Learning Rate: 0.000905
#   ✓ New best accuracy: 72.16%
#
# Epoch 21/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 55.92it/s, loss=0.6614, acc=73.10%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 131.17it/s, loss=0.4611, acc=70.93%]
# Epoch 21 Results:
#   Train Loss: 0.5208 | Train Acc: 73.10%
#   Test Loss:  0.5550 | Test Acc:  70.93%
#   Learning Rate: 0.000895
#
# Epoch 22/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 54.83it/s, loss=0.6162, acc=73.32%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 124.53it/s, loss=0.3289, acc=71.77%]
# Epoch 22 Results:
#   Train Loss: 0.5163 | Train Acc: 73.32%
#   Test Loss:  0.5382 | Test Acc:  71.77%
#   Learning Rate: 0.000885
#
# Epoch 23/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 54.54it/s, loss=0.6136, acc=73.74%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.37it/s, loss=0.2899, acc=72.43%]
# Epoch 23 Results:
#   Train Loss: 0.5124 | Train Acc: 73.74%
#   Test Loss:  0.5272 | Test Acc:  72.43%
#   Learning Rate: 0.000875
#   ✓ New best accuracy: 72.43%
#
# Epoch 24/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 52.29it/s, loss=0.6772, acc=73.91%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 126.76it/s, loss=0.3290, acc=73.00%]
# Epoch 24 Results:
#   Train Loss: 0.5110 | Train Acc: 73.91%
#   Test Loss:  0.5198 | Test Acc:  73.00%
#   Learning Rate: 0.000865
#   ✓ New best accuracy: 73.00%
#
# Epoch 25/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.82it/s, loss=0.4657, acc=73.79%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 128.05it/s, loss=0.3614, acc=73.13%]
# Epoch 25 Results:
#   Train Loss: 0.5088 | Train Acc: 73.79%
#   Test Loss:  0.5138 | Test Acc:  73.13%
#   Learning Rate: 0.000854
#   ✓ New best accuracy: 73.13%
#
# Epoch 26/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.97it/s, loss=0.5104, acc=74.53%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 121.85it/s, loss=0.2930, acc=72.93%]
# Epoch 26 Results:
#   Train Loss: 0.5008 | Train Acc: 74.53%
#   Test Loss:  0.5233 | Test Acc:  72.93%
#   Learning Rate: 0.000842
#
# Epoch 27/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.66it/s, loss=0.4600, acc=74.41%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 129.07it/s, loss=0.3810, acc=71.31%]
# Epoch 27 Results:
#   Train Loss: 0.4997 | Train Acc: 74.41%
#   Test Loss:  0.5647 | Test Acc:  71.31%
#   Learning Rate: 0.000831
#
# Epoch 28/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:28<00:00, 50.52it/s, loss=0.4620, acc=74.72%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 126.75it/s, loss=0.3139, acc=73.59%]
# Epoch 28 Results:
#   Train Loss: 0.4959 | Train Acc: 74.72%
#   Test Loss:  0.5192 | Test Acc:  73.59%
#   Learning Rate: 0.000819
#   ✓ New best accuracy: 73.59%
#
# Epoch 29/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.83it/s, loss=0.4895, acc=75.08%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 127.56it/s, loss=0.2746, acc=73.14%]
# Epoch 29 Results:
#   Train Loss: 0.4919 | Train Acc: 75.08%
#   Test Loss:  0.5136 | Test Acc:  73.14%
#   Learning Rate: 0.000807
#
# Epoch 30/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 51.17it/s, loss=0.3227, acc=75.41%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 126.35it/s, loss=0.2820, acc=71.95%]
# Epoch 30 Results:
#   Train Loss: 0.4891 | Train Acc: 75.41%
#   Test Loss:  0.5425 | Test Acc:  71.95%
#   Learning Rate: 0.000794
#
# Epoch 31/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 51.26it/s, loss=0.3660, acc=76.28%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 121.76it/s, loss=0.1965, acc=72.02%]
# Epoch 31 Results:
#   Train Loss: 0.4801 | Train Acc: 76.28%
#   Test Loss:  0.5510 | Test Acc:  72.02%
#   Learning Rate: 0.000781
#
# Epoch 32/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.93it/s, loss=0.6912, acc=76.39%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 130.10it/s, loss=0.3429, acc=72.70%]
# Epoch 32 Results:
#   Train Loss: 0.4764 | Train Acc: 76.39%
#   Test Loss:  0.5349 | Test Acc:  72.70%
#   Learning Rate: 0.000768
#
# Epoch 33/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:28<00:00, 50.42it/s, loss=0.3933, acc=77.12%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 121.57it/s, loss=0.3055, acc=71.77%]
# Epoch 33 Results:
#   Train Loss: 0.4680 | Train Acc: 77.12%
#   Test Loss:  0.5510 | Test Acc:  71.77%
#   Learning Rate: 0.000755
#
# Epoch 34/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 51.16it/s, loss=0.6070, acc=77.45%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 120.94it/s, loss=0.2556, acc=73.01%]
# Epoch 34 Results:
#   Train Loss: 0.4616 | Train Acc: 77.45%
#   Test Loss:  0.5225 | Test Acc:  73.01%
#   Learning Rate: 0.000741
#
# Epoch 35/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 51.05it/s, loss=0.3610, acc=78.09%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 128.63it/s, loss=0.2537, acc=72.22%]
# Epoch 35 Results:
#   Train Loss: 0.4557 | Train Acc: 78.09%
#   Test Loss:  0.5577 | Test Acc:  72.22%
#   Learning Rate: 0.000727
#
# Epoch 36/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.84it/s, loss=0.3244, acc=78.54%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 123.67it/s, loss=0.3442, acc=70.71%]
# Epoch 36 Results:
#   Train Loss: 0.4484 | Train Acc: 78.54%
#   Test Loss:  0.6044 | Test Acc:  70.71%
#   Learning Rate: 0.000713
#
# Epoch 37/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.94it/s, loss=0.7110, acc=79.01%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 128.16it/s, loss=0.2342, acc=71.91%]
# Epoch 37 Results:
#   Train Loss: 0.4381 | Train Acc: 79.01%
#   Test Loss:  0.5852 | Test Acc:  71.91%
#   Learning Rate: 0.000699
#
# Epoch 38/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 50.96it/s, loss=0.5158, acc=79.85%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 124.47it/s, loss=0.3110, acc=71.57%]
# Epoch 38 Results:
#   Train Loss: 0.4277 | Train Acc: 79.85%
#   Test Loss:  0.5844 | Test Acc:  71.57%
#   Learning Rate: 0.000684
#
# Epoch 39/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 51.04it/s, loss=0.5219, acc=80.44%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 127.05it/s, loss=0.3624, acc=72.18%]
# Epoch 39 Results:
#   Train Loss: 0.4165 | Train Acc: 80.44%
#   Test Loss:  0.6099 | Test Acc:  72.18%
#   Learning Rate: 0.000670
#
# Epoch 40/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:28<00:00, 50.46it/s, loss=0.3499, acc=81.13%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 131.11it/s, loss=0.3734, acc=71.36%]
# Epoch 40 Results:
#   Train Loss: 0.4078 | Train Acc: 81.13%
#   Test Loss:  0.6267 | Test Acc:  71.36%
#   Learning Rate: 0.000655
#
# Epoch 41/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:27<00:00, 51.06it/s, loss=0.3139, acc=81.83%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 127.54it/s, loss=0.3021, acc=71.56%]
# Epoch 41 Results:
#   Train Loss: 0.3941 | Train Acc: 81.83%
#   Test Loss:  0.6181 | Test Acc:  71.56%
#   Learning Rate: 0.000640
#
# Epoch 42/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:26<00:00, 52.48it/s, loss=0.9662, acc=82.51%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.73it/s, loss=0.2915, acc=71.38%]
# Epoch 42 Results:
#   Train Loss: 0.3831 | Train Acc: 82.51%
#   Test Loss:  0.6323 | Test Acc:  71.38%
#   Learning Rate: 0.000625
#
# Epoch 43/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.24it/s, loss=0.6130, acc=83.14%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.05it/s, loss=0.4363, acc=70.08%]
# Epoch 43 Results:
#   Train Loss: 0.3717 | Train Acc: 83.14%
#   Test Loss:  0.7330 | Test Acc:  70.08%
#   Learning Rate: 0.000609
#
# Epoch 44/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 55.92it/s, loss=0.3897, acc=83.44%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.65it/s, loss=0.2568, acc=70.63%]
# Epoch 44 Results:
#   Train Loss: 0.3647 | Train Acc: 83.44%
#   Test Loss:  0.6766 | Test Acc:  70.63%
#   Learning Rate: 0.000594
#
# Epoch 45/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 54.68it/s, loss=0.3812, acc=84.59%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.89it/s, loss=0.3945, acc=69.56%]
# Epoch 45 Results:
#   Train Loss: 0.3469 | Train Acc: 84.59%
#   Test Loss:  0.7850 | Test Acc:  69.56%
#   Learning Rate: 0.000579
#
# Epoch 46/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.49it/s, loss=0.4406, acc=85.13%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.72it/s, loss=0.4378, acc=69.39%]
# Epoch 46 Results:
#   Train Loss: 0.3335 | Train Acc: 85.13%
#   Test Loss:  0.8307 | Test Acc:  69.39%
#   Learning Rate: 0.000563
#
# Epoch 47/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.49it/s, loss=0.2746, acc=85.69%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.73it/s, loss=0.4293, acc=69.21%]
# Epoch 47 Results:
#   Train Loss: 0.3229 | Train Acc: 85.69%
#   Test Loss:  0.8910 | Test Acc:  69.21%
#   Learning Rate: 0.000548
#
# Epoch 48/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.66it/s, loss=0.2596, acc=86.07%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.39it/s, loss=0.5237, acc=68.98%]
# Epoch 48 Results:
#   Train Loss: 0.3149 | Train Acc: 86.07%
#   Test Loss:  0.9537 | Test Acc:  68.98%
#   Learning Rate: 0.000532
#
# Epoch 49/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.44it/s, loss=0.4772, acc=86.71%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.19it/s, loss=0.6406, acc=68.65%]
# Epoch 49 Results:
#   Train Loss: 0.3039 | Train Acc: 86.71%
#   Test Loss:  0.9547 | Test Acc:  68.65%
#   Learning Rate: 0.000516
#
# Epoch 50/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.12it/s, loss=0.4760, acc=87.27%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.03it/s, loss=0.6946, acc=69.61%]
# Epoch 50 Results:
#   Train Loss: 0.2913 | Train Acc: 87.27%
#   Test Loss:  0.8822 | Test Acc:  69.61%
#   Learning Rate: 0.000501
#
# Epoch 51/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.22it/s, loss=0.3349, acc=87.99%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 132.97it/s, loss=0.9350, acc=68.66%]
# Epoch 51 Results:
#   Train Loss: 0.2765 | Train Acc: 87.99%
#   Test Loss:  1.1055 | Test Acc:  68.66%
#   Learning Rate: 0.000485
#
# Epoch 52/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.50it/s, loss=0.2832, acc=88.18%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.58it/s, loss=0.7410, acc=69.07%]
# Epoch 52 Results:
#   Train Loss: 0.2701 | Train Acc: 88.18%
#   Test Loss:  1.0145 | Test Acc:  69.07%
#   Learning Rate: 0.000469
#
# Epoch 53/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.43it/s, loss=0.1848, acc=88.93%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.87it/s, loss=0.8339, acc=69.14%]
# Epoch 53 Results:
#   Train Loss: 0.2585 | Train Acc: 88.93%
#   Test Loss:  0.9657 | Test Acc:  69.14%
#   Learning Rate: 0.000453
#
# Epoch 54/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.62it/s, loss=0.4715, acc=89.45%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.96it/s, loss=0.7243, acc=68.99%]
# Epoch 54 Results:
#   Train Loss: 0.2465 | Train Acc: 89.45%
#   Test Loss:  1.0098 | Test Acc:  68.99%
#   Learning Rate: 0.000438
#
# Epoch 55/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.93it/s, loss=0.2324, acc=89.73%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.38it/s, loss=0.6554, acc=67.61%]
# Epoch 55 Results:
#   Train Loss: 0.2404 | Train Acc: 89.73%
#   Test Loss:  1.1967 | Test Acc:  67.61%
#   Learning Rate: 0.000422
#
# Epoch 56/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.91it/s, loss=0.2778, acc=90.19%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.23it/s, loss=0.8396, acc=68.18%]
# Epoch 56 Results:
#   Train Loss: 0.2293 | Train Acc: 90.19%
#   Test Loss:  1.2269 | Test Acc:  68.18%
#   Learning Rate: 0.000407
#
# Epoch 57/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.54it/s, loss=0.2423, acc=90.82%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.53it/s, loss=0.8654, acc=68.12%]
# Epoch 57 Results:
#   Train Loss: 0.2181 | Train Acc: 90.82%
#   Test Loss:  1.1975 | Test Acc:  68.12%
#   Learning Rate: 0.000392
#
# Epoch 58/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.38it/s, loss=0.3228, acc=91.36%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.44it/s, loss=0.9413, acc=67.66%]
# Epoch 58 Results:
#   Train Loss: 0.2064 | Train Acc: 91.36%
#   Test Loss:  1.3229 | Test Acc:  67.66%
#   Learning Rate: 0.000376
#
# Epoch 59/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.71it/s, loss=0.1869, acc=91.33%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.57it/s, loss=0.9011, acc=68.09%]
# Epoch 59 Results:
#   Train Loss: 0.2046 | Train Acc: 91.33%
#   Test Loss:  1.3022 | Test Acc:  68.09%
#   Learning Rate: 0.000361
#
# Epoch 60/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.62it/s, loss=0.1472, acc=92.08%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.06it/s, loss=1.0836, acc=68.34%]
# Epoch 60 Results:
#   Train Loss: 0.1911 | Train Acc: 92.08%
#   Test Loss:  1.2086 | Test Acc:  68.34%
#   Learning Rate: 0.000346
#
# Epoch 61/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.72it/s, loss=0.0787, acc=92.62%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.06it/s, loss=0.9965, acc=67.92%]
# Epoch 61 Results:
#   Train Loss: 0.1794 | Train Acc: 92.62%
#   Test Loss:  1.4089 | Test Acc:  67.92%
#   Learning Rate: 0.000331
#
# Epoch 62/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.33it/s, loss=0.2976, acc=92.84%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 131.34it/s, loss=1.2234, acc=67.27%]
# Epoch 62 Results:
#   Train Loss: 0.1727 | Train Acc: 92.84%
#   Test Loss:  1.4454 | Test Acc:  67.27%
#   Learning Rate: 0.000317
#
# Epoch 63/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.53it/s, loss=0.3129, acc=93.10%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.95it/s, loss=1.0926, acc=67.30%]
# Epoch 63 Results:
#   Train Loss: 0.1670 | Train Acc: 93.10%
#   Test Loss:  1.3541 | Test Acc:  67.30%
#   Learning Rate: 0.000302
#
# Epoch 64/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.69it/s, loss=0.2245, acc=93.62%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 131.67it/s, loss=1.2799, acc=67.12%]
# Epoch 64 Results:
#   Train Loss: 0.1557 | Train Acc: 93.62%
#   Test Loss:  1.5875 | Test Acc:  67.12%
#   Learning Rate: 0.000288
#
# Epoch 65/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.59it/s, loss=0.2027, acc=94.01%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 133.28it/s, loss=1.4967, acc=67.21%]
# Epoch 65 Results:
#   Train Loss: 0.1478 | Train Acc: 94.01%
#   Test Loss:  1.6423 | Test Acc:  67.21%
#   Learning Rate: 0.000274
#
# Epoch 66/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.61it/s, loss=0.0957, acc=94.10%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.86it/s, loss=1.0794, acc=66.76%]
# Epoch 66 Results:
#   Train Loss: 0.1444 | Train Acc: 94.10%
#   Test Loss:  1.6923 | Test Acc:  66.76%
#   Learning Rate: 0.000260
#
# Epoch 67/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.62it/s, loss=0.0396, acc=94.29%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 131.78it/s, loss=1.3264, acc=66.97%]
# Epoch 67 Results:
#   Train Loss: 0.1402 | Train Acc: 94.29%
#   Test Loss:  1.6328 | Test Acc:  66.97%
#   Learning Rate: 0.000246
#
# Epoch 68/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.91it/s, loss=0.2341, acc=94.74%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.72it/s, loss=1.3417, acc=67.43%]
# Epoch 68 Results:
#   Train Loss: 0.1321 | Train Acc: 94.74%
#   Test Loss:  1.7444 | Test Acc:  67.43%
#   Learning Rate: 0.000233
#
# Epoch 69/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.51it/s, loss=0.1500, acc=95.18%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 141.00it/s, loss=1.1178, acc=67.06%]
# Epoch 69 Results:
#   Train Loss: 0.1229 | Train Acc: 95.18%
#   Test Loss:  1.6932 | Test Acc:  67.06%
#   Learning Rate: 0.000220
#
# Epoch 70/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.44it/s, loss=0.0381, acc=95.01%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.58it/s, loss=1.3297, acc=67.62%]
# Epoch 70 Results:
#   Train Loss: 0.1217 | Train Acc: 95.01%
#   Test Loss:  1.7994 | Test Acc:  67.62%
#   Learning Rate: 0.000207
#
# Epoch 71/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.88it/s, loss=0.1000, acc=95.48%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.93it/s, loss=1.4018, acc=66.98%]
# Epoch 71 Results:
#   Train Loss: 0.1137 | Train Acc: 95.48%
#   Test Loss:  1.9175 | Test Acc:  66.98%
#   Learning Rate: 0.000194
#
# Epoch 72/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.58it/s, loss=0.1519, acc=95.84%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.03it/s, loss=1.2502, acc=66.89%]
# Epoch 72 Results:
#   Train Loss: 0.1066 | Train Acc: 95.84%
#   Test Loss:  1.9231 | Test Acc:  66.89%
#   Learning Rate: 0.000182
#
# Epoch 73/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.08it/s, loss=0.3709, acc=95.98%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.33it/s, loss=1.2842, acc=66.67%]
# Epoch 73 Results:
#   Train Loss: 0.1017 | Train Acc: 95.98%
#   Test Loss:  2.0514 | Test Acc:  66.67%
#   Learning Rate: 0.000170
#
# Epoch 74/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.04it/s, loss=0.0713, acc=96.30%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.21it/s, loss=1.1199, acc=66.25%]
# Epoch 74 Results:
#   Train Loss: 0.0958 | Train Acc: 96.30%
#   Test Loss:  2.0520 | Test Acc:  66.25%
#   Learning Rate: 0.000159
#
# Epoch 75/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.28it/s, loss=0.0953, acc=96.47%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.18it/s, loss=1.3113, acc=66.72%]
# Epoch 75 Results:
#   Train Loss: 0.0925 | Train Acc: 96.47%
#   Test Loss:  2.0730 | Test Acc:  66.72%
#   Learning Rate: 0.000147
#
# Epoch 76/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.75it/s, loss=0.2025, acc=96.71%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.36it/s, loss=1.6346, acc=65.95%]
# Epoch 76 Results:
#   Train Loss: 0.0872 | Train Acc: 96.71%
#   Test Loss:  2.3083 | Test Acc:  65.95%
#   Learning Rate: 0.000136
#
# Epoch 77/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.32it/s, loss=0.2639, acc=96.86%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.09it/s, loss=1.7963, acc=66.59%]
# Epoch 77 Results:
#   Train Loss: 0.0804 | Train Acc: 96.86%
#   Test Loss:  2.2955 | Test Acc:  66.59%
#   Learning Rate: 0.000126
#
# Epoch 78/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.58it/s, loss=0.1347, acc=96.87%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.87it/s, loss=2.0847, acc=66.12%]
# Epoch 78 Results:
#   Train Loss: 0.0797 | Train Acc: 96.87%
#   Test Loss:  2.4764 | Test Acc:  66.12%
#   Learning Rate: 0.000116
#
# Epoch 79/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.78it/s, loss=0.0268, acc=97.07%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.02it/s, loss=2.0094, acc=66.42%]
# Epoch 79 Results:
#   Train Loss: 0.0765 | Train Acc: 97.07%
#   Test Loss:  2.3882 | Test Acc:  66.42%
#   Learning Rate: 0.000106
#
# Epoch 80/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.17it/s, loss=0.0425, acc=97.17%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.48it/s, loss=1.9645, acc=65.88%]
# Epoch 80 Results:
#   Train Loss: 0.0744 | Train Acc: 97.17%
#   Test Loss:  2.5324 | Test Acc:  65.88%
#   Learning Rate: 0.000096
#
# Epoch 81/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.86it/s, loss=0.0087, acc=97.36%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 140.13it/s, loss=2.0155, acc=66.49%]
# Epoch 81 Results:
#   Train Loss: 0.0698 | Train Acc: 97.36%
#   Test Loss:  2.5295 | Test Acc:  66.49%
#   Learning Rate: 0.000087
#
# Epoch 82/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.92it/s, loss=0.0646, acc=97.58%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.37it/s, loss=1.8927, acc=66.62%]
# Epoch 82 Results:
#   Train Loss: 0.0642 | Train Acc: 97.58%
#   Test Loss:  2.6242 | Test Acc:  66.62%
#   Learning Rate: 0.000079
#
# Epoch 83/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.63it/s, loss=0.0149, acc=97.76%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 134.38it/s, loss=2.1346, acc=66.17%]
# Epoch 83 Results:
#   Train Loss: 0.0604 | Train Acc: 97.76%
#   Test Loss:  2.6711 | Test Acc:  66.17%
#   Learning Rate: 0.000071
#
# Epoch 84/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 57.41it/s, loss=0.0255, acc=97.74%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 139.69it/s, loss=2.1650, acc=66.08%]
# Epoch 84 Results:
#   Train Loss: 0.0601 | Train Acc: 97.74%
#   Test Loss:  2.7455 | Test Acc:  66.08%
#   Learning Rate: 0.000063
#
# Epoch 85/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.47it/s, loss=0.0782, acc=97.90%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.80it/s, loss=2.4550, acc=66.00%]
# Epoch 85 Results:
#   Train Loss: 0.0566 | Train Acc: 97.90%
#   Test Loss:  2.8083 | Test Acc:  66.00%
#   Learning Rate: 0.000055
#
# Epoch 86/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.59it/s, loss=0.1160, acc=97.95%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.63it/s, loss=2.1166, acc=65.82%]
# Epoch 86 Results:
#   Train Loss: 0.0532 | Train Acc: 97.95%
#   Test Loss:  2.9200 | Test Acc:  65.82%
#   Learning Rate: 0.000049
#
# Epoch 87/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.73it/s, loss=0.0147, acc=98.15%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.92it/s, loss=2.3300, acc=65.46%]
# Epoch 87 Results:
#   Train Loss: 0.0516 | Train Acc: 98.15%
#   Test Loss:  2.9983 | Test Acc:  65.46%
#   Learning Rate: 0.000042
#
# Epoch 88/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.79it/s, loss=0.0071, acc=98.11%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.69it/s, loss=2.4275, acc=65.92%]
# Epoch 88 Results:
#   Train Loss: 0.0509 | Train Acc: 98.11%
#   Test Loss:  2.9324 | Test Acc:  65.92%
#   Learning Rate: 0.000036
#
# Epoch 89/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.80it/s, loss=0.0743, acc=98.25%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.74it/s, loss=2.0907, acc=66.08%]
# Epoch 89 Results:
#   Train Loss: 0.0481 | Train Acc: 98.25%
#   Test Loss:  2.9352 | Test Acc:  66.08%
#   Learning Rate: 0.000031
#
# Epoch 90/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.75it/s, loss=0.0410, acc=98.21%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.26it/s, loss=2.3133, acc=65.62%]
# Epoch 90 Results:
#   Train Loss: 0.0477 | Train Acc: 98.21%
#   Test Loss:  2.9620 | Test Acc:  65.62%
#   Learning Rate: 0.000025
#
# Epoch 91/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.72it/s, loss=0.1153, acc=98.40%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.44it/s, loss=2.4960, acc=65.72%]
# Epoch 91 Results:
#   Train Loss: 0.0456 | Train Acc: 98.40%
#   Test Loss:  3.0194 | Test Acc:  65.72%
#   Learning Rate: 0.000021
#
# Epoch 92/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.78it/s, loss=0.0528, acc=98.51%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.46it/s, loss=2.4097, acc=65.84%]
# Epoch 92 Results:
#   Train Loss: 0.0437 | Train Acc: 98.51%
#   Test Loss:  3.0771 | Test Acc:  65.84%
#   Learning Rate: 0.000017
#
# Epoch 93/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.63it/s, loss=0.0668, acc=98.53%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 133.75it/s, loss=2.5406, acc=65.69%]
# Epoch 93 Results:
#   Train Loss: 0.0420 | Train Acc: 98.53%
#   Test Loss:  3.1005 | Test Acc:  65.69%
#   Learning Rate: 0.000013
#
# Epoch 94/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.96it/s, loss=0.0846, acc=98.53%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.19it/s, loss=2.5525, acc=65.62%]
# Epoch 94 Results:
#   Train Loss: 0.0421 | Train Acc: 98.53%
#   Test Loss:  3.0703 | Test Acc:  65.62%
#   Learning Rate: 0.000010
#
# Epoch 95/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.97it/s, loss=0.0189, acc=98.59%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 139.07it/s, loss=2.5203, acc=65.76%]
# Epoch 95 Results:
#   Train Loss: 0.0409 | Train Acc: 98.59%
#   Test Loss:  3.1321 | Test Acc:  65.76%
#   Learning Rate: 0.000007
#
# Epoch 96/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.59it/s, loss=0.0072, acc=98.57%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 135.59it/s, loss=2.5453, acc=65.71%]
# Epoch 96 Results:
#   Train Loss: 0.0407 | Train Acc: 98.57%
#   Test Loss:  3.1166 | Test Acc:  65.71%
#   Learning Rate: 0.000005
#
# Epoch 97/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:25<00:00, 56.31it/s, loss=0.0469, acc=98.57%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 132.29it/s, loss=2.6597, acc=65.69%]
# Epoch 97 Results:
#   Train Loss: 0.0406 | Train Acc: 98.57%
#   Test Loss:  3.1337 | Test Acc:  65.69%
#   Learning Rate: 0.000003
#
# Epoch 98/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.66it/s, loss=0.1100, acc=98.68%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 137.82it/s, loss=2.5514, acc=65.50%]
# Epoch 98 Results:
#   Train Loss: 0.0381 | Train Acc: 98.68%
#   Test Loss:  3.1574 | Test Acc:  65.50%
#   Learning Rate: 0.000002
#
# Epoch 99/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.93it/s, loss=0.0193, acc=98.65%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 136.08it/s, loss=2.5696, acc=65.76%]
# Epoch 99 Results:
#   Train Loss: 0.0384 | Train Acc: 98.65%
#   Test Loss:  3.1500 | Test Acc:  65.76%
#   Learning Rate: 0.000001
#
# Epoch 100/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:24<00:00, 56.65it/s, loss=0.0111, acc=98.61%]
# Validation: 100%|██████████| 354/354 [00:02<00:00, 138.58it/s, loss=2.5309, acc=65.55%]
# Epoch 100 Results:
#   Train Loss: 0.0390 | Train Acc: 98.61%
#   Test Loss:  3.1446 | Test Acc:  65.55%
#   Learning Rate: 0.000001
#
# ============================================================
# Training completed!
# Best test accuracy: 73.59%
# ============================================================
#
# Results saved to checkpoints/dreamer/results_dominance.json

# %% [markdown]
# ### Time-length comparison

# %%
def compare_segment_lengths(data_path, task='valence'):
    """Test different time window lengths"""

    segment_lengths = [256, 384, 512, 640]  # 2, 3, 4, 5 seconds
    results = []

    for seg_len in segment_lengths:
        print(f"\n{'='*60}")
        print(f"Testing segment length: {seg_len} samples ({seg_len/128:.1f}s)")
        print(f"{'='*60}")

        config = {
            'data_path': data_path,
            'task': task,
            'segment_length': seg_len,
            'num_time': seg_len,
            'overlap': 0.5,
            'test_size': 0.2,
            'random_state': 42,
            'normalize': True,
            'binary_classification': True,
            'threshold': 3,
            'num_classes': 2,
            'temporal_kernel': 13,
            'num_kernel': 64,
            'depth': 4,
            'heads': 16,
            'mlp_dim': 16,
            'dim_head': 16,
            'dropout': 0.5,
            'batch_size': 32,
            'num_epochs': 30,  # Reduced for quick comparison
            'learning_rate': 1e-3,
            'weight_decay': 0.01,
            'min_lr': 1e-6,
            'save_dir': f'checkpoints/segment_comparison/{task}',
        }

        trainer = EEGDeformerTrainer(config)
        trainer.train()

        results.append({
            'segment_length': seg_len,
            'seconds': seg_len / 128,
            'best_acc': trainer.best_acc
        })

    print(f"\n{'='*60}")
    print("SEGMENT LENGTH COMPARISON")
    print(f"{'='*60}")
    for r in results:
        print(f"{r['segment_length']:4d} samples ({r['seconds']:.1f}s): {r['best_acc']:.2f}%")

    with open(f'segment_length_comparison_{task}.json', 'w') as f:
        json.dump({
            'task': task,
            'results': results,
            'best': max(results, key=lambda x: x['best_acc'])
        }, f, indent=4)

    return results

# %%
for task in ['valence', 'arousal', 'dominance']:
    print(f"\n{'='*60}")
    print(f"TESTING SEGMENT LENGTHS FOR {task.upper()}")
    print(f"{'='*60}")
    results = compare_segment_lengths('DREAMER.mat', task)
# Out:
# ============================================================
# TESTING SEGMENT LENGTHS FOR VALENCE
# ============================================================
#
# ============================================================
# Testing segment length: 256 samples (2.0s)
# ============================================================
# Using device: cuda
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 85330 segments
# Label distribution: [50259 35071]
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 85330 segments
# Label distribution: [50259 35071]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4271423761.py in <cell line: 0>()
#       5     print(f"TESTING SEGMENT LENGTHS FOR {task.upper()}")
#       6     print(f"{'='*60}")
# ----> 7     results = compare_segment_lengths('DREAMER.mat', task)
#
# /content/hyperparameter_tuning.py in compare_segment_lengths(data_path, task)
#     209             'normalize': True,
#     210             'binary_classification': True,
# --> 211             'threshold': 3,
#     212             'num_classes': 2,
#     213             'temporal_kernel': 13,
#
# /content/train_dreamer.py in __init__(self, config)
#      51             temporal_kernel=config.get('temporal_kernel', 13),
#      52             num_kernel=config.get('num_kernel', 64),
# ---> 53             num_classes=config['num_classes'],
#      54             depth=config.get('depth', 4),
#      55             heads=config.get('heads', 16),
#
# KeyError: 'num_classes'

# %% [markdown]
# ### Comparison between different architectures

# %% [markdown]
# CNN model

# %%
class SimpleCNN(nn.Module):

    def __init__(self, num_channels=14, segment_length=384, num_classes=2):
        super().__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv1d(num_channels, 32, kernel_size=7, padding=3),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.5),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# LSTM model

# %%
class SimpleLSTM(nn.Module):

    def __init__(self, num_channels=14, segment_length=384, num_classes=2):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=num_channels,
            hidden_size=128,
            num_layers=2,
            batch_first=True,
            dropout=0.5,
            bidirectional=True
        )

        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        x = x.transpose(1, 2)  # (batch, time, channels)

        _, (h_n, _) = self.lstm(x)

        h_forward = h_n[-2]
        h_backward = h_n[-1]
        h = torch.cat([h_forward, h_backward], dim=1)

        return self.classifier(h)

# %% [markdown]
# Train and compare architectures

# %%
def train_model(model, train_loader, test_loader, device, num_epochs=30, model_name="Model"):

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)

    best_acc = 0.0
    history = {'train_acc': [], 'test_acc': []}

    print(f"\nTraining {model_name}...")
    print(f"Parameters: {sum(p.numel() for p in model.parameters()):,}")

    for epoch in range(num_epochs):
        # Train
        model.train()
        train_correct = 0
        train_total = 0

        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(data)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, predicted = outputs.max(1)
            train_total += labels.size(0)
            train_correct += predicted.eq(labels).sum().item()

        train_acc = 100. * train_correct / train_total

        # Test
        model.eval()
        test_correct = 0
        test_total = 0

        with torch.no_grad():
            for data, labels in test_loader:
                data, labels = data.to(device), labels.to(device)
                outputs = model(data)
                _, predicted = outputs.max(1)
                test_total += labels.size(0)
                test_correct += predicted.eq(labels).sum().item()

        test_acc = 100. * test_correct / test_total

        history['train_acc'].append(train_acc)
        history['test_acc'].append(test_acc)

        if test_acc > best_acc:
            best_acc = test_acc

        if (epoch + 1) % 5 == 0:
            print(f"Epoch {epoch+1}/{num_epochs}: "
                  f"Train={train_acc:.2f}%, Test={test_acc:.2f}%, Best={best_acc:.2f}%")

    print(f"{model_name} - Best Accuracy: {best_acc:.2f}%\n")

    return {
        'best_acc': best_acc,
        'final_train_acc': history['train_acc'][-1],
        'final_test_acc': history['test_acc'][-1],
        'history': history,
        'num_params': sum(p.numel() for p in model.parameters())
    }


def compare_architectures(data_path='DREAMER.mat', task='valence', num_epochs=30):

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}\n")

    train_loader, test_loader = get_dreamer_dataloaders(
        data_path=data_path,
        task=task,
        segment_length=384,
        batch_size=32
    )

    results = {}

    print(f"\n{'='*80}")
    print(f"ARCHITECTURE COMPARISON - {task.upper()}")
    print(f"{'='*80}\n")

    #  Simple CNN
    print(f"\n{'='*60}")
    print("1. SIMPLE CNN BASELINE")
    print(f"{'='*60}")

    cnn_model = SimpleCNN(num_channels=14, segment_length=384, num_classes=2).to(device)
    results['CNN'] = train_model(cnn_model, train_loader, test_loader, device, num_epochs, "CNN")

    #  LSTM
    print(f"\n{'='*60}")
    print("2. LSTM BASELINE")
    print(f"{'='*60}")

    lstm_model = SimpleLSTM(num_channels=14, segment_length=384, num_classes=2).to(device)
    results['LSTM'] = train_model(lstm_model, train_loader, test_loader, device, num_epochs, "LSTM")

    # EEGDeformer
    print(f"\n{'='*60}")
    print("3. EEGDEFORMER (TRANSFORMER)")
    print(f"{'='*60}")

    deformer_model = Deformer(
        num_chan=14,
        num_time=384,
        temporal_kernel=13,
        num_kernel=64,
        num_classes=2,
        depth=4,
        heads=16,
        mlp_dim=16,
        dim_head=16,
        dropout=0.5
    ).to(device)

    results['EEGDeformer'] = train_model(deformer_model, train_loader, test_loader,
                                         device, num_epochs, "EEGDeformer")

    print(f"\n{'='*80}")
    print(f"RESULTS SUMMARY - {task.upper()}")
    print(f"{'='*80}")
    print(f"{'Architecture':<20} {'Parameters':<15} {'Best Acc':<12} {'Final Test':<12}")
    print(f"{'-'*80}")

    for name, result in results.items():
        print(f"{name:<20} {result['num_params']:>14,} "
              f"{result['best_acc']:>11.2f}% {result['final_test_acc']:>11.2f}%")

    cnn_acc = results['CNN']['best_acc']
    lstm_acc = results['LSTM']['best_acc']
    deformer_acc = results['EEGDeformer']['best_acc']

    print(f"{'-'*80}")
    print(f"EEGDeformer vs CNN:  +{deformer_acc - cnn_acc:.2f}%")
    print(f"EEGDeformer vs LSTM: +{deformer_acc - lstm_acc:.2f}%")
    print(f"{'='*80}\n")

    output = {
        'task': task,
        'num_epochs': num_epochs,
        'results': {name: {k: v for k, v in r.items() if k != 'history'}
                   for name, r in results.items()},
        'full_results': results
    }

    output_file = f'architecture_comparison_{task}.json'
    with open(output_file, 'w') as f:
        json.dump(output, f, indent=4)

    print(f"Results saved to {output_file}\n")

    return results

# %%
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--data_path', type=str, default='DREAMER.mat')
parser.add_argument('--task', type=str, default='valence',
                   choices=['valence', 'arousal', 'dominance', 'all'])
parser.add_argument('--epochs', type=int, default=30)

args, unknown = parser.parse_known_args()

compare_architectures(args.data_path, args.task, args.epochs)
# Out:
# Using device: cuda
#
# Loading DREAMER dataset...
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [33299 23281]
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [33299 23281]
#
# ================================================================================
# ARCHITECTURE COMPARISON - VALENCE
# ================================================================================
#
#
# ============================================================
# 1. SIMPLE CNN BASELINE
# ============================================================
#
# Training CNN...
# Parameters: 47,010
# Epoch 5/30: Train=68.72%, Test=67.60%, Best=68.65%
# Epoch 10/30: Train=71.16%, Test=70.91%, Best=71.00%
# Epoch 15/30: Train=73.70%, Test=72.40%, Best=72.40%
# Epoch 20/30: Train=75.39%, Test=66.13%, Best=73.66%
# Epoch 25/30: Train=77.41%, Test=72.65%, Best=73.68%
# Epoch 30/30: Train=78.95%, Test=74.56%, Best=74.82%
# CNN - Best Accuracy: 74.82%
#
#
# ============================================================
# 2. LSTM BASELINE
# ============================================================
#
# Training LSTM...
# Parameters: 559,298
# Epoch 5/30: Train=58.84%, Test=58.87%, Best=58.87%
# Epoch 10/30: Train=58.87%, Test=58.95%, Best=58.95%
# Epoch 15/30: Train=58.89%, Test=58.91%, Best=60.37%
# Epoch 20/30: Train=59.61%, Test=58.85%, Best=60.37%
# Epoch 25/30: Train=58.91%, Test=58.95%, Best=60.37%
# Epoch 30/30: Train=59.48%, Test=59.04%, Best=60.37%
# LSTM - Best Accuracy: 60.37%
#
#
# ============================================================
# 3. EEGDEFORMER (TRANSFORMER)
# ============================================================
#
# Training EEGDeformer...
# Parameters: 477,394
# Epoch 5/30: Train=69.05%, Test=69.26%, Best=69.67%
# Epoch 10/30: Train=71.11%, Test=70.74%, Best=71.68%
# Epoch 15/30: Train=72.96%, Test=73.14%, Best=73.14%
# Epoch 20/30: Train=73.67%, Test=74.07%, Best=74.07%
# Epoch 25/30: Train=75.11%, Test=71.62%, Best=74.07%
# Epoch 30/30: Train=76.32%, Test=69.13%, Best=74.53%
# EEGDeformer - Best Accuracy: 74.53%
#
#
# ================================================================================
# RESULTS SUMMARY - VALENCE
# ================================================================================
# Architecture         Parameters      Best Acc     Final Test
# --------------------------------------------------------------------------------
# CNN                          47,010       74.82%       74.56%
# LSTM                        559,298       60.37%       59.04%
# EEGDeformer                 477,394       74.53%       69.13%
# --------------------------------------------------------------------------------
# EEGDeformer vs CNN:  +-0.29%
# EEGDeformer vs LSTM: +14.17%
# ================================================================================
#
# Results saved to architecture_comparison_valence.json

# %% [markdown]
# ### Test on different depth

# %%
config = {
    # Data parameters
    'data_path': 'DREAMER.mat',
    'task': 'valence',
    'segment_length': 384,
    'overlap': 0.5,
    'test_size': 0.2,
    'random_state': 42,
    'normalize': True,
    'binary_classification': True,
    'threshold': 3,

    # Model parameters
    'num_classes': 2,
    'temporal_kernel': 13,
    'num_kernel': 64,
    'depth': 1,
    'heads': 16,
    'mlp_dim': 16,
    'dim_head': 16,
    'dropout': 0.5,

    # Training parameters
    'batch_size': 32,
    'num_epochs': 100,
    'learning_rate': 1e-3,
    'weight_decay': 0.01,
    'min_lr': 1e-6,

    # Other
        'save_dir': 'checkpoints/dreamer',
}

trainer = EEGDeformerTrainer(config)
trainer.train()
# Out:
# Using device: cuda
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [33299 23281]
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [33299 23281]
#
# Model parameters: 238,354
#
# ============================================================
# Starting training for task: VALENCE
# ============================================================
#
#
# Epoch 1/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:12<00:00, 112.28it/s, loss=0.8852, acc=55.85%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.75it/s, loss=0.6769, acc=60.68%]
# Epoch 1 Results:
#   Train Loss: 0.7990 | Train Acc: 55.85%
#   Test Loss:  0.6637 | Test Acc:  60.68%
#   Learning Rate: 0.001000
#   ✓ New best accuracy: 60.68%
#
# Epoch 2/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.79it/s, loss=0.8002, acc=60.76%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 243.29it/s, loss=0.8274, acc=52.84%]
# Epoch 2 Results:
#   Train Loss: 0.6931 | Train Acc: 60.76%
#   Test Loss:  0.7587 | Test Acc:  52.84%
#   Learning Rate: 0.000999
#
# Epoch 3/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.06it/s, loss=0.7560, acc=63.08%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.95it/s, loss=0.5514, acc=65.62%]
# Epoch 3 Results:
#   Train Loss: 0.6515 | Train Acc: 63.08%
#   Test Loss:  0.6065 | Test Acc:  65.62%
#   Learning Rate: 0.000998
#   ✓ New best accuracy: 65.62%
#
# Epoch 4/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.86it/s, loss=0.5892, acc=64.54%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.88it/s, loss=0.5825, acc=66.71%]
# Epoch 4 Results:
#   Train Loss: 0.6324 | Train Acc: 64.54%
#   Test Loss:  0.6011 | Test Acc:  66.71%
#   Learning Rate: 0.000996
#   ✓ New best accuracy: 66.71%
#
# Epoch 5/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 136.24it/s, loss=0.5886, acc=65.79%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.37it/s, loss=0.5611, acc=67.43%]
# Epoch 5 Results:
#   Train Loss: 0.6172 | Train Acc: 65.79%
#   Test Loss:  0.5863 | Test Acc:  67.43%
#   Learning Rate: 0.000994
#   ✓ New best accuracy: 67.43%
#
# Epoch 6/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.60it/s, loss=0.6658, acc=66.62%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.87it/s, loss=0.5812, acc=66.08%]
# Epoch 6 Results:
#   Train Loss: 0.6092 | Train Acc: 66.62%
#   Test Loss:  0.6012 | Test Acc:  66.08%
#   Learning Rate: 0.000991
#
# Epoch 7/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.83it/s, loss=0.8988, acc=67.36%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.32it/s, loss=0.6331, acc=68.26%]
# Epoch 7 Results:
#   Train Loss: 0.5988 | Train Acc: 67.36%
#   Test Loss:  0.5739 | Test Acc:  68.26%
#   Learning Rate: 0.000988
#   ✓ New best accuracy: 68.26%
#
# Epoch 8/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.25it/s, loss=0.5903, acc=67.96%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.30it/s, loss=0.7235, acc=63.93%]
# Epoch 8 Results:
#   Train Loss: 0.5908 | Train Acc: 67.96%
#   Test Loss:  0.6561 | Test Acc:  63.93%
#   Learning Rate: 0.000984
#
# Epoch 9/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.67it/s, loss=0.5769, acc=68.01%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.89it/s, loss=0.6131, acc=68.44%]
# Epoch 9 Results:
#   Train Loss: 0.5885 | Train Acc: 68.01%
#   Test Loss:  0.5706 | Test Acc:  68.44%
#   Learning Rate: 0.000980
#   ✓ New best accuracy: 68.44%
#
# Epoch 10/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.67it/s, loss=0.7340, acc=68.66%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.83it/s, loss=0.5832, acc=69.59%]
# Epoch 10 Results:
#   Train Loss: 0.5814 | Train Acc: 68.66%
#   Test Loss:  0.5657 | Test Acc:  69.59%
#   Learning Rate: 0.000976
#   ✓ New best accuracy: 69.59%
#
# Epoch 11/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.78it/s, loss=0.6621, acc=69.20%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.58it/s, loss=0.5993, acc=70.11%]
# Epoch 11 Results:
#   Train Loss: 0.5750 | Train Acc: 69.20%
#   Test Loss:  0.5598 | Test Acc:  70.11%
#   Learning Rate: 0.000970
#   ✓ New best accuracy: 70.11%
#
# Epoch 12/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.35it/s, loss=0.4950, acc=70.19%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.09it/s, loss=0.5618, acc=64.27%]
# Epoch 12 Results:
#   Train Loss: 0.5676 | Train Acc: 70.19%
#   Test Loss:  0.6417 | Test Acc:  64.27%
#   Learning Rate: 0.000965
#
# Epoch 13/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.82it/s, loss=0.6181, acc=70.00%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 244.07it/s, loss=0.5820, acc=67.64%]
# Epoch 13 Results:
#   Train Loss: 0.5631 | Train Acc: 70.00%
#   Test Loss:  0.5934 | Test Acc:  67.64%
#   Learning Rate: 0.000959
#
# Epoch 14/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.43it/s, loss=0.4959, acc=70.36%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.56it/s, loss=0.5173, acc=68.83%]
# Epoch 14 Results:
#   Train Loss: 0.5620 | Train Acc: 70.36%
#   Test Loss:  0.5690 | Test Acc:  68.83%
#   Learning Rate: 0.000952
#
# Epoch 15/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.59it/s, loss=0.5065, acc=70.99%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 230.29it/s, loss=0.5680, acc=70.86%]
# Epoch 15 Results:
#   Train Loss: 0.5535 | Train Acc: 70.99%
#   Test Loss:  0.5565 | Test Acc:  70.86%
#   Learning Rate: 0.000946
#   ✓ New best accuracy: 70.86%
#
# Epoch 16/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.67it/s, loss=0.5244, acc=71.01%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 231.35it/s, loss=0.6290, acc=70.23%]
# Epoch 16 Results:
#   Train Loss: 0.5510 | Train Acc: 71.01%
#   Test Loss:  0.5600 | Test Acc:  70.23%
#   Learning Rate: 0.000938
#
# Epoch 17/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.21it/s, loss=0.4816, acc=71.59%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.19it/s, loss=0.5648, acc=70.20%]
# Epoch 17 Results:
#   Train Loss: 0.5420 | Train Acc: 71.59%
#   Test Loss:  0.5486 | Test Acc:  70.20%
#   Learning Rate: 0.000930
#
# Epoch 18/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.83it/s, loss=0.4798, acc=72.06%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.98it/s, loss=0.5774, acc=69.42%]
# Epoch 18 Results:
#   Train Loss: 0.5377 | Train Acc: 72.06%
#   Test Loss:  0.5712 | Test Acc:  69.42%
#   Learning Rate: 0.000922
#
# Epoch 19/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.29it/s, loss=0.5849, acc=72.74%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 240.00it/s, loss=0.6427, acc=66.37%]
# Epoch 19 Results:
#   Train Loss: 0.5322 | Train Acc: 72.74%
#   Test Loss:  0.6087 | Test Acc:  66.37%
#   Learning Rate: 0.000914
#
# Epoch 20/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.79it/s, loss=0.8493, acc=72.76%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.50it/s, loss=0.4526, acc=70.01%]
# Epoch 20 Results:
#   Train Loss: 0.5290 | Train Acc: 72.76%
#   Test Loss:  0.5659 | Test Acc:  70.01%
#   Learning Rate: 0.000905
#
# Epoch 21/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.62it/s, loss=0.3994, acc=73.46%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.91it/s, loss=0.6164, acc=67.02%]
# Epoch 21 Results:
#   Train Loss: 0.5221 | Train Acc: 73.46%
#   Test Loss:  0.6013 | Test Acc:  67.02%
#   Learning Rate: 0.000895
#
# Epoch 22/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.77it/s, loss=0.4862, acc=73.75%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.47it/s, loss=0.5863, acc=68.96%]
# Epoch 22 Results:
#   Train Loss: 0.5155 | Train Acc: 73.75%
#   Test Loss:  0.5852 | Test Acc:  68.96%
#   Learning Rate: 0.000885
#
# Epoch 23/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 135.54it/s, loss=0.5619, acc=74.42%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.35it/s, loss=0.5867, acc=71.31%]
# Epoch 23 Results:
#   Train Loss: 0.5082 | Train Acc: 74.42%
#   Test Loss:  0.5493 | Test Acc:  71.31%
#   Learning Rate: 0.000875
#   ✓ New best accuracy: 71.31%
#
# Epoch 24/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.45it/s, loss=0.4400, acc=74.34%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.26it/s, loss=0.5342, acc=72.12%]
# Epoch 24 Results:
#   Train Loss: 0.5076 | Train Acc: 74.34%
#   Test Loss:  0.5323 | Test Acc:  72.12%
#   Learning Rate: 0.000865
#   ✓ New best accuracy: 72.12%
#
# Epoch 25/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.15it/s, loss=0.4789, acc=74.84%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.31it/s, loss=0.5651, acc=70.86%]
# Epoch 25 Results:
#   Train Loss: 0.4991 | Train Acc: 74.84%
#   Test Loss:  0.5551 | Test Acc:  70.86%
#   Learning Rate: 0.000854
#
# Epoch 26/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.40it/s, loss=0.4923, acc=75.19%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 241.18it/s, loss=0.5281, acc=70.90%]
# Epoch 26 Results:
#   Train Loss: 0.4930 | Train Acc: 75.19%
#   Test Loss:  0.5526 | Test Acc:  70.90%
#   Learning Rate: 0.000842
#
# Epoch 27/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.81it/s, loss=0.5834, acc=75.51%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.34it/s, loss=0.5182, acc=71.20%]
# Epoch 27 Results:
#   Train Loss: 0.4882 | Train Acc: 75.51%
#   Test Loss:  0.5401 | Test Acc:  71.20%
#   Learning Rate: 0.000831
#
# Epoch 28/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.64it/s, loss=0.4852, acc=75.82%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.59it/s, loss=0.5658, acc=70.00%]
# Epoch 28 Results:
#   Train Loss: 0.4863 | Train Acc: 75.82%
#   Test Loss:  0.5666 | Test Acc:  70.00%
#   Learning Rate: 0.000819
#
# Epoch 29/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.75it/s, loss=0.4382, acc=76.32%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 242.21it/s, loss=0.6243, acc=71.62%]
# Epoch 29 Results:
#   Train Loss: 0.4803 | Train Acc: 76.32%
#   Test Loss:  0.5483 | Test Acc:  71.62%
#   Learning Rate: 0.000807
#
# Epoch 30/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.41it/s, loss=0.4222, acc=76.81%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.32it/s, loss=0.5668, acc=70.41%]
# Epoch 30 Results:
#   Train Loss: 0.4690 | Train Acc: 76.81%
#   Test Loss:  0.5616 | Test Acc:  70.41%
#   Learning Rate: 0.000794
#
# Epoch 31/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.08it/s, loss=0.4901, acc=77.02%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.55it/s, loss=0.6182, acc=72.04%]
# Epoch 31 Results:
#   Train Loss: 0.4647 | Train Acc: 77.02%
#   Test Loss:  0.5522 | Test Acc:  72.04%
#   Learning Rate: 0.000781
#
# Epoch 32/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.23it/s, loss=0.4937, acc=76.89%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.19it/s, loss=0.6683, acc=70.03%]
# Epoch 32 Results:
#   Train Loss: 0.4670 | Train Acc: 76.89%
#   Test Loss:  0.6000 | Test Acc:  70.03%
#   Learning Rate: 0.000768
#
# Epoch 33/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.27it/s, loss=0.7134, acc=77.63%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.90it/s, loss=0.5173, acc=72.75%]
# Epoch 33 Results:
#   Train Loss: 0.4596 | Train Acc: 77.63%
#   Test Loss:  0.5237 | Test Acc:  72.75%
#   Learning Rate: 0.000755
#   ✓ New best accuracy: 72.75%
#
# Epoch 34/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.93it/s, loss=0.4537, acc=77.72%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.75it/s, loss=0.5559, acc=72.34%]
# Epoch 34 Results:
#   Train Loss: 0.4556 | Train Acc: 77.72%
#   Test Loss:  0.5311 | Test Acc:  72.34%
#   Learning Rate: 0.000741
#
# Epoch 35/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.80it/s, loss=0.4298, acc=78.37%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.29it/s, loss=0.5634, acc=71.42%]
# Epoch 35 Results:
#   Train Loss: 0.4466 | Train Acc: 78.37%
#   Test Loss:  0.5455 | Test Acc:  71.42%
#   Learning Rate: 0.000727
#
# Epoch 36/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 130.14it/s, loss=0.5594, acc=78.46%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.93it/s, loss=0.5267, acc=73.20%]
# Epoch 36 Results:
#   Train Loss: 0.4455 | Train Acc: 78.46%
#   Test Loss:  0.5300 | Test Acc:  73.20%
#   Learning Rate: 0.000713
#   ✓ New best accuracy: 73.20%
#
# Epoch 37/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.40it/s, loss=0.2240, acc=78.74%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.79it/s, loss=0.5246, acc=72.25%]
# Epoch 37 Results:
#   Train Loss: 0.4395 | Train Acc: 78.74%
#   Test Loss:  0.5385 | Test Acc:  72.25%
#   Learning Rate: 0.000699
#
# Epoch 38/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.53it/s, loss=0.2995, acc=79.25%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 231.12it/s, loss=0.4362, acc=73.32%]
# Epoch 38 Results:
#   Train Loss: 0.4319 | Train Acc: 79.25%
#   Test Loss:  0.5339 | Test Acc:  73.32%
#   Learning Rate: 0.000684
#   ✓ New best accuracy: 73.32%
#
# Epoch 39/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.94it/s, loss=0.4080, acc=79.48%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 230.19it/s, loss=0.5981, acc=72.62%]
# Epoch 39 Results:
#   Train Loss: 0.4300 | Train Acc: 79.48%
#   Test Loss:  0.5389 | Test Acc:  72.62%
#   Learning Rate: 0.000670
#
# Epoch 40/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.36it/s, loss=0.4103, acc=80.04%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 228.08it/s, loss=0.5928, acc=71.59%]
# Epoch 40 Results:
#   Train Loss: 0.4226 | Train Acc: 80.04%
#   Test Loss:  0.5621 | Test Acc:  71.59%
#   Learning Rate: 0.000655
#
# Epoch 41/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 131.85it/s, loss=0.3624, acc=80.05%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 229.89it/s, loss=0.6084, acc=72.61%]
# Epoch 41 Results:
#   Train Loss: 0.4205 | Train Acc: 80.05%
#   Test Loss:  0.5394 | Test Acc:  72.61%
#   Learning Rate: 0.000640
#
# Epoch 42/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.22it/s, loss=0.5319, acc=80.21%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.84it/s, loss=0.4600, acc=73.78%]
# Epoch 42 Results:
#   Train Loss: 0.4162 | Train Acc: 80.21%
#   Test Loss:  0.5200 | Test Acc:  73.78%
#   Learning Rate: 0.000625
#   ✓ New best accuracy: 73.78%
#
# Epoch 43/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.95it/s, loss=0.3529, acc=80.63%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.73it/s, loss=0.6269, acc=72.46%]
# Epoch 43 Results:
#   Train Loss: 0.4096 | Train Acc: 80.63%
#   Test Loss:  0.5438 | Test Acc:  72.46%
#   Learning Rate: 0.000609
#
# Epoch 44/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.95it/s, loss=0.2935, acc=81.08%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.20it/s, loss=0.5623, acc=72.21%]
# Epoch 44 Results:
#   Train Loss: 0.4029 | Train Acc: 81.08%
#   Test Loss:  0.5592 | Test Acc:  72.21%
#   Learning Rate: 0.000594
#
# Epoch 45/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.69it/s, loss=0.4318, acc=81.16%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.42it/s, loss=0.5377, acc=74.00%]
# Epoch 45 Results:
#   Train Loss: 0.4028 | Train Acc: 81.16%
#   Test Loss:  0.5247 | Test Acc:  74.00%
#   Learning Rate: 0.000579
#   ✓ New best accuracy: 74.00%
#
# Epoch 46/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.33it/s, loss=0.3429, acc=81.37%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.19it/s, loss=0.4531, acc=73.74%]
# Epoch 46 Results:
#   Train Loss: 0.3957 | Train Acc: 81.37%
#   Test Loss:  0.5265 | Test Acc:  73.74%
#   Learning Rate: 0.000563
#
# Epoch 47/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.30it/s, loss=0.1559, acc=81.82%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.83it/s, loss=0.4209, acc=74.42%]
# Epoch 47 Results:
#   Train Loss: 0.3880 | Train Acc: 81.82%
#   Test Loss:  0.5133 | Test Acc:  74.42%
#   Learning Rate: 0.000548
#   ✓ New best accuracy: 74.42%
#
# Epoch 48/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.40it/s, loss=0.4420, acc=82.05%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 238.32it/s, loss=0.4127, acc=74.08%]
# Epoch 48 Results:
#   Train Loss: 0.3874 | Train Acc: 82.05%
#   Test Loss:  0.5236 | Test Acc:  74.08%
#   Learning Rate: 0.000532
#
# Epoch 49/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 131.82it/s, loss=0.4911, acc=82.10%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.23it/s, loss=0.5233, acc=70.97%]
# Epoch 49 Results:
#   Train Loss: 0.3839 | Train Acc: 82.10%
#   Test Loss:  0.5813 | Test Acc:  70.97%
#   Learning Rate: 0.000516
#
# Epoch 50/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.91it/s, loss=0.2448, acc=82.52%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.07it/s, loss=0.4828, acc=74.43%]
# Epoch 50 Results:
#   Train Loss: 0.3785 | Train Acc: 82.52%
#   Test Loss:  0.5286 | Test Acc:  74.43%
#   Learning Rate: 0.000501
#   ✓ New best accuracy: 74.43%
#
# Epoch 51/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.78it/s, loss=0.3946, acc=82.99%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.53it/s, loss=0.4789, acc=74.98%]
# Epoch 51 Results:
#   Train Loss: 0.3717 | Train Acc: 82.99%
#   Test Loss:  0.5080 | Test Acc:  74.98%
#   Learning Rate: 0.000485
#   ✓ New best accuracy: 74.98%
#
# Epoch 52/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.50it/s, loss=0.1363, acc=83.14%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.50it/s, loss=0.4664, acc=73.97%]
# Epoch 52 Results:
#   Train Loss: 0.3677 | Train Acc: 83.14%
#   Test Loss:  0.5392 | Test Acc:  73.97%
#   Learning Rate: 0.000469
#
# Epoch 53/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.07it/s, loss=0.5698, acc=83.14%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.30it/s, loss=0.4216, acc=75.10%]
# Epoch 53 Results:
#   Train Loss: 0.3644 | Train Acc: 83.14%
#   Test Loss:  0.5174 | Test Acc:  75.10%
#   Learning Rate: 0.000453
#   ✓ New best accuracy: 75.10%
#
# Epoch 54/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 130.55it/s, loss=0.4273, acc=83.34%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.07it/s, loss=0.5112, acc=73.29%]
# Epoch 54 Results:
#   Train Loss: 0.3632 | Train Acc: 83.34%
#   Test Loss:  0.5531 | Test Acc:  73.29%
#   Learning Rate: 0.000438
#
# Epoch 55/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.45it/s, loss=0.4321, acc=83.93%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.67it/s, loss=0.5066, acc=73.83%]
# Epoch 55 Results:
#   Train Loss: 0.3529 | Train Acc: 83.93%
#   Test Loss:  0.5493 | Test Acc:  73.83%
#   Learning Rate: 0.000422
#
# Epoch 56/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.70it/s, loss=0.5771, acc=84.20%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.02it/s, loss=0.4936, acc=74.65%]
# Epoch 56 Results:
#   Train Loss: 0.3494 | Train Acc: 84.20%
#   Test Loss:  0.5274 | Test Acc:  74.65%
#   Learning Rate: 0.000407
#
# Epoch 57/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 130.57it/s, loss=0.2417, acc=84.21%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.43it/s, loss=0.5346, acc=73.93%]
# Epoch 57 Results:
#   Train Loss: 0.3474 | Train Acc: 84.21%
#   Test Loss:  0.5565 | Test Acc:  73.93%
#   Learning Rate: 0.000392
#
# Epoch 58/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.02it/s, loss=0.6344, acc=84.45%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 230.80it/s, loss=0.5474, acc=74.69%]
# Epoch 58 Results:
#   Train Loss: 0.3424 | Train Acc: 84.45%
#   Test Loss:  0.5418 | Test Acc:  74.69%
#   Learning Rate: 0.000376
#
# Epoch 59/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.18it/s, loss=0.4668, acc=84.89%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 227.85it/s, loss=0.5783, acc=74.03%]
# Epoch 59 Results:
#   Train Loss: 0.3374 | Train Acc: 84.89%
#   Test Loss:  0.5523 | Test Acc:  74.03%
#   Learning Rate: 0.000361
#
# Epoch 60/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.66it/s, loss=0.2547, acc=85.18%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.80it/s, loss=0.5227, acc=74.33%]
# Epoch 60 Results:
#   Train Loss: 0.3303 | Train Acc: 85.18%
#   Test Loss:  0.5478 | Test Acc:  74.33%
#   Learning Rate: 0.000346
#
# Epoch 61/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.67it/s, loss=0.2924, acc=85.43%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 231.49it/s, loss=0.5342, acc=74.03%]
# Epoch 61 Results:
#   Train Loss: 0.3277 | Train Acc: 85.43%
#   Test Loss:  0.5608 | Test Acc:  74.03%
#   Learning Rate: 0.000331
#
# Epoch 62/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.25it/s, loss=0.3058, acc=85.44%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.65it/s, loss=0.5345, acc=74.46%]
# Epoch 62 Results:
#   Train Loss: 0.3235 | Train Acc: 85.44%
#   Test Loss:  0.5544 | Test Acc:  74.46%
#   Learning Rate: 0.000317
#
# Epoch 63/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.05it/s, loss=0.1633, acc=85.82%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.46it/s, loss=0.5345, acc=74.87%]
# Epoch 63 Results:
#   Train Loss: 0.3171 | Train Acc: 85.82%
#   Test Loss:  0.5516 | Test Acc:  74.87%
#   Learning Rate: 0.000302
#
# Epoch 64/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.37it/s, loss=0.3665, acc=85.76%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.79it/s, loss=0.5782, acc=75.22%]
# Epoch 64 Results:
#   Train Loss: 0.3192 | Train Acc: 85.76%
#   Test Loss:  0.5444 | Test Acc:  75.22%
#   Learning Rate: 0.000288
#   ✓ New best accuracy: 75.22%
#
# Epoch 65/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.51it/s, loss=0.1247, acc=86.20%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.70it/s, loss=0.5423, acc=74.45%]
# Epoch 65 Results:
#   Train Loss: 0.3094 | Train Acc: 86.20%
#   Test Loss:  0.5827 | Test Acc:  74.45%
#   Learning Rate: 0.000274
#
# Epoch 66/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.06it/s, loss=0.3811, acc=86.35%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.37it/s, loss=0.5154, acc=75.23%]
# Epoch 66 Results:
#   Train Loss: 0.3075 | Train Acc: 86.35%
#   Test Loss:  0.5710 | Test Acc:  75.23%
#   Learning Rate: 0.000260
#   ✓ New best accuracy: 75.23%
#
# Epoch 67/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.89it/s, loss=0.3339, acc=86.67%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 228.61it/s, loss=0.4943, acc=73.75%]
# Epoch 67 Results:
#   Train Loss: 0.3009 | Train Acc: 86.67%
#   Test Loss:  0.5994 | Test Acc:  73.75%
#   Learning Rate: 0.000246
#
# Epoch 68/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 131.94it/s, loss=0.3171, acc=87.16%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.92it/s, loss=0.4390, acc=74.99%]
# Epoch 68 Results:
#   Train Loss: 0.2948 | Train Acc: 87.16%
#   Test Loss:  0.5717 | Test Acc:  74.99%
#   Learning Rate: 0.000233
#
# Epoch 69/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 130.91it/s, loss=0.4842, acc=86.98%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.53it/s, loss=0.5450, acc=75.87%]
# Epoch 69 Results:
#   Train Loss: 0.2949 | Train Acc: 86.98%
#   Test Loss:  0.5662 | Test Acc:  75.87%
#   Learning Rate: 0.000220
#   ✓ New best accuracy: 75.87%
#
# Epoch 70/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.16it/s, loss=0.2694, acc=87.35%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 229.30it/s, loss=0.5546, acc=75.07%]
# Epoch 70 Results:
#   Train Loss: 0.2890 | Train Acc: 87.35%
#   Test Loss:  0.5875 | Test Acc:  75.07%
#   Learning Rate: 0.000207
#
# Epoch 71/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.79it/s, loss=0.5454, acc=87.64%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.33it/s, loss=0.5582, acc=75.09%]
# Epoch 71 Results:
#   Train Loss: 0.2824 | Train Acc: 87.64%
#   Test Loss:  0.5864 | Test Acc:  75.09%
#   Learning Rate: 0.000194
#
# Epoch 72/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 131.72it/s, loss=0.2167, acc=88.26%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.54it/s, loss=0.5463, acc=75.87%]
# Epoch 72 Results:
#   Train Loss: 0.2740 | Train Acc: 88.26%
#   Test Loss:  0.5768 | Test Acc:  75.87%
#   Learning Rate: 0.000182
#   ✓ New best accuracy: 75.87%
#
# Epoch 73/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.30it/s, loss=0.2433, acc=88.30%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 228.52it/s, loss=0.6133, acc=73.21%]
# Epoch 73 Results:
#   Train Loss: 0.2707 | Train Acc: 88.30%
#   Test Loss:  0.6523 | Test Acc:  73.21%
#   Learning Rate: 0.000170
#
# Epoch 74/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.78it/s, loss=0.4631, acc=88.44%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 231.62it/s, loss=0.6453, acc=72.80%]
# Epoch 74 Results:
#   Train Loss: 0.2692 | Train Acc: 88.44%
#   Test Loss:  0.6590 | Test Acc:  72.80%
#   Learning Rate: 0.000159
#
# Epoch 75/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.50it/s, loss=0.1263, acc=88.56%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.00it/s, loss=0.5409, acc=75.08%]
# Epoch 75 Results:
#   Train Loss: 0.2657 | Train Acc: 88.56%
#   Test Loss:  0.6234 | Test Acc:  75.08%
#   Learning Rate: 0.000147
#
# Epoch 76/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.06it/s, loss=0.1558, acc=88.74%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 239.27it/s, loss=0.5713, acc=75.26%]
# Epoch 76 Results:
#   Train Loss: 0.2603 | Train Acc: 88.74%
#   Test Loss:  0.6276 | Test Acc:  75.26%
#   Learning Rate: 0.000136
#
# Epoch 77/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.02it/s, loss=0.5727, acc=88.73%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.95it/s, loss=0.5695, acc=75.02%]
# Epoch 77 Results:
#   Train Loss: 0.2585 | Train Acc: 88.73%
#   Test Loss:  0.6318 | Test Acc:  75.02%
#   Learning Rate: 0.000126
#
# Epoch 78/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.70it/s, loss=0.1468, acc=88.93%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.94it/s, loss=0.5267, acc=75.27%]
# Epoch 78 Results:
#   Train Loss: 0.2550 | Train Acc: 88.93%
#   Test Loss:  0.6435 | Test Acc:  75.27%
#   Learning Rate: 0.000116
#
# Epoch 79/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.02it/s, loss=0.2579, acc=89.21%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.96it/s, loss=0.5399, acc=75.07%]
# Epoch 79 Results:
#   Train Loss: 0.2520 | Train Acc: 89.21%
#   Test Loss:  0.6493 | Test Acc:  75.07%
#   Learning Rate: 0.000106
#
# Epoch 80/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.27it/s, loss=0.1937, acc=89.57%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.67it/s, loss=0.5410, acc=74.95%]
# Epoch 80 Results:
#   Train Loss: 0.2443 | Train Acc: 89.57%
#   Test Loss:  0.6605 | Test Acc:  74.95%
#   Learning Rate: 0.000096
#
# Epoch 81/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.67it/s, loss=0.2068, acc=89.62%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 230.25it/s, loss=0.4701, acc=75.30%]
# Epoch 81 Results:
#   Train Loss: 0.2439 | Train Acc: 89.62%
#   Test Loss:  0.6563 | Test Acc:  75.30%
#   Learning Rate: 0.000087
#
# Epoch 82/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 134.06it/s, loss=0.1338, acc=89.75%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 230.43it/s, loss=0.5246, acc=75.04%]
# Epoch 82 Results:
#   Train Loss: 0.2416 | Train Acc: 89.75%
#   Test Loss:  0.6606 | Test Acc:  75.04%
#   Learning Rate: 0.000079
#
# Epoch 83/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.84it/s, loss=0.2525, acc=89.89%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.48it/s, loss=0.5331, acc=75.11%]
# Epoch 83 Results:
#   Train Loss: 0.2391 | Train Acc: 89.89%
#   Test Loss:  0.6890 | Test Acc:  75.11%
#   Learning Rate: 0.000071
#
# Epoch 84/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 131.99it/s, loss=0.3210, acc=89.99%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.71it/s, loss=0.5516, acc=75.07%]
# Epoch 84 Results:
#   Train Loss: 0.2345 | Train Acc: 89.99%
#   Test Loss:  0.6775 | Test Acc:  75.07%
#   Learning Rate: 0.000063
#
# Epoch 85/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.84it/s, loss=0.3671, acc=90.04%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.90it/s, loss=0.5055, acc=75.11%]
# Epoch 85 Results:
#   Train Loss: 0.2312 | Train Acc: 90.04%
#   Test Loss:  0.6877 | Test Acc:  75.11%
#   Learning Rate: 0.000055
#
# Epoch 86/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.94it/s, loss=0.1553, acc=90.11%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.81it/s, loss=0.5343, acc=75.23%]
# Epoch 86 Results:
#   Train Loss: 0.2317 | Train Acc: 90.11%
#   Test Loss:  0.6861 | Test Acc:  75.23%
#   Learning Rate: 0.000049
#
# Epoch 87/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.97it/s, loss=0.1847, acc=90.55%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.99it/s, loss=0.5597, acc=74.62%]
# Epoch 87 Results:
#   Train Loss: 0.2253 | Train Acc: 90.55%
#   Test Loss:  0.6944 | Test Acc:  74.62%
#   Learning Rate: 0.000042
#
# Epoch 88/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.86it/s, loss=0.1368, acc=90.38%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.80it/s, loss=0.5379, acc=74.45%]
# Epoch 88 Results:
#   Train Loss: 0.2263 | Train Acc: 90.38%
#   Test Loss:  0.6981 | Test Acc:  74.45%
#   Learning Rate: 0.000036
#
# Epoch 89/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.14it/s, loss=0.0487, acc=90.41%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.19it/s, loss=0.5391, acc=75.05%]
# Epoch 89 Results:
#   Train Loss: 0.2235 | Train Acc: 90.41%
#   Test Loss:  0.6964 | Test Acc:  75.05%
#   Learning Rate: 0.000031
#
# Epoch 90/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.53it/s, loss=0.1284, acc=90.85%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 240.05it/s, loss=0.5570, acc=74.62%]
# Epoch 90 Results:
#   Train Loss: 0.2196 | Train Acc: 90.85%
#   Test Loss:  0.7046 | Test Acc:  74.62%
#   Learning Rate: 0.000025
#
# Epoch 91/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.74it/s, loss=0.2668, acc=90.68%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 236.86it/s, loss=0.5408, acc=74.62%]
# Epoch 91 Results:
#   Train Loss: 0.2217 | Train Acc: 90.68%
#   Test Loss:  0.7054 | Test Acc:  74.62%
#   Learning Rate: 0.000021
#
# Epoch 92/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.04it/s, loss=0.2289, acc=90.68%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.91it/s, loss=0.5376, acc=74.66%]
# Epoch 92 Results:
#   Train Loss: 0.2192 | Train Acc: 90.68%
#   Test Loss:  0.7139 | Test Acc:  74.66%
#   Learning Rate: 0.000017
#
# Epoch 93/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.76it/s, loss=0.3250, acc=90.88%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.10it/s, loss=0.5657, acc=74.51%]
# Epoch 93 Results:
#   Train Loss: 0.2169 | Train Acc: 90.88%
#   Test Loss:  0.7196 | Test Acc:  74.51%
#   Learning Rate: 0.000013
#
# Epoch 94/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 131.56it/s, loss=0.1639, acc=91.03%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 237.15it/s, loss=0.5193, acc=74.95%]
# Epoch 94 Results:
#   Train Loss: 0.2159 | Train Acc: 91.03%
#   Test Loss:  0.7147 | Test Acc:  74.95%
#   Learning Rate: 0.000010
#
# Epoch 95/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.97it/s, loss=0.2537, acc=90.98%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 233.16it/s, loss=0.5593, acc=74.20%]
# Epoch 95 Results:
#   Train Loss: 0.2156 | Train Acc: 90.98%
#   Test Loss:  0.7282 | Test Acc:  74.20%
#   Learning Rate: 0.000007
#
# Epoch 96/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.47it/s, loss=0.1384, acc=90.96%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.18it/s, loss=0.5483, acc=74.70%]
# Epoch 96 Results:
#   Train Loss: 0.2143 | Train Acc: 90.96%
#   Test Loss:  0.7224 | Test Acc:  74.70%
#   Learning Rate: 0.000005
#
# Epoch 97/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 129.75it/s, loss=0.3422, acc=91.00%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 235.65it/s, loss=0.5321, acc=74.68%]
# Epoch 97 Results:
#   Train Loss: 0.2121 | Train Acc: 91.00%
#   Test Loss:  0.7229 | Test Acc:  74.68%
#   Learning Rate: 0.000003
#
# Epoch 98/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 132.63it/s, loss=0.4312, acc=91.06%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.04it/s, loss=0.5508, acc=74.54%]
# Epoch 98 Results:
#   Train Loss: 0.2115 | Train Acc: 91.06%
#   Test Loss:  0.7247 | Test Acc:  74.54%
#   Learning Rate: 0.000002
#
# Epoch 99/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.06it/s, loss=0.1054, acc=91.20%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 232.98it/s, loss=0.5414, acc=74.77%]
# Epoch 99 Results:
#   Train Loss: 0.2129 | Train Acc: 91.20%
#   Test Loss:  0.7260 | Test Acc:  74.77%
#   Learning Rate: 0.000001
#
# Epoch 100/100
# ------------------------------------------------------------
# Training: 100%|██████████| 1415/1415 [00:10<00:00, 133.69it/s, loss=0.1504, acc=91.13%]
# Validation: 100%|██████████| 354/354 [00:01<00:00, 234.40it/s, loss=0.5527, acc=74.32%]
# Epoch 100 Results:
#   Train Loss: 0.2123 | Train Acc: 91.13%
#   Test Loss:  0.7286 | Test Acc:  74.32%
#   Learning Rate: 0.000001
#
# ============================================================
# Training completed!
# Best test accuracy: 75.87%
# ============================================================
#
# Results saved to checkpoints/dreamer/results_valence.json

# %% [markdown]
# ### Temporal Order Analysis

# %%
class ShuffledDREAMERDataset(Dataset):

    def __init__(self, original_dataset, shuffle_type='random'):
        self.data = original_dataset.data.copy()
        self.labels = original_dataset.labels.copy()
        self.shuffle_type = shuffle_type

        self._shuffle_temporal()

    def _shuffle_temporal(self):
        """Shuffle the temporal dimension"""
        n_samples, n_channels, n_timepoints = self.data.shape

        if self.shuffle_type == 'random':
            for i in range(n_samples):
                for c in range(n_channels):
                    np.random.shuffle(self.data[i, c, :])

        elif self.shuffle_type == 'reverse':
            self.data = self.data[:, :, ::-1].copy()

        elif self.shuffle_type == 'block':
            mid = n_timepoints // 2
            first_half = self.data[:, :, :mid].copy()
            second_half = self.data[:, :, mid:].copy()
            self.data[:, :, :mid] = second_half
            self.data[:, :, mid:] = first_half

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = torch.FloatTensor(self.data[idx])
        label = torch.LongTensor([self.labels[idx]])[0]
        return data, label


def temporal_order_analysis(data_path='DREAMER.mat', task='valence', num_epochs=30):
    """Test if temporal order matters for performance"""

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}\n")

    print(f"{'='*80}")
    print(f"TEMPORAL ORDER ANALYSIS - {task.upper()}")
    print(f"{'='*80}\n")

    results = {}

    # Original data
    print(f"{'='*60}")
    print("1. ORIGINAL DATA (No shuffling)")
    print(f"{'='*60}\n")

    train_dataset = DREAMERDataset(data_path, task=task, split='train', segment_length=384)
    test_dataset = DREAMERDataset(data_path, task=task, split='test', segment_length=384)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    print("Training CNN on original data...")
    cnn_model = SimpleCNN().to(device)
    cnn_original = train_model(cnn_model, train_loader, test_loader, device, num_epochs)
    results['CNN_original'] = cnn_original
    print(f"CNN Original: {cnn_original:.2f}%\n")

    print("Training EEGDeformer on original data...")
    deformer_model = Deformer(
        num_chan=14, num_time=384, temporal_kernel=13, num_kernel=64,
        num_classes=2, depth=4, heads=16, mlp_dim=16, dim_head=16, dropout=0.5
    ).to(device)
    deformer_original = train_model(deformer_model, train_loader, test_loader, device, num_epochs)
    results['EEGDeformer_original'] = deformer_original
    print(f"EEGDeformer Original: {deformer_original:.2f}%\n")

    shuffle_types = [
        ('random', 'Randomly shuffled time points'),
        ('reverse', 'Reversed time dimension'),
        ('block', 'Swapped first/second half')
    ]

    for shuffle_type, description in shuffle_types:
        print(f"\n{'='*60}")
        print(f"2. {description.upper()}")
        print(f"{'='*60}\n")

        train_shuffled = ShuffledDREAMERDataset(train_dataset, shuffle_type)
        test_shuffled = ShuffledDREAMERDataset(test_dataset, shuffle_type)

        train_loader_shuffled = DataLoader(train_shuffled, batch_size=32, shuffle=True)
        test_loader_shuffled = DataLoader(test_shuffled, batch_size=32, shuffle=False)

        print(f"Training CNN on {shuffle_type} shuffled data...")
        cnn_model_shuffled = SimpleCNN().to(device)
        cnn_shuffled = train_model(cnn_model_shuffled, train_loader_shuffled,
                                   test_loader_shuffled, device, num_epochs)
        results[f'CNN_{shuffle_type}'] = cnn_shuffled
        print(f"CNN {shuffle_type}: {cnn_shuffled:.2f}%")
        print(f"  Change: {cnn_shuffled - cnn_original:+.2f}%\n")

        print(f"Training EEGDeformer on {shuffle_type} shuffled data...")
        deformer_model_shuffled = Deformer(
            num_chan=14, num_time=384, temporal_kernel=13, num_kernel=64,
            num_classes=2, depth=4, heads=16, mlp_dim=16, dim_head=16, dropout=0.5
        ).to(device)
        deformer_shuffled = train_model(deformer_model_shuffled, train_loader_shuffled,
                                       test_loader_shuffled, device, num_epochs)
        results[f'EEGDeformer_{shuffle_type}'] = deformer_shuffled
        print(f"EEGDeformer {shuffle_type}: {deformer_shuffled:.2f}%")
        print(f"  Change: {deformer_shuffled - deformer_original:+.2f}%\n")

    print(f"\n{'='*80}")
    print("TEMPORAL ORDER ANALYSIS SUMMARY")
    print(f"{'='*80}\n")

    print(f"{'Condition':<30} {'CNN':<12} {'EEGDeformer':<12} {'Difference'}")
    print(f"{'-'*80}")

    print(f"{'Original (No shuffle)':<30} {cnn_original:<11.2f}% {deformer_original:<11.2f}% "
          f"{deformer_original - cnn_original:+.2f}%")

    for shuffle_type, description in shuffle_types:
        cnn_acc = results[f'CNN_{shuffle_type}']
        deformer_acc = results[f'EEGDeformer_{shuffle_type}']
        print(f"{description:<30} {cnn_acc:<11.2f}% {deformer_acc:<11.2f}% "
              f"{deformer_acc - cnn_acc:+.2f}%")

    print(f"\n{'-'*80}")
    print("Performance Drops from Original:")
    print(f"{'-'*80}")

    for shuffle_type, description in shuffle_types:
        cnn_drop = results[f'CNN_{shuffle_type}'] - cnn_original
        deformer_drop = results[f'EEGDeformer_{shuffle_type}'] - deformer_original
        print(f"{description:<30} CNN: {cnn_drop:+.2f}%  Deformer: {deformer_drop:+.2f}%")

    print(f"\n{'='*80}")
    print("INTERPRETATION:")
    print(f"{'='*80}")

    avg_cnn_drop = np.mean([results[f'CNN_{st}'] - cnn_original for st, _ in shuffle_types])
    avg_deformer_drop = np.mean([results[f'EEGDeformer_{st}'] - deformer_original
                                 for st, _ in shuffle_types])

    if abs(avg_cnn_drop) < 2 and abs(avg_deformer_drop) < 2:
        print("✓ Temporal order does NOT matter (<2% drop)")
        print("  → Models learn frequency/power features, not temporal dynamics")
        print("  → This explains why CNN ≈ Transformer!")
    elif abs(avg_cnn_drop) < abs(avg_deformer_drop):
        print("✓ Temporal order matters MORE for Transformer")
        print(f"  CNN drop: {avg_cnn_drop:.2f}%")
        print(f"  Transformer drop: {avg_deformer_drop:.2f}%")
        print("  → Transformer learns temporal patterns CNN ignores")
    else:
        print("✓ Temporal order matters MORE for CNN")
        print(f"  CNN drop: {avg_cnn_drop:.2f}%")
        print(f"  Transformer drop: {avg_deformer_drop:.2f}%")
        print("  → CNN's convolutions encode temporal structure")

    print(f"{'='*80}\n")

    output = {
        'task': task,
        'num_epochs': num_epochs,
        'results': results,
        'analysis': {
            'avg_cnn_drop': avg_cnn_drop,
            'avg_deformer_drop': avg_deformer_drop,
            'temporal_matters': abs(avg_cnn_drop) > 2 or abs(avg_deformer_drop) > 2
        }
    }

    output_file = f'temporal_order_analysis_{task}.json'

    def convert_to_json_serializable(obj):
        if isinstance(obj, dict):
            return {k: convert_to_json_serializable(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [convert_to_json_serializable(item) for item in obj]
        elif isinstance(obj, (np.bool_, bool)):
            return bool(obj)
        elif isinstance(obj, (np.integer, np.int64)):
            return int(obj)
        elif isinstance(obj, (np.floating, np.float64)):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return obj

    output = convert_to_json_serializable(output)

    with open(output_file, 'w') as f:
        json.dump(output, f, indent=4)

    print(f"Results saved to {output_file}\n")

    return results

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--data_path', type=str, default='DREAMER.mat')
parser.add_argument('--task', type=str, default='valence')
parser.add_argument('--epochs', type=int, default=30)

args, unknown = parser.parse_known_args()
temporal_order_analysis(args.data_path, args.task, args.epochs)
# Out:
# Using device: cuda
#
# ================================================================================
# TEMPORAL ORDER ANALYSIS - VALENCE
# ================================================================================
#
# ============================================================
# 1. ORIGINAL DATA (No shuffling)
# ============================================================
#
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [33299 23281]
# Loading DREAMER dataset from DREAMER.mat...
# Processing 23 subjects...
# Generated 56580 segments
# Label distribution: [33299 23281]
# Training CNN on original data...
#   Epoch 10: Test Acc = 70.27%, Best = 71.37%
#   Epoch 20: Test Acc = 67.32%, Best = 73.42%
#   Epoch 30: Test Acc = 74.86%, Best = 75.42%
# CNN Original: 75.42%
#
# Training EEGDeformer on original data...
#   Epoch 10: Test Acc = 71.39%, Best = 72.18%
#   Epoch 20: Test Acc = 72.80%, Best = 73.52%
#   Epoch 30: Test Acc = 73.39%, Best = 74.09%
# EEGDeformer Original: 74.09%
#
#
# ============================================================
# 2. RANDOMLY SHUFFLED TIME POINTS
# ============================================================
#
# Training CNN on random shuffled data...
#   Epoch 10: Test Acc = 52.70%, Best = 58.85%
#   Epoch 20: Test Acc = 51.30%, Best = 58.85%
#   Epoch 30: Test Acc = 52.52%, Best = 58.85%
# CNN random: 58.85%
#   Change: -16.56%
#
# Training EEGDeformer on random shuffled data...

# %% [markdown]
# # Noise Robustness Experiment

# %% [markdown]
# Create Dataset for SNR

# %%
import os, pickle
import numpy as np
from tqdm import tqdm

def add_gaussian_noise(trial, snr_db):
    # trial shape: (Channels, Time)
    sig_avg_watts = np.mean(np.square(trial))
    sig_avg_db = 10 * np.log10(sig_avg_watts)
    noise_avg_db = sig_avg_db - snr_db
    noise_avg_watts = 10 ** (noise_avg_db / 10)
    noise_volts = np.random.normal(0, np.sqrt(noise_avg_watts), trial.shape)
    return trial + noise_volts

base_dir = '/content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_FTG'
snr_levels = [20, 10, 5]

for snr in snr_levels:
    output_dir = f'/content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_SNR_{snr}'
    os.makedirs(output_dir, exist_ok=True)
    print(f"\n--- Generating data for SNR: {snr}dB ---")

    subject_files = [f for f in os.listdir(base_dir) if f.startswith('sub') and f.endswith('.pkl')]

    for filename in tqdm(subject_files):
        with open(os.path.join(base_dir, filename), 'rb') as f:
            content = pickle.load(f)

        # content['data'] shape is (Trials, Channels, Time)
        noisy_data = np.array([add_gaussian_noise(trial, snr) for trial in content['data']])

        save_dict = {'data': noisy_data, 'label': content['label']}
        with open(os.path.join(output_dir, filename), 'wb') as f:
            pickle.dump(save_dict, f)

    import shutil
    shutil.copy(os.path.join(base_dir, 'dataset_info.pkl'), os.path.join(output_dir, 'dataset_info.pkl'))
# Out:
# --- Generating data for SNR: 20dB ---
# 100%|██████████| 11/11 [00:02<00:00,  4.37it/s]
# --- Generating data for SNR: 10dB ---
# 100%|██████████| 11/11 [00:02<00:00,  4.90it/s]
# --- Generating data for SNR: 5dB ---
# 100%|██████████| 11/11 [00:03<00:00,  3.32it/s]

# %%
# %cd /content/EEG-Deformer/EEG-Deformer/

#  SNR 20 (Mild Noise)
# !rm -rf ./data_processed/data_eeg_FATIG_FTG
# !ln -s /content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_SNR_20 ./data_processed/data_eeg_FATIG_FTG
# !python main_FATIG.py --model Deformer --full-run 1 --save-path ./save/SNR_20

#  Run SNR 10 (Real-world Noise)
# !rm -rf ./data_processed/data_eeg_FATIG_FTG
# !ln -s /content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_SNR_10 ./data_processed/data_eeg_FATIG_FTG
# !python main_FATIG.py --model Deformer --full-run 1 --save-path ./save/SNR_10

# Run SNR 5 (Heavy Noise)
# !rm -rf ./data_processed/data_eeg_FATIG_FTG
# !ln -s /content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_SNR_5 ./data_processed/data_eeg_FATIG_FTG
# !python main_FATIG.py --model Deformer --full-run 1 --save-path ./save/SNR_5
# Out:
# Epoch 74: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.492, val_acc=0.895, val_f1=0.891, train_loss=0.0455, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.39it/s]
# Epoch 75: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.460, val_acc=0.893, val_f1=0.889, train_loss=0.0388, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.78it/s]
# Epoch 76: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.546, val_acc=0.889, val_f1=0.884, train_loss=0.0321, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 73.18it/s]
# Epoch 77: 100% 35/35 [00:03<00:00, 10.19it/s, v_num=ub40, val_loss=0.573, val_acc=0.878, val_f1=0.871, train_loss=0.0366, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.88it/s]
# Epoch 78: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.482, val_acc=0.902, val_f1=0.898, train_loss=0.0377, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.00it/s]
# Epoch 79: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.762, val_acc=0.826, val_f1=0.807, train_loss=0.0405, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.70it/s]
# Epoch 80: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.487, val_acc=0.889, val_f1=0.884, train_loss=0.0405, train_acc=0.985, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.14it/s]
# Epoch 81: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.553, val_acc=0.877, val_f1=0.870, train_loss=0.0485, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.63it/s]
# Epoch 82: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.626, val_acc=0.869, val_f1=0.861, train_loss=0.0488, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.58it/s]
# Epoch 83: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.430, val_acc=0.900, val_f1=0.898, train_loss=0.0671, train_acc=0.973, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.71it/s]
# Epoch 84: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.467, val_acc=0.891, val_f1=0.886, train_loss=0.0454, train_acc=0.980, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.71it/s]
# Epoch 85: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.537, val_acc=0.889, val_f1=0.883, train_loss=0.0357, train_acc=0.987, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.11it/s]
# Epoch 86: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.489, val_acc=0.898, val_f1=0.893, train_loss=0.0374, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.05it/s]
# Epoch 87: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.470, val_acc=0.902, val_f1=0.899, train_loss=0.036, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 71.85it/s]
# Epoch 88: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.543, val_acc=0.898, val_f1=0.894, train_loss=0.0371, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.14it/s]
# Epoch 89: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.538, val_acc=0.893, val_f1=0.887, train_loss=0.041, train_acc=0.983, train_f1=0.982]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.19it/s]
# Epoch 90: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.585, val_acc=0.878, val_f1=0.871, train_loss=0.042, train_acc=0.985, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.70it/s]
# Epoch 91: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.540, val_acc=0.882, val_f1=0.876, train_loss=0.0381, train_acc=0.985, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.36it/s]
# Epoch 92: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=ub40, val_loss=0.542, val_acc=0.887, val_f1=0.881, train_loss=0.0404, train_acc=0.983, train_f1=0.982]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.61it/s]
# Epoch 93: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.681, val_acc=0.853, val_f1=0.842, train_loss=0.0346, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.10it/s]
# Epoch 94: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.637, val_acc=0.862, val_f1=0.852, train_loss=0.0376, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.68it/s]
# Epoch 95: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.527, val_acc=0.891, val_f1=0.886, train_loss=0.037, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.86it/s]
# Epoch 96: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.475, val_acc=0.893, val_f1=0.888, train_loss=0.0327, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.76it/s]
# Epoch 97: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.530, val_acc=0.887, val_f1=0.882, train_loss=0.0249, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.39it/s]
# Epoch 98: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.540, val_acc=0.886, val_f1=0.880, train_loss=0.0299, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.13it/s]
# Epoch 99: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.516, val_acc=0.898, val_f1=0.894, train_loss=0.0255, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.31it/s]
# Epoch 100: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.558, val_acc=0.891, val_f1=0.886, train_loss=0.0325, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 71.19it/s]
# Epoch 101: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.455, val_acc=0.907, val_f1=0.905, train_loss=0.0338, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.78it/s]
# Epoch 102: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.512, val_acc=0.891, val_f1=0.887, train_loss=0.029, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.61it/s]
# Epoch 103: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.503, val_acc=0.895, val_f1=0.891, train_loss=0.0324, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.00it/s]
# Epoch 104: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.477, val_acc=0.907, val_f1=0.905, train_loss=0.0267, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.61it/s]
# Epoch 105: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.568, val_acc=0.884, val_f1=0.877, train_loss=0.0216, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.41it/s]
# Epoch 106: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.545, val_acc=0.887, val_f1=0.883, train_loss=0.0297, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.19it/s]
# Epoch 107: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.531, val_acc=0.904, val_f1=0.900, train_loss=0.0246, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.95it/s]
# Epoch 108: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.507, val_acc=0.891, val_f1=0.887, train_loss=0.0239, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.32it/s]
# Epoch 109: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.585, val_acc=0.880, val_f1=0.872, train_loss=0.0268, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.95it/s]
# Epoch 110: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.529, val_acc=0.900, val_f1=0.897, train_loss=0.0336, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.46it/s]
# Epoch 111: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.485, val_acc=0.895, val_f1=0.891, train_loss=0.0275, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.82it/s]
# Epoch 112: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.508, val_acc=0.902, val_f1=0.898, train_loss=0.0287, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.61it/s]
# Epoch 113: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.560, val_acc=0.893, val_f1=0.887, train_loss=0.0191, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.05it/s]
# Epoch 114: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.546, val_acc=0.893, val_f1=0.889, train_loss=0.0273, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.36it/s]
# Epoch 115: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.487, val_acc=0.895, val_f1=0.891, train_loss=0.028, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.96it/s]
# Epoch 116: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.541, val_acc=0.895, val_f1=0.890, train_loss=0.0261, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.34it/s]
# Epoch 117: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.643, val_acc=0.869, val_f1=0.862, train_loss=0.0211, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 70.14it/s]
# Epoch 118: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.470, val_acc=0.907, val_f1=0.904, train_loss=0.0222, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.99it/s]
# Epoch 119: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.469, val_acc=0.902, val_f1=0.899, train_loss=0.0267, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.53it/s]
# Epoch 120: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.560, val_acc=0.891, val_f1=0.886, train_loss=0.0207, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.61it/s]
# Epoch 121: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.569, val_acc=0.882, val_f1=0.875, train_loss=0.0211, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.39it/s]
# Epoch 122: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.515, val_acc=0.897, val_f1=0.892, train_loss=0.0153, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.43it/s]
# Epoch 123: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.569, val_acc=0.895, val_f1=0.890, train_loss=0.0207, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.99it/s]
# Epoch 124: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.642, val_acc=0.869, val_f1=0.861, train_loss=0.0184, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.85it/s]
# Epoch 125: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.553, val_acc=0.893, val_f1=0.888, train_loss=0.0142, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.33it/s]
# Epoch 126: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.594, val_acc=0.884, val_f1=0.877, train_loss=0.0203, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.85it/s]
# Epoch 127: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.560, val_acc=0.895, val_f1=0.890, train_loss=0.0186, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.48it/s]
# Epoch 128: 100% 35/35 [00:03<00:00, 10.19it/s, v_num=ub40, val_loss=0.570, val_acc=0.897, val_f1=0.892, train_loss=0.0176, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 56.76it/s]
# Epoch 129: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=ub40, val_loss=0.561, val_acc=0.889, val_f1=0.884, train_loss=0.0172, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.90it/s]
# Epoch 130: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.587, val_acc=0.886, val_f1=0.880, train_loss=0.0203, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.46it/s]
# Epoch 131: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.581, val_acc=0.895, val_f1=0.890, train_loss=0.0215, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 73.02it/s]
# Epoch 132: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.601, val_acc=0.891, val_f1=0.885, train_loss=0.020, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.96it/s]
# Epoch 133: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.505, val_acc=0.902, val_f1=0.899, train_loss=0.0191, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.18it/s]
# Epoch 134: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.659, val_acc=0.875, val_f1=0.867, train_loss=0.0184, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.76it/s]
# Epoch 135: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.678, val_acc=0.860, val_f1=0.849, train_loss=0.0204, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.05it/s]
# Epoch 136: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.497, val_acc=0.904, val_f1=0.900, train_loss=0.0192, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.43it/s]
# Epoch 137: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.580, val_acc=0.893, val_f1=0.887, train_loss=0.020, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.55it/s]
# Epoch 138: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.539, val_acc=0.895, val_f1=0.890, train_loss=0.0173, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.06it/s]
# Epoch 139: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.549, val_acc=0.898, val_f1=0.894, train_loss=0.0134, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.34it/s]
# Epoch 140: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.538, val_acc=0.897, val_f1=0.892, train_loss=0.0121, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.31it/s]
# Epoch 141: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.616, val_acc=0.893, val_f1=0.888, train_loss=0.0146, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.34it/s]
# Epoch 142: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.604, val_acc=0.900, val_f1=0.895, train_loss=0.011, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 72.63it/s]
# Epoch 143: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.601, val_acc=0.884, val_f1=0.878, train_loss=0.0158, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.96it/s]
# Epoch 144: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.546, val_acc=0.895, val_f1=0.891, train_loss=0.0155, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.94it/s]
# Epoch 145: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.592, val_acc=0.897, val_f1=0.892, train_loss=0.0122, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.14it/s]
# Epoch 146: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.734, val_acc=0.868, val_f1=0.858, train_loss=0.0134, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.96it/s]
# Epoch 147: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.598, val_acc=0.891, val_f1=0.886, train_loss=0.0132, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.02it/s]
# Epoch 148: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.528, val_acc=0.897, val_f1=0.892, train_loss=0.0123, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.53it/s]
# Epoch 149: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.627, val_acc=0.897, val_f1=0.891, train_loss=0.0156, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.07it/s]
# Epoch 150: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.569, val_acc=0.886, val_f1=0.880, train_loss=0.012, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.07it/s]
# Epoch 151: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.529, val_acc=0.897, val_f1=0.892, train_loss=0.0108, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.44it/s]
# Epoch 152: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.547, val_acc=0.898, val_f1=0.894, train_loss=0.0154, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.25it/s]
# Epoch 153: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.530, val_acc=0.897, val_f1=0.893, train_loss=0.0119, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.78it/s]
# Epoch 154: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.562, val_acc=0.900, val_f1=0.896, train_loss=0.0106, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.72it/s]
# Epoch 155: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.598, val_acc=0.897, val_f1=0.892, train_loss=0.0119, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.17it/s]
# Epoch 156: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.583, val_acc=0.889, val_f1=0.885, train_loss=0.0114, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.02it/s]
# Epoch 157: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.602, val_acc=0.891, val_f1=0.886, train_loss=0.00826, train_acc=0.999, train_f1=0.999]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.34it/s]
# Epoch 158: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.530, val_acc=0.904, val_f1=0.901, train_loss=0.00877, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.89it/s]
# Epoch 159: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.604, val_acc=0.891, val_f1=0.886, train_loss=0.0149, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.07it/s]
# Epoch 160: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.602, val_acc=0.889, val_f1=0.884, train_loss=0.0186, train_acc=0.993, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.33it/s]
# Epoch 161: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.635, val_acc=0.889, val_f1=0.883, train_loss=0.0119, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.58it/s]
# Epoch 162: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.751, val_acc=0.862, val_f1=0.851, train_loss=0.015, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.24it/s]
# Epoch 163: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.705, val_acc=0.880, val_f1=0.873, train_loss=0.0153, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.81it/s]
# Epoch 164: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.591, val_acc=0.889, val_f1=0.884, train_loss=0.0111, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.00it/s]
# Epoch 165: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.719, val_acc=0.875, val_f1=0.866, train_loss=0.0159, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.10it/s]
# Epoch 166: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.539, val_acc=0.891, val_f1=0.887, train_loss=0.0126, train_acc=0.996, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.20it/s]
# Epoch 167: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.628, val_acc=0.889, val_f1=0.883, train_loss=0.0105, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.58it/s]
# Epoch 168: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.548, val_acc=0.891, val_f1=0.887, train_loss=0.00959, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.67it/s]
# Epoch 169: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.613, val_acc=0.895, val_f1=0.889, train_loss=0.00596, train_acc=0.999, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.08it/s]
# Epoch 170: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.559, val_acc=0.895, val_f1=0.890, train_loss=0.00624, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.74it/s]
# Epoch 171: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.627, val_acc=0.891, val_f1=0.885, train_loss=0.00938, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 72.21it/s]
# Epoch 172: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.531, val_acc=0.897, val_f1=0.893, train_loss=0.0068, train_acc=0.999, train_f1=0.999]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.66it/s]
# Epoch 173: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.535, val_acc=0.898, val_f1=0.894, train_loss=0.0105, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.35it/s]
# Epoch 174: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.529, val_acc=0.895, val_f1=0.891, train_loss=0.0127, train_acc=0.996, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.31it/s]
# Epoch 175: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.653, val_acc=0.882, val_f1=0.875, train_loss=0.00743, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.86it/s]
# Epoch 176: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.583, val_acc=0.889, val_f1=0.884, train_loss=0.0113, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.58it/s]
# Epoch 177: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.542, val_acc=0.895, val_f1=0.891, train_loss=0.00854, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.37it/s]
# Epoch 178: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.597, val_acc=0.891, val_f1=0.886, train_loss=0.0138, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.49it/s]
# Epoch 179: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.590, val_acc=0.893, val_f1=0.888, train_loss=0.00681, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.80it/s]
# Epoch 180: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.532, val_acc=0.891, val_f1=0.887, train_loss=0.011, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.99it/s]
# Epoch 181: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.593, val_acc=0.897, val_f1=0.892, train_loss=0.0153, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.95it/s]
# Epoch 182: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=ub40, val_loss=0.505, val_acc=0.898, val_f1=0.895, train_loss=0.0087, train_acc=0.997, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.54it/s]
# Epoch 183: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.666, val_acc=0.882, val_f1=0.875, train_loss=0.00917, train_acc=0.999, train_f1=0.999]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.84it/s]
# Epoch 184: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.688, val_acc=0.873, val_f1=0.865, train_loss=0.00965, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.24it/s]
# Epoch 185: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.641, val_acc=0.893, val_f1=0.887, train_loss=0.0119, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.39it/s]
# Epoch 186: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.526, val_acc=0.900, val_f1=0.896, train_loss=0.00865, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.19it/s]
# Epoch 187: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.582, val_acc=0.893, val_f1=0.888, train_loss=0.00965, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.57it/s]
# Epoch 188: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.623, val_acc=0.891, val_f1=0.885, train_loss=0.00921, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.88it/s]
# Epoch 189: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.564, val_acc=0.897, val_f1=0.892, train_loss=0.00855, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.25it/s]
# Epoch 190: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.537, val_acc=0.898, val_f1=0.894, train_loss=0.00646, train_acc=1.000, train_f1=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.76it/s]
# Epoch 191: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.522, val_acc=0.898, val_f1=0.895, train_loss=0.010, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.63it/s]
# Epoch 192: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.631, val_acc=0.893, val_f1=0.887, train_loss=0.0121, train_acc=0.997, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.69it/s]
# Epoch 193: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=ub40, val_loss=0.574, val_acc=0.897, val_f1=0.892, train_loss=0.00986, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 72.94it/s]
# Epoch 194: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.634, val_acc=0.893, val_f1=0.887, train_loss=0.00723, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.03it/s]
# Epoch 195: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.547, val_acc=0.897, val_f1=0.892, train_loss=0.00958, train_acc=0.997, train_f1=0.997]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.95it/s]
# Epoch 196: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.650, val_acc=0.886, val_f1=0.879, train_loss=0.00769, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.41it/s]
# Epoch 197: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=ub40, val_loss=0.593, val_acc=0.891, val_f1=0.886, train_loss=0.0128, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.57it/s]
# Epoch 198: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.688, val_acc=0.880, val_f1=0.873, train_loss=0.00738, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.69it/s]
# Epoch 199: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.571, val_acc=0.893, val_f1=0.888, train_loss=0.00857, train_acc=0.998, train_f1=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.57it/s]
# Epoch 199: 100% 35/35 [00:03<00:00,  9.73it/s, v_num=ub40, val_loss=0.596, val_acc=0.891, val_f1=0.886, train_loss=0.012, train_acc=0.996, train_f1=0.996]  `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199: 100% 35/35 [00:03<00:00,  9.73it/s, v_num=ub40, val_loss=0.596, val_acc=0.891, val_f1=0.886, train_loss=0.012, train_acc=0.996, train_f1=0.996]
# Loading best model weights from: ./save/SNR_20/logs_FATIG_Deformer/sub40/checkpoints/epoch=60-step=2135.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 1/1 [00:00<00:00, 29.99it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7839195728302002     │
# │          test_f1          │    0.7833725214004517     │
# │         test_loss         │    1.2100225687026978     │
# └───────────────────────────┴───────────────────────────┘
# Data has been logged to ./save/SNR_20/logs_FATIG_Deformer/sub40/result.csv
# Global seed set to 2023
# Train:(2238, 30, 384) Val:(560, 30, 384) Test:(154, 30, 384)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type               | Params
# --------------------------------------------
# 0 | net  | Deformer           | 542 K
# 1 | acc  | MulticlassAccuracy | 0
# 2 | F1   | MulticlassF1Score  | 0
# --------------------------------------------
# 542 K     Trainable params
# 0         Non-trainable params
# 542 K     Total params
# 2.172     Total estimated model params size (MB)
# Epoch 0: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 48.73it/s]
# Epoch 1: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.617, val_acc=0.675, val_f1=0.604, train_loss=0.725, train_acc=0.596, train_f1=0.534]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.52it/s]
# Epoch 2: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.535, val_acc=0.721, val_f1=0.664, train_loss=0.607, train_acc=0.682, train_f1=0.656]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.21it/s]
# Epoch 3: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.664, val_acc=0.705, val_f1=0.610, train_loss=0.482, train_acc=0.777, train_f1=0.762]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.23it/s]
# Epoch 4: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.370, val_acc=0.852, val_f1=0.843, train_loss=0.419, train_acc=0.826, train_f1=0.817]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.86it/s]
# Epoch 5: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.493, val_acc=0.779, val_f1=0.731, train_loss=0.368, train_acc=0.851, train_f1=0.843]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.36it/s]
# Epoch 6: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub41, val_loss=0.460, val_acc=0.816, val_f1=0.787, train_loss=0.333, train_acc=0.860, train_f1=0.853]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.51it/s]
# Epoch 7: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub41, val_loss=0.414, val_acc=0.823, val_f1=0.800, train_loss=0.322, train_acc=0.866, train_f1=0.858]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 43.63it/s]
# Epoch 8: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.414, val_acc=0.834, val_f1=0.808, train_loss=0.317, train_acc=0.870, train_f1=0.863]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.72it/s]
# Epoch 9: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub41, val_loss=0.311, val_acc=0.886, val_f1=0.876, train_loss=0.299, train_acc=0.877, train_f1=0.870]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.37it/s]
# Epoch 10: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub41, val_loss=0.404, val_acc=0.850, val_f1=0.829, train_loss=0.282, train_acc=0.891, train_f1=0.885]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.46it/s]
# Epoch 11: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub41, val_loss=0.406, val_acc=0.854, val_f1=0.837, train_loss=0.267, train_acc=0.891, train_f1=0.886]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.18it/s]
# Epoch 12: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub41, val_loss=0.348, val_acc=0.871, val_f1=0.862, train_loss=0.239, train_acc=0.899, train_f1=0.894]
# ...
# Epoch 44: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.376, val_acc=0.884, val_f1=0.879, train_loss=0.130, train_acc=0.947, train_f1=0.944]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.73it/s]
# Epoch 45: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.387, val_acc=0.884, val_f1=0.881, train_loss=0.133, train_acc=0.949, train_f1=0.946]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.50it/s]
# Epoch 46: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.405, val_acc=0.890, val_f1=0.887, train_loss=0.130, train_acc=0.946, train_f1=0.943]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.30it/s]
# Epoch 47: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.399, val_acc=0.875, val_f1=0.870, train_loss=0.110, train_acc=0.957, train_f1=0.955]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.14it/s]
# Epoch 48: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.391, val_acc=0.884, val_f1=0.880, train_loss=0.120, train_acc=0.951, train_f1=0.947]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.39it/s]
# Epoch 49: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.396, val_acc=0.892, val_f1=0.888, train_loss=0.113, train_acc=0.957, train_f1=0.955]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.43it/s]
# Epoch 50: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=sub0, val_loss=0.358, val_acc=0.881, val_f1=0.877, train_loss=0.119, train_acc=0.951, train_f1=0.949]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.05it/s]
# Epoch 51: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.543, val_acc=0.850, val_f1=0.838, train_loss=0.114, train_acc=0.953, train_f1=0.951]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.43it/s]
# Epoch 52: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.421, val_acc=0.864, val_f1=0.856, train_loss=0.111, train_acc=0.953, train_f1=0.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.82it/s]
# Epoch 53: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.459, val_acc=0.864, val_f1=0.855, train_loss=0.118, train_acc=0.952, train_f1=0.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.20it/s]
# Epoch 54: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.400, val_acc=0.893, val_f1=0.889, train_loss=0.101, train_acc=0.962, train_f1=0.959]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.75it/s]
# Epoch 55: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.356, val_acc=0.893, val_f1=0.890, train_loss=0.108, train_acc=0.959, train_f1=0.957]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.97it/s]
# Epoch 56: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.528, val_acc=0.846, val_f1=0.835, train_loss=0.103, train_acc=0.962, train_f1=0.960]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.32it/s]
# Epoch 57: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=sub0, val_loss=0.388, val_acc=0.892, val_f1=0.887, train_loss=0.094, train_acc=0.966, train_f1=0.964]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.05it/s]
# Epoch 58: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.465, val_acc=0.877, val_f1=0.870, train_loss=0.085, train_acc=0.969, train_f1=0.968]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.75it/s]
# Epoch 59: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.394, val_acc=0.890, val_f1=0.885, train_loss=0.0811, train_acc=0.970, train_f1=0.969]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.38it/s]
# Epoch 60: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.405, val_acc=0.895, val_f1=0.891, train_loss=0.0796, train_acc=0.969, train_f1=0.968]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.47it/s]
# Epoch 61: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.467, val_acc=0.866, val_f1=0.858, train_loss=0.0879, train_acc=0.965, train_f1=0.962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.08it/s]
# Epoch 62: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.469, val_acc=0.872, val_f1=0.865, train_loss=0.106, train_acc=0.959, train_f1=0.957]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.46it/s]
# Epoch 63: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.486, val_acc=0.868, val_f1=0.861, train_loss=0.0843, train_acc=0.967, train_f1=0.966]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.34it/s]
# Epoch 64:   0% 0/35 [00:00<?, ?it/s, v_num=sub0, val_loss=0.589, val_acc=0.859, val_f1=0.850, train_loss=0.094, train_acc=0.965, train_f1=0.963]/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/call.py:53: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# Loading best model weights from: ./save/SNR_5/logs_FATIG_Deformer/sub0/checkpoints/epoch=15-step=560.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 1/1 [00:00<00:00, 31.32it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.8324607610702515     │
# │          test_f1          │    0.8322353959083557     │
# │         test_loss         │    0.39352861046791077    │
# └───────────────────────────┴───────────────────────────┘
# Data has been logged to ./save/SNR_5/logs_FATIG_Deformer/sub0/result.csv
# Global seed set to 2023
# Train:(2019, 30, 384) Val:(505, 30, 384) Test:(428, 30, 384)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type               | Params
# --------------------------------------------
# 0 | net  | Deformer           | 542 K
# 1 | acc  | MulticlassAccuracy | 0
# 2 | F1   | MulticlassF1Score  | 0
# --------------------------------------------
# 542 K     Trainable params
# 0         Non-trainable params
# 542 K     Total params
# 2.172     Total estimated model params size (MB)
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:281: PossibleUserWarning: The number of training batches (32) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0: 100% 32/32 [00:03<00:00, 10.11it/s, v_num=sub4]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 60.63it/s]
# Epoch 1: 100% 32/32 [00:03<00:00, 10.20it/s, v_num=sub4, val_loss=0.751, val_acc=0.687, val_f1=0.676, train_loss=0.714, train_acc=0.609, train_f1=0.574]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.97it/s]
# Epoch 2: 100% 32/32 [00:03<00:00, 10.09it/s, v_num=sub4, val_loss=0.662, val_acc=0.697, val_f1=0.682, train_loss=0.609, train_acc=0.694, train_f1=0.679]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.76it/s]
# Epoch 3: 100% 32/32 [00:03<00:00, 10.18it/s, v_num=sub4, val_loss=0.973, val_acc=0.610, val_f1=0.536, train_loss=0.496, train_acc=0.773, train_f1=0.766]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.92it/s]
# Epoch 4: 100% 32/32 [00:03<00:00, 10.18it/s, v_num=sub4, val_loss=0.645, val_acc=0.725, val_f1=0.706, train_loss=0.454, train_acc=0.799, train_f1=0.795]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 60.40it/s]
# Epoch 5: 100% 32/32 [00:03<00:00, 10.18it/s, v_num=sub4, val_loss=0.455, val_acc=0.802, val_f1=0.799, train_loss=0.411, train_acc=0.812, train_f1=0.809]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 50.88it/s]
# Epoch 6: 100% 32/32 [00:03<00:00, 10.09it/s, v_num=sub4, val_loss=0.555, val_acc=0.770, val_f1=0.761, train_loss=0.385, train_acc=0.838, train_f1=0.835]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 63.93it/s]
# Epoch 7: 100% 32/32 [00:03<00:00, 10.17it/s, v_num=sub4, val_loss=0.594, val_acc=0.750, val_f1=0.737, train_loss=0.396, train_acc=0.832, train_f1=0.828]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.72it/s]
# Epoch 8: 100% 32/32 [00:03<00:00, 10.16it/s, v_num=sub4, val_loss=0.569, val_acc=0.788, val_f1=0.782, train_loss=0.343, train_acc=0.847, train_f1=0.845]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 58.85it/s]
# Epoch 9: 100% 32/32 [00:03<00:00, 10.16it/s, v_num=sub4, val_loss=0.425, val_acc=0.812, val_f1=0.811, train_loss=0.353, train_acc=0.848, train_f1=0.845]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.91it/s]
# Epoch 10: 100% 32/32 [00:03<00:00, 10.18it/s, v_num=sub4, val_loss=0.518, val_acc=0.796, val_f1=0.789, train_loss=0.326, train_acc=0.874, train_f1=0.872]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.94it/s]
# Epoch 11: 100% 32/32 [00:03<00:00, 10.17it/s, v_num=sub4, val_loss=0.803, val_acc=0.691, val_f1=0.655, train_loss=0.312, train_acc=0.866, train_f1=0.864]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 56.63it/s]
# Epoch 12: 100% 32/32 [00:03<00:00, 10.17it/s, v_num=sub4, val_loss=0.550, val_acc=0.788, val_f1=0.781, train_loss=0.314, train_acc=0.864, train_f1=0.862]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.53it/s]
# Epoch 13: 100% 32/32 [00:03<00:00, 10.18it/s, v_num=sub4, val_loss=0.429, val_acc=0.818, val_f1=0.815, train_loss=0.295, train_acc=0.880, train_f1=0.877]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 58.31it/s]
# Epoch 14: 100% 32/32 [00:03<00:00, 10.20it/s, v_num=sub4, val_loss=0.859, val_acc=0.689, val_f1=0.652, train_loss=0.300, train_acc=0.880, train_f1=0.877]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.78it/s]
# Epoch 15: 100% 32/32 [00:03<00:00, 10.15it/s, v_num=sub4, val_loss=0.507, val_acc=0.786, val_f1=0.777, train_loss=0.278, train_acc=0.881, train_f1=0.879]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.90it/s]
# Epoch 16: 100% 32/32 [00:03<00:00, 10.21it/s, v_num=sub4, val_loss=0.766, val_acc=0.725, val_f1=0.700, train_loss=0.256, train_acc=0.899, train_f1=0.898]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.50it/s]
# Epoch 17: 100% 32/32 [00:03<00:00, 10.14it/s, v_num=sub4, val_loss=0.530, val_acc=0.816, val_f1=0.814, train_loss=0.249, train_acc=0.893, train_f1=0.891]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 57.00it/s]
# Epoch 18: 100% 32/32 [00:03<00:00, 10.19it/s, v_num=sub4, val_loss=0.431, val_acc=0.820, val_f1=0.818, train_loss=0.260, train_acc=0.896, train_f1=0.894]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:00<00:00, 59.56it/s]
# Epoch 19:   0% 0/32 [00:00<?, ?it/s, v_num=sub4, val_loss=0.443, val_acc=0.812, val_f1=0.810, train_loss=0.260, train_acc=0.893, train_f1=0.891][rank: 0] Received SIGTERM: 15
# [rank: 0] Received SIGTERM: 15
# Loading best model weights from: ./save/SNR_5/logs_FATIG_Deformer/sub4/checkpoints/epoch=17-step=576.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 1/1 [00:00<00:00, 15.88it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.5420560836791992     │
# │          test_f1          │    0.5015567541122437     │
# │         test_loss         │     1.433868408203125     │
# └───────────────────────────┴───────────────────────────┘
# Data has been logged to ./save/SNR_5/logs_FATIG_Deformer/sub4/result.csv
# Global seed set to 2023
# ^C

# %%
# !mkdir -p /content/drive/MyDrive/MVA/time-series-project/final_results/experiments


# !cp -r /content/EEG-Deformer/EEG-Deformer/save /content/drive/MyDrive/MVA/time-series-project/final_results/experiments/
# drive_results_path = "/content/drive/MyDrive/MVA/time-series-project/results_jan3"
# os.makedirs(drive_results_path, exist_ok=True)

# %%
drive_results_path = "/content/drive/MyDrive/MVA/time-series-project/results_final"
os.makedirs(drive_results_path, exist_ok=True)

snr_levels = ["20", "5"]

for snr in snr_levels:
    print(f"\nSTARTING EXPERIMENT: SNR {snr}dB")


    # !rm -rf /content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_FTG
    # !ln -s /content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_SNR_{snr} /content/EEG-Deformer/EEG-Deformer/data_processed/data_eeg_FATIG_FTG


    # !python main_FATIG.py --model Deformer --full-run 1 --save-path ./save/SNR_{snr}

    source = f"./save/SNR_{snr}"
    destination = os.path.join(drive_results_path, f"SNR_{snr}")
    # !cp -r {source} {destination}
    print(f"Saved SNR {snr} results to Drive.")

# %%
import os

workable_subs = [0, 21, 30, 40] # just run on the subjects from snr20 bc of computational expensiveness
snr_level = "SNR_5"

os.chdir("/content/EEG-Deformer/EEG-Deformer/")

for sub in workable_subs: # Python colon!
    print(f"Stress Testing Subject {sub} at {snr_level}...")

    # 1. Run the command
    # !python3 main_FATIG.py --model Deformer --full-run 0 --test-sub {sub} --save-path ./save/{snr_level}/sub{sub}

    # 2. Backup to Drive
    drive_path = f"/content/drive/MyDrive/MVA/time-series-project/results_final/{snr_level}/sub{sub}"
    os.makedirs(drive_path, exist_ok=True)

    # !cp ./save/{snr_level}/sub{sub}/result.csv {drive_path}/result.csv
    print(f"Sub {sub} results secured in Drive.")
# Out:
# 🔬 Stress Testing Subject 0 at SNR_5...
# Global seed set to 2023
# Train:(2208, 30, 384) Val:(553, 30, 384) Test:(191, 30, 384)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 2026-01-04 00:25:46.732433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767486346.752383   97991 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767486346.758534   97991 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767486346.774334   97991 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767486346.774361   97991 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767486346.774364   97991 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767486346.774368   97991 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-04 00:25:46.779343: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type               | Params
# --------------------------------------------
# 0 | net  | Deformer           | 542 K
# 1 | acc  | MulticlassAccuracy | 0
# 2 | F1   | MulticlassF1Score  | 0
# --------------------------------------------
# 542 K     Trainable params
# 0         Non-trainable params
# 542 K     Total params
# 2.172     Total estimated model params size (MB)
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:281: PossibleUserWarning: The number of training batches (35) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.72it/s]
# Epoch 1: 100% 35/35 [00:03<00:00, 10.70it/s, v_num=sub0, val_loss=0.706, val_acc=0.627, val_f1=0.519, train_loss=0.718, train_acc=0.597, train_f1=0.524]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.41it/s]
# Epoch 2: 100% 35/35 [00:03<00:00, 10.77it/s, v_num=sub0, val_loss=0.583, val_acc=0.702, val_f1=0.687, train_loss=0.640, train_acc=0.652, train_f1=0.610]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.93it/s]
# Epoch 3: 100% 35/35 [00:03<00:00, 10.76it/s, v_num=sub0, val_loss=0.514, val_acc=0.781, val_f1=0.776, train_loss=0.555, train_acc=0.718, train_f1=0.696]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.31it/s]
# Epoch 4: 100% 35/35 [00:03<00:00, 10.68it/s, v_num=sub0, val_loss=0.568, val_acc=0.772, val_f1=0.769, train_loss=0.480, train_acc=0.777, train_f1=0.759]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.42it/s]
# Epoch 5: 100% 35/35 [00:03<00:00, 10.63it/s, v_num=sub0, val_loss=0.689, val_acc=0.765, val_f1=0.761, train_loss=0.425, train_acc=0.817, train_f1=0.807]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.88it/s]
# Epoch 6: 100% 35/35 [00:03<00:00, 10.68it/s, v_num=sub0, val_loss=0.414, val_acc=0.817, val_f1=0.803, train_loss=0.409, train_acc=0.818, train_f1=0.810]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.13it/s]
# Epoch 7: 100% 35/35 [00:03<00:00, 10.64it/s, v_num=sub0, val_loss=0.367, val_acc=0.857, val_f1=0.850, train_loss=0.380, train_acc=0.836, train_f1=0.824]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.35it/s]
# Epoch 8: 100% 35/35 [00:03<00:00, 10.55it/s, v_num=sub0, val_loss=0.331, val_acc=0.861, val_f1=0.856, train_loss=0.349, train_acc=0.863, train_f1=0.857]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.30it/s]
# Epoch 9: 100% 35/35 [00:03<00:00, 10.53it/s, v_num=sub0, val_loss=0.449, val_acc=0.843, val_f1=0.840, train_loss=0.329, train_acc=0.866, train_f1=0.858]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.28it/s]
# Epoch 10: 100% 35/35 [00:03<00:00, 10.51it/s, v_num=sub0, val_loss=0.346, val_acc=0.859, val_f1=0.853, train_loss=0.331, train_acc=0.861, train_f1=0.854]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.76it/s]
# Epoch 11: 100% 35/35 [00:03<00:00, 10.51it/s, v_num=sub0, val_loss=0.373, val_acc=0.861, val_f1=0.856, train_loss=0.298, train_acc=0.885, train_f1=0.878]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.14it/s]
# Epoch 12: 100% 35/35 [00:03<00:00, 10.39it/s, v_num=sub0, val_loss=0.429, val_acc=0.850, val_f1=0.847, train_loss=0.309, train_acc=0.867, train_f1=0.860]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.02it/s]
# Epoch 13: 100% 35/35 [00:03<00:00, 10.46it/s, v_num=sub0, val_loss=0.335, val_acc=0.881, val_f1=0.876, train_loss=0.265, train_acc=0.890, train_f1=0.884]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.15it/s]
# Epoch 14: 100% 35/35 [00:03<00:00, 10.45it/s, v_num=sub0, val_loss=0.325, val_acc=0.886, val_f1=0.883, train_loss=0.292, train_acc=0.876, train_f1=0.869]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.25it/s]
# Epoch 15: 100% 35/35 [00:03<00:00, 10.42it/s, v_num=sub0, val_loss=0.354, val_acc=0.870, val_f1=0.866, train_loss=0.273, train_acc=0.893, train_f1=0.886]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.22it/s]
# Epoch 16: 100% 35/35 [00:03<00:00, 10.36it/s, v_num=sub0, val_loss=0.313, val_acc=0.897, val_f1=0.893, train_loss=0.264, train_acc=0.889, train_f1=0.884]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.30it/s]
# Epoch 17: 100% 35/35 [00:03<00:00, 10.32it/s, v_num=sub0, val_loss=0.356, val_acc=0.863, val_f1=0.855, train_loss=0.236, train_acc=0.905, train_f1=0.901]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.49it/s]
# Epoch 18: 100% 35/35 [00:03<00:00, 10.29it/s, v_num=sub0, val_loss=0.354, val_acc=0.850, val_f1=0.839, train_loss=0.249, train_acc=0.894, train_f1=0.887]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.89it/s]
# Epoch 19: 100% 35/35 [00:03<00:00, 10.19it/s, v_num=sub0, val_loss=0.319, val_acc=0.873, val_f1=0.869, train_loss=0.226, train_acc=0.916, train_f1=0.912]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.30it/s]
# Epoch 20: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.331, val_acc=0.882, val_f1=0.878, train_loss=0.243, train_acc=0.907, train_f1=0.901]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.96it/s]
# Epoch 21: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.325, val_acc=0.864, val_f1=0.857, train_loss=0.228, train_acc=0.909, train_f1=0.903]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.34it/s]
# Epoch 22: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=sub0, val_loss=0.442, val_acc=0.841, val_f1=0.827, train_loss=0.224, train_acc=0.906, train_f1=0.901]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.25it/s]
# Epoch 23: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.354, val_acc=0.886, val_f1=0.883, train_loss=0.198, train_acc=0.923, train_f1=0.919]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.87it/s]
# Epoch 24: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.420, val_acc=0.841, val_f1=0.826, train_loss=0.186, train_acc=0.924, train_f1=0.921]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.83it/s]
# Epoch 25: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.436, val_acc=0.843, val_f1=0.832, train_loss=0.218, train_acc=0.917, train_f1=0.912]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.06it/s]
# Epoch 26: 100% 35/35 [00:03<00:00, 10.05it/s, v_num=sub0, val_loss=0.444, val_acc=0.861, val_f1=0.858, train_loss=0.224, train_acc=0.906, train_f1=0.900]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.28it/s]
# Epoch 27: 100% 35/35 [00:03<00:00,  9.93it/s, v_num=sub0, val_loss=0.410, val_acc=0.868, val_f1=0.858, train_loss=0.187, train_acc=0.927, train_f1=0.924]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.94it/s]
# Epoch 28: 100% 35/35 [00:03<00:00, 10.04it/s, v_num=sub0, val_loss=0.328, val_acc=0.870, val_f1=0.864, train_loss=0.166, train_acc=0.941, train_f1=0.938]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.69it/s]
# Epoch 29: 100% 35/35 [00:03<00:00,  9.99it/s, v_num=sub0, val_loss=0.349, val_acc=0.875, val_f1=0.869, train_loss=0.176, train_acc=0.929, train_f1=0.925]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 55.74it/s]
# Epoch 30: 100% 35/35 [00:03<00:00,  9.88it/s, v_num=sub0, val_loss=0.351, val_acc=0.882, val_f1=0.879, train_loss=0.194, train_acc=0.914, train_f1=0.909]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.11it/s]
# Epoch 31: 100% 35/35 [00:03<00:00,  9.90it/s, v_num=sub0, val_loss=0.505, val_acc=0.839, val_f1=0.823, train_loss=0.171, train_acc=0.934, train_f1=0.931]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 54.14it/s]
# Epoch 32: 100% 35/35 [00:03<00:00,  9.92it/s, v_num=sub0, val_loss=0.342, val_acc=0.886, val_f1=0.882, train_loss=0.179, train_acc=0.923, train_f1=0.920]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.80it/s]
# Epoch 33: 100% 35/35 [00:03<00:00,  9.95it/s, v_num=sub0, val_loss=0.428, val_acc=0.852, val_f1=0.842, train_loss=0.170, train_acc=0.928, train_f1=0.924]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.66it/s]
# Epoch 34: 100% 35/35 [00:03<00:00,  9.85it/s, v_num=sub0, val_loss=0.359, val_acc=0.886, val_f1=0.882, train_loss=0.156, train_acc=0.938, train_f1=0.934]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.18it/s]
# Epoch 35: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.430, val_acc=0.863, val_f1=0.854, train_loss=0.162, train_acc=0.933, train_f1=0.929]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 55.27it/s]
# Epoch 36: 100% 35/35 [00:03<00:00, 10.03it/s, v_num=sub0, val_loss=0.399, val_acc=0.872, val_f1=0.866, train_loss=0.145, train_acc=0.938, train_f1=0.934]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.92it/s]
# Epoch 37: 100% 35/35 [00:03<00:00, 10.05it/s, v_num=sub0, val_loss=0.423, val_acc=0.864, val_f1=0.856, train_loss=0.126, train_acc=0.946, train_f1=0.943]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 56.50it/s]
# Epoch 38: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.403, val_acc=0.873, val_f1=0.869, train_loss=0.146, train_acc=0.940, train_f1=0.937]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.80it/s]
# Epoch 39: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.468, val_acc=0.861, val_f1=0.852, train_loss=0.140, train_acc=0.944, train_f1=0.942]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.05it/s]
# Epoch 40: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.399, val_acc=0.861, val_f1=0.854, train_loss=0.133, train_acc=0.945, train_f1=0.942]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.87it/s]
# Epoch 41: 100% 35/35 [00:03<00:00, 10.00it/s, v_num=sub0, val_loss=0.400, val_acc=0.879, val_f1=0.875, train_loss=0.153, train_acc=0.934, train_f1=0.930]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.82it/s]
# Epoch 42: 100% 35/35 [00:03<00:00, 10.02it/s, v_num=sub0, val_loss=0.410, val_acc=0.888, val_f1=0.885, train_loss=0.119, train_acc=0.960, train_f1=0.958]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.99it/s]
# Epoch 43: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=sub0, val_loss=0.360, val_acc=0.879, val_f1=0.872, train_loss=0.121, train_acc=0.950, train_f1=0.947]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.69it/s]
# Epoch 44: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.376, val_acc=0.884, val_f1=0.879, train_loss=0.130, train_acc=0.947, train_f1=0.944]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.71it/s]
# Epoch 45: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.387, val_acc=0.884, val_f1=0.881, train_loss=0.133, train_acc=0.949, train_f1=0.946]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 56.69it/s]
# Epoch 46: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=sub0, val_loss=0.405, val_acc=0.890, val_f1=0.887, train_loss=0.130, train_acc=0.946, train_f1=0.943]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.01it/s]
# Epoch 47: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.399, val_acc=0.875, val_f1=0.870, train_loss=0.110, train_acc=0.957, train_f1=0.955]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.42it/s]
# Epoch 48: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=sub0, val_loss=0.391, val_acc=0.884, val_f1=0.880, train_loss=0.120, train_acc=0.951, train_f1=0.947]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.80it/s]
# Epoch 49: 100% 35/35 [00:03<00:00, 10.01it/s, v_num=sub0, val_loss=0.396, val_acc=0.892, val_f1=0.888, train_loss=0.113, train_acc=0.957, train_f1=0.955]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.93it/s]
# Epoch 50: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.358, val_acc=0.881, val_f1=0.877, train_loss=0.119, train_acc=0.951, train_f1=0.949]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.54it/s]
# Epoch 51: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.543, val_acc=0.850, val_f1=0.838, train_loss=0.114, train_acc=0.953, train_f1=0.951]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.26it/s]
# Epoch 52: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.421, val_acc=0.864, val_f1=0.856, train_loss=0.111, train_acc=0.953, train_f1=0.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 50.18it/s]
# Epoch 53: 100% 35/35 [00:03<00:00, 10.02it/s, v_num=sub0, val_loss=0.459, val_acc=0.864, val_f1=0.855, train_loss=0.118, train_acc=0.952, train_f1=0.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.02it/s]
# Epoch 54: 100% 35/35 [00:03<00:00, 10.06it/s, v_num=sub0, val_loss=0.400, val_acc=0.893, val_f1=0.889, train_loss=0.101, train_acc=0.962, train_f1=0.959]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.31it/s]
# Epoch 55: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.356, val_acc=0.893, val_f1=0.890, train_loss=0.108, train_acc=0.959, train_f1=0.957]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.37it/s]
# Epoch 56: 100% 35/35 [00:03<00:00, 10.03it/s, v_num=sub0, val_loss=0.528, val_acc=0.846, val_f1=0.835, train_loss=0.103, train_acc=0.962, train_f1=0.960]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.34it/s]
# Epoch 57: 100% 35/35 [00:03<00:00, 10.05it/s, v_num=sub0, val_loss=0.388, val_acc=0.892, val_f1=0.887, train_loss=0.094, train_acc=0.966, train_f1=0.964]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.34it/s]
# Epoch 58: 100% 35/35 [00:03<00:00, 10.05it/s, v_num=sub0, val_loss=0.465, val_acc=0.877, val_f1=0.870, train_loss=0.085, train_acc=0.969, train_f1=0.968]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.71it/s]
# Epoch 59: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=sub0, val_loss=0.394, val_acc=0.890, val_f1=0.885, train_loss=0.0811, train_acc=0.970, train_f1=0.969]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.59it/s]
# Epoch 60: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.405, val_acc=0.895, val_f1=0.891, train_loss=0.0796, train_acc=0.969, train_f1=0.968]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.50it/s]
# Epoch 61: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=sub0, val_loss=0.467, val_acc=0.866, val_f1=0.858, train_loss=0.0879, train_acc=0.965, train_f1=0.962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.36it/s]
# Epoch 62: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.469, val_acc=0.872, val_f1=0.865, train_loss=0.106, train_acc=0.959, train_f1=0.957]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.62it/s]
# Epoch 63: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.486, val_acc=0.868, val_f1=0.861, train_loss=0.0843, train_acc=0.967, train_f1=0.966]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.96it/s]
# Epoch 64: 100% 35/35 [00:03<00:00, 10.06it/s, v_num=sub0, val_loss=0.589, val_acc=0.859, val_f1=0.850, train_loss=0.094, train_acc=0.965, train_f1=0.963]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.79it/s]
# Epoch 65: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.439, val_acc=0.890, val_f1=0.887, train_loss=0.117, train_acc=0.955, train_f1=0.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.01it/s]
# Epoch 66: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.499, val_acc=0.875, val_f1=0.867, train_loss=0.112, train_acc=0.954, train_f1=0.951]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.21it/s]
# Epoch 67: 100% 35/35 [00:03<00:00, 10.02it/s, v_num=sub0, val_loss=0.362, val_acc=0.884, val_f1=0.880, train_loss=0.0769, train_acc=0.969, train_f1=0.968]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 47.79it/s]
# Epoch 68: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.424, val_acc=0.881, val_f1=0.876, train_loss=0.0833, train_acc=0.969, train_f1=0.966]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.35it/s]
# Epoch 69: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.402, val_acc=0.881, val_f1=0.876, train_loss=0.0726, train_acc=0.972, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.98it/s]
# Epoch 70: 100% 35/35 [00:03<00:00, 10.06it/s, v_num=sub0, val_loss=0.393, val_acc=0.881, val_f1=0.876, train_loss=0.0869, train_acc=0.970, train_f1=0.967]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.20it/s]
# Epoch 71: 100% 35/35 [00:03<00:00,  9.96it/s, v_num=sub0, val_loss=0.415, val_acc=0.881, val_f1=0.875, train_loss=0.076, train_acc=0.974, train_f1=0.973]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.26it/s]
# Epoch 72: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.439, val_acc=0.882, val_f1=0.877, train_loss=0.0625, train_acc=0.975, train_f1=0.973]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.90it/s]
# Epoch 73: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=sub0, val_loss=0.451, val_acc=0.873, val_f1=0.867, train_loss=0.0756, train_acc=0.971, train_f1=0.969]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.02it/s]
# Epoch 74: 100% 35/35 [00:03<00:00, 10.01it/s, v_num=sub0, val_loss=0.450, val_acc=0.888, val_f1=0.885, train_loss=0.0742, train_acc=0.973, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 51.80it/s]
# Epoch 75: 100% 35/35 [00:03<00:00, 10.03it/s, v_num=sub0, val_loss=0.511, val_acc=0.868, val_f1=0.860, train_loss=0.0696, train_acc=0.974, train_f1=0.973]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.18it/s]
# Epoch 76: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=sub0, val_loss=0.448, val_acc=0.888, val_f1=0.883, train_loss=0.0615, train_acc=0.977, train_f1=0.975]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.65it/s]
# Epoch 77: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.470, val_acc=0.882, val_f1=0.879, train_loss=0.0743, train_acc=0.968, train_f1=0.966]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.84it/s]
# Epoch 78: 100% 35/35 [00:03<00:00, 10.00it/s, v_num=sub0, val_loss=0.465, val_acc=0.875, val_f1=0.870, train_loss=0.0692, train_acc=0.974, train_f1=0.972]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 52.67it/s]
# Epoch 79: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=sub0, val_loss=0.462, val_acc=0.884, val_f1=0.880, train_loss=0.0615, train_acc=0.977, train_f1=0.976]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.39it/s]
# Epoch 80: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.437, val_acc=0.877, val_f1=0.872, train_loss=0.0564, train_acc=0.977, train_f1=0.976]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.63it/s]
# Epoch 81: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.409, val_acc=0.882, val_f1=0.877, train_loss=0.0549, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.84it/s]
# Epoch 82: 100% 35/35 [00:03<00:00,  9.98it/s, v_num=sub0, val_loss=0.406, val_acc=0.892, val_f1=0.887, train_loss=0.0621, train_acc=0.976, train_f1=0.976]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 56.64it/s]
# Epoch 83: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.416, val_acc=0.893, val_f1=0.889, train_loss=0.0637, train_acc=0.974, train_f1=0.972]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.04it/s]
# Epoch 84: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.501, val_acc=0.879, val_f1=0.873, train_loss=0.0572, train_acc=0.978, train_f1=0.977]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.08it/s]
# Epoch 85: 100% 35/35 [00:03<00:00, 10.05it/s, v_num=sub0, val_loss=0.450, val_acc=0.895, val_f1=0.891, train_loss=0.0567, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.46it/s]
# Epoch 86: 100% 35/35 [00:03<00:00, 10.04it/s, v_num=sub0, val_loss=0.452, val_acc=0.879, val_f1=0.874, train_loss=0.0635, train_acc=0.980, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.38it/s]
# Epoch 87: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.465, val_acc=0.884, val_f1=0.881, train_loss=0.0495, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.80it/s]
# Epoch 88: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=sub0, val_loss=0.403, val_acc=0.890, val_f1=0.886, train_loss=0.0566, train_acc=0.973, train_f1=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.86it/s]
# Epoch 89: 100% 35/35 [00:03<00:00, 10.03it/s, v_num=sub0, val_loss=0.704, val_acc=0.852, val_f1=0.839, train_loss=0.0561, train_acc=0.980, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.70it/s]
# Epoch 90: 100% 35/35 [00:03<00:00, 10.03it/s, v_num=sub0, val_loss=0.496, val_acc=0.868, val_f1=0.860, train_loss=0.0708, train_acc=0.973, train_f1=0.972]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.19it/s]
# Epoch 91: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.481, val_acc=0.877, val_f1=0.871, train_loss=0.052, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.52it/s]
# Epoch 92: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.414, val_acc=0.897, val_f1=0.893, train_loss=0.0664, train_acc=0.975, train_f1=0.973]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.58it/s]
# Epoch 93: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.463, val_acc=0.890, val_f1=0.886, train_loss=0.0659, train_acc=0.977, train_f1=0.976]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.13it/s]
# Epoch 94: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=sub0, val_loss=0.466, val_acc=0.881, val_f1=0.875, train_loss=0.0493, train_acc=0.981, train_f1=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.30it/s]
# Epoch 95: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.472, val_acc=0.888, val_f1=0.883, train_loss=0.0497, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.88it/s]
# Epoch 96: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.500, val_acc=0.877, val_f1=0.871, train_loss=0.0628, train_acc=0.975, train_f1=0.973]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.60it/s]
# Epoch 97: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.416, val_acc=0.886, val_f1=0.882, train_loss=0.0542, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.30it/s]
# Epoch 98: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.456, val_acc=0.884, val_f1=0.881, train_loss=0.0722, train_acc=0.977, train_f1=0.976]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.79it/s]
# Epoch 99: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.428, val_acc=0.892, val_f1=0.888, train_loss=0.0612, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.10it/s]
# Epoch 100: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.440, val_acc=0.899, val_f1=0.895, train_loss=0.0499, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.50it/s]
# Epoch 101: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.454, val_acc=0.897, val_f1=0.894, train_loss=0.0432, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.05it/s]
# Epoch 102: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=sub0, val_loss=0.433, val_acc=0.893, val_f1=0.889, train_loss=0.0614, train_acc=0.977, train_f1=0.975]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.15it/s]
# Epoch 103: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.477, val_acc=0.893, val_f1=0.889, train_loss=0.0448, train_acc=0.983, train_f1=0.982]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.16it/s]
# Epoch 104: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.455, val_acc=0.897, val_f1=0.894, train_loss=0.0392, train_acc=0.986, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.02it/s]
# Epoch 105: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=sub0, val_loss=0.508, val_acc=0.882, val_f1=0.878, train_loss=0.0459, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.83it/s]
# Epoch 106: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=sub0, val_loss=0.479, val_acc=0.884, val_f1=0.879, train_loss=0.0344, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.42it/s]
# Epoch 107: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.475, val_acc=0.877, val_f1=0.871, train_loss=0.0453, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 63.09it/s]
# Epoch 108: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=sub0, val_loss=0.447, val_acc=0.886, val_f1=0.882, train_loss=0.0387, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.46it/s]
# Epoch 109: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=sub0, val_loss=0.456, val_acc=0.890, val_f1=0.886, train_loss=0.0287, train_acc=0.991, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.08it/s]
# Epoch 110: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.454, val_acc=0.892, val_f1=0.888, train_loss=0.048, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.22it/s]
# Epoch 111: 100% 35/35 [00:03<00:00,  9.98it/s, v_num=sub0, val_loss=0.451, val_acc=0.890, val_f1=0.885, train_loss=0.0426, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.46it/s]
# Epoch 112: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.466, val_acc=0.882, val_f1=0.877, train_loss=0.0583, train_acc=0.980, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.04it/s]
# Epoch 113: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.461, val_acc=0.893, val_f1=0.889, train_loss=0.0437, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 57.44it/s]
# Epoch 114: 100% 35/35 [00:03<00:00, 10.04it/s, v_num=sub0, val_loss=0.470, val_acc=0.882, val_f1=0.877, train_loss=0.045, train_acc=0.983, train_f1=0.982]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.40it/s]
# Epoch 115: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.487, val_acc=0.892, val_f1=0.886, train_loss=0.0338, train_acc=0.987, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.41it/s]
# Epoch 116: 100% 35/35 [00:03<00:00, 10.08it/s, v_num=sub0, val_loss=0.493, val_acc=0.893, val_f1=0.890, train_loss=0.0501, train_acc=0.979, train_f1=0.978]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.86it/s]
# Epoch 117: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=sub0, val_loss=0.441, val_acc=0.884, val_f1=0.880, train_loss=0.0363, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.69it/s]
# Epoch 118: 100% 35/35 [00:03<00:00,  9.99it/s, v_num=sub0, val_loss=0.527, val_acc=0.868, val_f1=0.861, train_loss=0.035, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 60.76it/s]
# Epoch 119: 100% 35/35 [00:03<00:00, 10.00it/s, v_num=sub0, val_loss=0.469, val_acc=0.893, val_f1=0.889, train_loss=0.0377, train_acc=0.988, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.22it/s]
# Epoch 120: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.548, val_acc=0.868, val_f1=0.860, train_loss=0.0453, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.59it/s]
# Epoch 121: 100% 35/35 [00:03<00:00, 10.06it/s, v_num=sub0, val_loss=0.497, val_acc=0.868, val_f1=0.860, train_loss=0.0411, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.14it/s]
# Epoch 122: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.455, val_acc=0.884, val_f1=0.880, train_loss=0.0459, train_acc=0.984, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.88it/s]
# Epoch 123: 100% 35/35 [00:03<00:00, 10.02it/s, v_num=sub0, val_loss=0.491, val_acc=0.870, val_f1=0.864, train_loss=0.0448, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 56.15it/s]
# Epoch 124: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=sub0, val_loss=0.472, val_acc=0.888, val_f1=0.884, train_loss=0.0362, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.87it/s]
# Epoch 125: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.492, val_acc=0.882, val_f1=0.879, train_loss=0.0323, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 53.19it/s]
# Epoch 126: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.481, val_acc=0.877, val_f1=0.872, train_loss=0.0334, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.63it/s]
# Epoch 127: 100% 35/35 [00:03<00:00, 10.09it/s, v_num=sub0, val_loss=0.500, val_acc=0.888, val_f1=0.883, train_loss=0.0366, train_acc=0.986, train_f1=0.985]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.20it/s]
# Epoch 128: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=sub0, val_loss=0.501, val_acc=0.879, val_f1=0.873, train_loss=0.0432, train_acc=0.981, train_f1=0.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 54.49it/s]
# Epoch 129: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.539, val_acc=0.879, val_f1=0.873, train_loss=0.0424, train_acc=0.982, train_f1=0.981]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 54.40it/s]
# Epoch 130: 100% 35/35 [00:03<00:00,  9.97it/s, v_num=sub0, val_loss=0.459, val_acc=0.895, val_f1=0.891, train_loss=0.0317, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 59.30it/s]
# Epoch 131: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.495, val_acc=0.893, val_f1=0.890, train_loss=0.0449, train_acc=0.983, train_f1=0.982]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 58.72it/s]
# Epoch 132: 100% 35/35 [00:03<00:00, 10.07it/s, v_num=sub0, val_loss=0.488, val_acc=0.890, val_f1=0.886, train_loss=0.0302, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 62.88it/s]
# Epoch 133: 100% 35/35 [00:03<00:00, 10.00it/s, v_num=sub0, val_loss=0.506, val_acc=0.893, val_f1=0.890, train_loss=0.0412, train_acc=0.985, train_f1=0.984]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 49.13it/s]
# Epoch 134: 100% 35/35 [00:03<00:00,  9.99it/s, v_num=sub0, val_loss=0.482, val_acc=0.890, val_f1=0.886, train_loss=0.0243, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 55.88it/s]
# Epoch 135: 100% 35/35 [00:03<00:00, 10.04it/s, v_num=sub0, val_loss=0.512, val_acc=0.890, val_f1=0.885, train_loss=0.0301, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 61.31it/s]
# ...
# Epoch 156: 100% 35/35 [00:03<00:00, 10.19it/s, v_num=ub40, val_loss=0.670, val_acc=0.862, val_f1=0.856, train_loss=0.0249, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.35it/s]
# Epoch 157: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.794, val_acc=0.838, val_f1=0.826, train_loss=0.0268, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.84it/s]
# Epoch 158: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.651, val_acc=0.868, val_f1=0.862, train_loss=0.0217, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.22it/s]
# Epoch 159: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.728, val_acc=0.855, val_f1=0.845, train_loss=0.0281, train_acc=0.987, train_f1=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 70.12it/s]
# Epoch 160: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.684, val_acc=0.857, val_f1=0.849, train_loss=0.0373, train_acc=0.985, train_f1=0.983]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.16it/s]
# Epoch 161: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.769, val_acc=0.844, val_f1=0.832, train_loss=0.0249, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.91it/s]
# Epoch 162: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.978, val_acc=0.804, val_f1=0.781, train_loss=0.0307, train_acc=0.989, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 72.10it/s]
# Epoch 163: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.790, val_acc=0.844, val_f1=0.831, train_loss=0.0188, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.50it/s]
# Epoch 164: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.693, val_acc=0.864, val_f1=0.857, train_loss=0.0232, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.76it/s]
# Epoch 165: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.715, val_acc=0.857, val_f1=0.847, train_loss=0.0259, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.09it/s]
# Epoch 166: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.678, val_acc=0.862, val_f1=0.855, train_loss=0.0293, train_acc=0.990, train_f1=0.988]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.15it/s]
# Epoch 167: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.773, val_acc=0.844, val_f1=0.832, train_loss=0.0291, train_acc=0.989, train_f1=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.07it/s]
# Epoch 168: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.651, val_acc=0.864, val_f1=0.857, train_loss=0.0264, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.36it/s]
# Epoch 169: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.715, val_acc=0.858, val_f1=0.848, train_loss=0.022, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.73it/s]
# Epoch 170: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.681, val_acc=0.862, val_f1=0.853, train_loss=0.023, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.96it/s]
# Epoch 171: 100% 35/35 [00:03<00:00, 10.18it/s, v_num=ub40, val_loss=0.742, val_acc=0.857, val_f1=0.846, train_loss=0.0232, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.33it/s]
# Epoch 172: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.638, val_acc=0.862, val_f1=0.856, train_loss=0.0245, train_acc=0.991, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.27it/s]
# Epoch 173: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.639, val_acc=0.864, val_f1=0.858, train_loss=0.0176, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.86it/s]
# Epoch 174: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.623, val_acc=0.864, val_f1=0.859, train_loss=0.0274, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.25it/s]
# Epoch 175: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.794, val_acc=0.831, val_f1=0.816, train_loss=0.021, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 72.73it/s]
# Epoch 176: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.704, val_acc=0.855, val_f1=0.844, train_loss=0.0225, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 65.52it/s]
# Epoch 177: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.641, val_acc=0.862, val_f1=0.856, train_loss=0.0155, train_acc=0.996, train_f1=0.996]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.95it/s]
# Epoch 178: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.741, val_acc=0.849, val_f1=0.837, train_loss=0.0248, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.25it/s]
# Epoch 179: 100% 35/35 [00:03<00:00, 10.15it/s, v_num=ub40, val_loss=0.710, val_acc=0.853, val_f1=0.842, train_loss=0.0205, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.02it/s]
# Epoch 180: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.651, val_acc=0.864, val_f1=0.857, train_loss=0.0246, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.20it/s]
# Epoch 181: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.721, val_acc=0.855, val_f1=0.844, train_loss=0.0303, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.03it/s]
# Epoch 182: 100% 35/35 [00:03<00:00, 10.19it/s, v_num=ub40, val_loss=0.622, val_acc=0.866, val_f1=0.860, train_loss=0.0234, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.71it/s]
# Epoch 183: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.770, val_acc=0.848, val_f1=0.836, train_loss=0.023, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.48it/s]
# Epoch 184: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.951, val_acc=0.819, val_f1=0.800, train_loss=0.0275, train_acc=0.990, train_f1=0.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.15it/s]
# Epoch 185: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.818, val_acc=0.840, val_f1=0.827, train_loss=0.0222, train_acc=0.992, train_f1=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.78it/s]
# Epoch 186: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.659, val_acc=0.857, val_f1=0.849, train_loss=0.019, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 70.38it/s]
# Epoch 187: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.709, val_acc=0.858, val_f1=0.849, train_loss=0.017, train_acc=0.995, train_f1=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.33it/s]
# Epoch 188: 100% 35/35 [00:03<00:00, 10.19it/s, v_num=ub40, val_loss=0.922, val_acc=0.822, val_f1=0.804, train_loss=0.0215, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.49it/s]
# Epoch 189: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.698, val_acc=0.866, val_f1=0.857, train_loss=0.0251, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 69.48it/s]
# Epoch 190: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.639, val_acc=0.864, val_f1=0.858, train_loss=0.0194, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 64.10it/s]
# Epoch 191: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.638, val_acc=0.864, val_f1=0.858, train_loss=0.0217, train_acc=0.994, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.86it/s]
# Epoch 192: 100% 35/35 [00:03<00:00, 10.14it/s, v_num=ub40, val_loss=0.771, val_acc=0.853, val_f1=0.842, train_loss=0.0236, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.91it/s]
# Epoch 193: 100% 35/35 [00:03<00:00, 10.13it/s, v_num=ub40, val_loss=0.862, val_acc=0.831, val_f1=0.815, train_loss=0.0241, train_acc=0.992, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.25it/s]
# Epoch 194: 100% 35/35 [00:03<00:00, 10.12it/s, v_num=ub40, val_loss=0.759, val_acc=0.855, val_f1=0.844, train_loss=0.016, train_acc=0.993, train_f1=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 67.78it/s]
# Epoch 195: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.670, val_acc=0.866, val_f1=0.859, train_loss=0.0228, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.51it/s]
# Epoch 196: 100% 35/35 [00:03<00:00, 10.16it/s, v_num=ub40, val_loss=0.947, val_acc=0.820, val_f1=0.802, train_loss=0.0228, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 68.12it/s]
# Epoch 197: 100% 35/35 [00:03<00:00, 10.10it/s, v_num=ub40, val_loss=0.721, val_acc=0.858, val_f1=0.849, train_loss=0.0291, train_acc=0.990, train_f1=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.88it/s]
# Epoch 198: 100% 35/35 [00:03<00:00, 10.17it/s, v_num=ub40, val_loss=0.952, val_acc=0.817, val_f1=0.798, train_loss=0.0175, train_acc=0.995, train_f1=0.994]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.91it/s]
# Epoch 199: 100% 35/35 [00:03<00:00, 10.11it/s, v_num=ub40, val_loss=0.711, val_acc=0.858, val_f1=0.849, train_loss=0.0211, train_acc=0.994, train_f1=0.993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 9/9 [00:00<00:00, 66.74it/s]
# Epoch 199: 100% 35/35 [00:03<00:00,  9.71it/s, v_num=ub40, val_loss=0.706, val_acc=0.860, val_f1=0.851, train_loss=0.0287, train_acc=0.989, train_f1=0.988]`Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199: 100% 35/35 [00:03<00:00,  9.71it/s, v_num=ub40, val_loss=0.706, val_acc=0.860, val_f1=0.851, train_loss=0.0287, train_acc=0.989, train_f1=0.988]
# Loading best model weights from: ./save/SNR_5/sub40/logs_FATIG_Deformer/sub40/checkpoints/epoch=68-step=2415.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 1/1 [00:00<00:00, 27.64it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.8241205811500549     │
# │          test_f1          │    0.8241028189659119     │
# │         test_loss         │    1.1289572715759277     │
# └───────────────────────────┴───────────────────────────┘
# Data has been logged to ./save/SNR_5/sub40/logs_FATIG_Deformer/sub40/result.csv
# cp: cannot stat './save/SNR_5/sub40/result.csv': No such file or directory
# ✅ Sub 40 results secured in Drive.

# %% [markdown]
# ## Plot Experiment 2

# %%
from google.colab import drive

# 1. Unmount the drive (this clears the 'busy' error)
# Note: This might throw a warning if it's already unmounted, that's fine.
# !fusermount -u /content/drive

# 2. Re-mount the drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

path = "/content/drive/MyDrive/MVA/time-series-project/"

df_b = pd.read_csv(path + "baseline_results.csv")
df_20 = pd.read_csv(path + "SNR_20_results.csv")
df_5 = pd.read_csv(path + "SNR_5_results.csv")

for df in [df_b, df_20, df_5]:
    df.columns = df.columns.str.strip()

shared_subs = ['sub0', 'sub21', 'sub30', 'sub40']
conditions = ['Baseline', 'SNR 20dB', 'SNR 5dB']

def get_subset_data(metric_name):
    """Extracts a 2D array of [subjects x conditions] for a specific metric."""
    matrix = []
    for sub in shared_subs:
        row = [
            df_b[df_b['Subject'] == sub][metric_name].values[0],
            df_20[df_20['Subject'] == sub][metric_name].values[0],
            df_5[df_5['Subject'] == sub][metric_name].values[0]
        ]
        matrix.append(row)
    return np.array(matrix)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
markers = ['o', 's', '^', 'D']

#Accuracy Decay
acc_data = get_subset_data('Test_Accuracy')
for i, sub in enumerate(shared_subs):
    ax1.plot(conditions, acc_data[i], marker=markers[i], label=f'Subject {sub[3:]}',
             color=colors[i], linewidth=2.5, markersize=8)

ax1.set_title("Robustness Stress Test: Accuracy", fontsize=14, fontweight='bold')
ax1.set_ylabel("Accuracy Score")
ax1.set_ylim(0.5, 1.0) # Increased limit to see the 'Resilience' better
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend()

#  F1-Score Decay
f1_data = get_subset_data('Test_F1')
for i, sub in enumerate(shared_subs):
    ax2.plot(conditions, f1_data[i], marker=markers[i], label=f'Subject {sub[3:]}',
             color=colors[i], linewidth=2.5, markersize=8)

ax2.set_title("Robustness Stress Test: F1-Score", fontsize=14, fontweight='bold')
ax2.set_ylabel("F1-Score")
ax2.set_ylim(0.4, 1.0)
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend()

plt.suptitle("EEG-Deformer Longitudinal Performance Analysis (Shared Subset N=4)",
             fontsize=16, fontweight='bold', y=1.05)
plt.tight_layout()


save_name = "submission_robustness_plot.png"
local_path = "./" + save_name
drive_full_path = path + save_name


fig.savefig(local_path, dpi=300, bbox_inches='tight')

# copy from local runtime to Drive
import shutil
shutil.copy(local_path, drive_full_path)

# download
from google.colab import files
files.download(local_path)


plt.show()


# summary
print("\n" + "="*50)
print(f"{'Condition':<15} | {'Mean Acc':<10} | {'Mean F1':<10}")
print("-" * 50)
subset_acc_means = acc_data.mean(axis=0)
subset_f1_means = f1_data.mean(axis=0)

for i, cond in enumerate(conditions):
    print(f"{cond:<15} | {subset_acc_means[i]:.4f}     | {subset_f1_means[i]:.4f}")
print("="*50)
# Out:
# ==================================================
# Condition       | Mean Acc   | Mean F1
# --------------------------------------------------
# Baseline        | 0.7345     | 0.7325
# SNR 20dB        | 0.7432     | 0.7387
# SNR 5dB         | 0.7343     | 0.7324
# ==================================================
